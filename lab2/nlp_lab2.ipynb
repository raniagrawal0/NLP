# %%
pip install visual-automata

# %%
import re

def valid_eng_word(word):
    pattern = r'\b[a-z]+\b'  # start and end with lowercase letters only
    accept = re.fullmatch(pattern, word)
    if accept:
        print(accept.string,'Accepted')
    else:
        print('Not accepted')

# %%
valid_eng_word('dog'),
valid_eng_word('cat'),
valid_eng_word('a  '),
valid_eng_word('rani0')
valid_eng_word(' cat'),
valid_eng_word('_at')
# Out:
# dog Accepted
# cat Accepted
# Not accepted
# Not accepted
# Not accepted
# Not accepted

# %%
from automata.fa.dfa import DFA

from visual_automata.fa.dfa import VisualDFA

# %% [raw]
# #not working
#
# # Define DFA
#
# alphabet = set('abcdefghijklmnopqrstuvwxyz')
#
# dfa = DFA(
#     states={'q0', 'q1', 'q2', 'q3', 'q4', 'q5', 'dead'},
#     input_symbols=alphabet,
#     transitions={
#         'q0': {ch: 'q1' for ch in alphabet},
#         'q1': {ch: 'q2' for ch in alphabet},
#         'q2': {ch: 'q3' for ch in alphabet},
#         'q3': {ch: 'q4' for ch in alphabet},
#         'q4': {ch: 'q5' for ch in alphabet},
#         'q5': {ch: 'dead' for ch in alphabet},  # extra input goes to dead
#         'dead': {ch: 'dead' for ch in alphabet},  # dead state loops
#     },
#     initial_state='q0',
#     final_states={'q5'}  # accept only 5-letter lowercase words
# )
#
# # Visualize DFA
# visual_dfa = VisualDFA(dfa)
# visual_dfa.show_diagram()

# %%
import os

# Optional: load the nouns from brown_nouns.txt if available
lexicon = set()    #unordered
if os.path.exists("brown_nouns.txt"):
    with open("brown_nouns.txt", "r") as f:
        lexicon = {line.strip().lower() for line in f if line.strip()}
        

print(len(lexicon))
# Irregular plural forms
irregular_plurals = {
    "men": "man",
    "women": "woman",
    "children": "child",
    "teeth": "tooth",
    "feet": "foot",
    "mice": "mouse",
    "geese": "goose",
    "knives": "knife",
    "wives": "wife",
    "lives": "life",
    "leaves": "leaf",
}

def analyze_noun(word):
    w = word.lower()

    # Irregular plural check
    if w in irregular_plurals:
        return f"{irregular_plurals[w]}+N+PL"
    if w in irregular_plurals.values():
        return f"{w}+N+SG"

    # Rule: Plural with 'es' after certain endings
    if w.endswith("es"):
        if any(w.endswith(e) for e in ["ses", "zes", "xes", "ches", "shes"]):
            root = w[:-2]  # remove 'es'
            if lexicon and root not in lexicon:
                return "Invalid Word"
            return f"{root}+N+PL"

    # Rule: Plural with 'ies' (y → ies)
    if w.endswith("ies"):
        root = w[:-3] + "y"
        if lexicon and root not in lexicon:
            return "Invalid Word"
        return f"{root}+N+PL"

    # Rule: Singular with 'y'
    if w.endswith("y"):
        if lexicon and w not in lexicon:
            return "Invalid Word"
        return f"{w}+N+SG"

    # Rule: Regular plural with 's'
    if w.endswith("s"):
        root = w[:-1]
        # Reject if root ends with x, s, z, ch, sh (needs 'es')
        if any(root.endswith(e) for e in ["x", "s", "z", "ch", "sh"]):
            return "Invalid Word"
        
        return f"{root}+N+PL"

    # Singular default
    if lexicon and w not in lexicon:
        return "Invalid Word"
    return f"{w}+N+SG"

for i,word in enumerate(lexicon):
    print(f"{i+1}.{word} = {analyze_noun(word)}")

#print(f"{'ballards'} = {analyze_noun('ballards')}")
# Out:
# 17892
# 1.landing = landing+N+SG
# 2.optics = optic+N+PL
# 3.scrim = scrim+N+SG
# 4.associates = associate+N+PL
# 5.similarities = similarity+N+PL
# 6.video = video+N+SG
# 7.bluebush = bluebush+N+SG
# 8.stretcher = stretcher+N+SG
# 9.alteration = alteration+N+SG
# 10.swallows = swallow+N+PL
# 11.grubs = grub+N+PL
# 12.downs = down+N+PL
# 13.ucla = ucla+N+SG
# 14.groundwork = groundwork+N+SG
# 15.bobby = bobby+N+SG
# 16.shit = shit+N+SG
# 17.horsepower = horsepower+N+SG
# 18.ducks = duck+N+PL
# 19.stampede = stampede+N+SG
# 20.bromphenol = bromphenol+N+SG
# 21.fruit = fruit+N+SG
# 22.remark = remark+N+SG
# 23.delusion = delusion+N+SG
# 24.esters = ester+N+PL
# 25.electrolysis = electrolysi+N+PL
# 26.slowness = Invalid Word
# 27.shrubbery = shrubbery+N+SG
# 28.evangelists = evangelist+N+PL
# 29.threads = thread+N+PL
# 30.favors = favor+N+PL
# 31.doorkeeper = doorkeeper+N+SG
# 32.roar = roar+N+SG
# 33.bus = bu+N+PL
# 34.check = check+N+SG
# 35.acquisitions = acquisition+N+PL
# 36.staff = staff+N+SG
# 37.bun = bun+N+SG
# 38.head = head+N+SG
# 39.attentions = attention+N+PL
# 40.prairie = prairie+N+SG
# 41.thousands = thousand+N+PL
# 42.glen = glen+N+SG
# 43.phonetics = phonetic+N+PL
# 44.bloat = bloat+N+SG
# 45.standby = standby+N+SG
# 46.subspace = subspace+N+SG
# 47.walks = walk+N+PL
# 48.snuffer = snuffer+N+SG
# 49.chaperon = chaperon+N+SG
# 50.swim = swim+N+SG
# 51.depression = depression+N+SG
# 52.cane = cane+N+SG
# 53.breakwater = breakwater+N+SG
# 54.omelet = omelet+N+SG
# 55.optimum = optimum+N+SG
# 56.reproduction = reproduction+N+SG
# 57.shipmates = shipmate+N+PL
# 58.liabilities = liability+N+PL
# 59.curettage = curettage+N+SG
# 60.sensation = sensation+N+SG
# 61.aspiration = aspiration+N+SG
# 62.hail = hail+N+SG
# 63.grudges = grudge+N+PL
# 64.guiftes = guifte+N+PL
# 65.foreigners = foreigner+N+PL
# 66.provisons = provison+N+PL
# 67.demagnification = demagnification+N+SG
# 68.seeds = seed+N+PL
# 69.niece = niece+N+SG
# 70.pothole = pothole+N+SG
# 71.black = black+N+SG
# 72.transferral = transferral+N+SG
# 73.modifications = modification+N+PL
# 74.assault = assault+N+SG
# 75.ads = ad+N+PL
# 76.sheaf = sheaf+N+SG
# 77.calypso = calypso+N+SG
# 78.catcher = catcher+N+SG
# 79.bypass = Invalid Word
# 80.improviser = improviser+N+SG
# 81.rainbow = rainbow+N+SG
# 82.inns = inn+N+PL
# 83.gargle = gargle+N+SG
# 84.trestles = trestle+N+PL
# 85.leaflet = leaflet+N+SG
# 86.valley = valley+N+SG
# 87.overseas = oversea+N+PL
# 88.leg = leg+N+SG
# 89.steps = step+N+PL
# 90.catkin = catkin+N+SG
# 91.monopolists = monopolist+N+PL
# 92.craters = crater+N+PL
# 93.freak = freak+N+SG
# 94.oranges = orange+N+PL
# 95.frogs = frog+N+PL
# 96.connexion = connexion+N+SG
# 97.roasts = roast+N+PL
# 98.incomprehension = incomprehension+N+SG
# 99.enigma = enigma+N+SG
# 100.lionesses = lioness+N+PL
# 101.ibm = ibm+N+SG
# 102.patterns = pattern+N+PL
# 103.craze = craze+N+SG
# 104.peaches = peach+N+PL
# 105.saliva = saliva+N+SG
# 106.teen = teen+N+SG
# 107.solidity = solidity+N+SG
# 108.attributes = attribute+N+PL
# 109.islands = island+N+PL
# 110.shavings = shaving+N+PL
# 111.airmen = airmen+N+SG
# 112.memorial = memorial+N+SG
# 113.parsley = parsley+N+SG
# 114.comedies = comedy+N+PL
# 115.distiller = distiller+N+SG
# 116.indoctrinating = indoctrinating+N+SG
# 117.rake = rake+N+SG
# 118.debating = debating+N+SG
# 119.wagons = wagon+N+PL
# 120.goose = goose+N+SG
# 121.redcoats = redcoat+N+PL
# 122.expansiveness = Invalid Word
# 123.sinking = sinking+N+SG
# 124.name = name+N+SG
# 125.grace = grace+N+SG
# 126.rich = rich+N+SG
# 127.lubrication = lubrication+N+SG
# 128.exacerbation = exacerbation+N+SG
# 129.epitome = epitome+N+SG
# 130.anisotropy = anisotropy+N+SG
# 131.power = power+N+SG
# 132.chiefdoms = chiefdom+N+PL
# 133.coaching = coaching+N+SG
# 134.$.027 = $.027+N+SG
# 135.diocs = dioc+N+PL
# 136.litters = litter+N+PL
# 137.noise = noise+N+SG
# 138.offersey = offersey+N+SG
# 139.captures = capture+N+PL
# 140.curriculum = curriculum+N+SG
# 141.mysteries = mystery+N+PL
# 142.chute = chute+N+SG
# 143.reference = reference+N+SG
# 144.apartment = apartment+N+SG
# 145.9/32'' = 9/32''+N+SG
# 146.**b = **b+N+SG
# 147.'thirties = Invalid Word
# 148.sweetness = Invalid Word
# 149.glover = glover+N+SG
# 150.intent = intent+N+SG
# 151.least = least+N+SG
# 152.curls = curl+N+PL
# 153.thong = thong+N+SG
# 154.blushes = Invalid Word
# 155.sewer = sewer+N+SG
# 156.boatload = boatload+N+SG
# 157.vocalization = vocalization+N+SG
# 158.promoter = promoter+N+SG
# 159.switchboard = switchboard+N+SG
# 160.nester = nester+N+SG
# 161.races = race+N+PL
# 162.pistoleers = pistoleer+N+PL
# 163.sea = sea+N+SG
# 164.gage = gage+N+SG
# 165.48'' = 48''+N+SG
# 166.waves = wave+N+PL
# 167.speedometer = speedometer+N+SG
# 168.radiation = radiation+N+SG
# 169.tithes = tithe+N+PL
# 170.dancer = dancer+N+SG
# 171.ladder = ladder+N+SG
# 172.wars = war+N+PL
# 173.obviousness = Invalid Word
# 174.deathbed = deathbed+N+SG
# 175.wells = well+N+PL
# 176.antagonist = antagonist+N+SG
# 177.carriers = carrier+N+PL
# 178.insulin = insulin+N+SG
# 179.school = school+N+SG
# 180.highpoint = highpoint+N+SG
# 181.grapevines = grapevine+N+PL
# 182.algorithm = algorithm+N+SG
# 183.botany = botany+N+SG
# 184.tumbrels = tumbrel+N+PL
# 185.burglary = burglary+N+SG
# 186.provocation = provocation+N+SG
# 187.underwriting = underwriting+N+SG
# 188.magnums = magnum+N+PL
# 189.paratroops = paratroop+N+PL
# 190.licensing = licensing+N+SG
# 191.hills = hill+N+PL
# 192.doldrums = doldrum+N+PL
# 193.writs = writ+N+PL
# 194.obligations = obligation+N+PL
# 195.metamorphosis = metamorphosi+N+PL
# 196.breakers = breaker+N+PL
# 197.infraction = infraction+N+SG
# 198.line = line+N+SG
# 199.abaringe = abaringe+N+SG
# 200.sneak = sneak+N+SG
# 201.$11.50 = $11.50+N+SG
# 202.intuitions = intuition+N+PL
# 203.restaurateur = restaurateur+N+SG
# 204.necessities = necessity+N+PL
# 205.mantrap = mantrap+N+SG
# 206.caramel = caramel+N+SG
# 207.crudities = crudity+N+PL
# 208.workmen = workmen+N+SG
# 209.guard = guard+N+SG
# 210.13% = 13%+N+SG
# 211.$.12 = $.12+N+SG
# 212.enjoyment = enjoyment+N+SG
# 213.tannin = tannin+N+SG
# 214.bulletins = bulletin+N+PL
# 215.pool = pool+N+SG
# 216.rosebuds = rosebud+N+PL
# 217.poppies = poppy+N+PL
# 218.geldings = gelding+N+PL
# 219.burrow = burrow+N+SG
# 220.sojourners = sojourner+N+PL
# 221.rotor = rotor+N+SG
# 222.funerals = funeral+N+PL
# 223.raincoats = raincoat+N+PL
# 224.substitute = substitute+N+SG
# 225.food = food+N+SG
# 226.wristwatch = wristwatch+N+SG
# 227.descriptions = description+N+PL
# 228.listing = listing+N+SG
# 229.planeload = planeload+N+SG
# 230.learning = learning+N+SG
# 231.stumpage = stumpage+N+SG
# 232.smear = smear+N+SG
# 233.stake = stake+N+SG
# 234.regard = regard+N+SG
# 235.rigger = rigger+N+SG
# 236.frangipani = frangipani+N+SG
# 237.aggregation = aggregation+N+SG
# 238.motorscooters = motorscooter+N+PL
# 239.candidacy = candidacy+N+SG
# 240.stronghold = stronghold+N+SG
# 241.repeater = repeater+N+SG
# 242.cavemen = cavemen+N+SG
# 243.$.054/mbf = $.054/mbf+N+SG
# 244.midday = midday+N+SG
# 245.avail = avail+N+SG
# 246.patient = patient+N+SG
# 247.drums = drum+N+PL
# 248.shield = shield+N+SG
# 249.intolerance = intolerance+N+SG
# 250.sternum = sternum+N+SG
# 251.plagiarism = plagiarism+N+SG
# 252.killers = killer+N+PL
# 253.gentian = gentian+N+SG
# 254.carbon = carbon+N+SG
# 255.$70 = $70+N+SG
# 256.fresco = fresco+N+SG
# 257.$2,000,000 = $2,000,000+N+SG
# 258.height = height+N+SG
# 259.bull = bull+N+SG
# 260.ica's = ica'+N+PL
# 261.gauss = Invalid Word
# 262.exchanges = exchange+N+PL
# 263.theses = Invalid Word
# 264.bathroom = bathroom+N+SG
# 265.misstep = misstep+N+SG
# 266.$5,000 = $5,000+N+SG
# 267.radios = radio+N+PL
# 268.objective = objective+N+SG
# 269.intransigents = intransigent+N+PL
# 270.hosses = hoss+N+PL
# 271.recording = recording+N+SG
# 272.qualms = qualm+N+PL
# 273.convexity = convexity+N+SG
# 274.prophecy = prophecy+N+SG
# 275.xxxx = xxxx+N+SG
# 276.peg = peg+N+SG
# 277.defeat = defeat+N+SG
# 278.soviet = soviet+N+SG
# 279.greetings = greeting+N+PL
# 280.redheads = redhead+N+PL
# 281.nucleotide = nucleotide+N+SG
# 282.schoolchildren = schoolchildren+N+SG
# 283.pocket = pocket+N+SG
# 284.flood = flood+N+SG
# 285.immersion = immersion+N+SG
# 286.qualifications = qualification+N+PL
# 287.pacifier = pacifier+N+SG
# 288.pavilions = pavilion+N+PL
# 289.teacher = teacher+N+SG
# 290.stationmaster = stationmaster+N+SG
# 291.ecliptic = ecliptic+N+SG
# 292.dualism = dualism+N+SG
# 293.acquisitiveness = Invalid Word
# 294.unrealism = unrealism+N+SG
# 295.jumper = jumper+N+SG
# 296.stallion = stallion+N+SG
# 297.fennel = fennel+N+SG
# 298.champs = champ+N+PL
# 299.backs = back+N+PL
# 300.7/16'' = 7/16''+N+SG
# 301.brokers = broker+N+PL
# 302.sham = sham+N+SG
# 303.chum = chum+N+SG
# 304.fireman = fireman+N+SG
# 305.naivete = naivete+N+SG
# 306.mixing = mixing+N+SG
# 307.isolation = isolation+N+SG
# 308.entry = entry+N+SG
# 309.swell = swell+N+SG
# 310.snapping = snapping+N+SG
# 311.mungus = mungu+N+PL
# 312.sideboards = sideboard+N+PL
# 313.sharks = shark+N+PL
# 314.triplication = triplication+N+SG
# 315.royalties = royalty+N+PL
# 316.orthography = orthography+N+SG
# 317.tenure = tenure+N+SG
# 318.domain = domain+N+SG
# 319.continuities = continuity+N+PL
# 320.remorse = remorse+N+SG
# 321.galls = gall+N+PL
# 322.mistake = mistake+N+SG
# 323.hayfields = hayfield+N+PL
# 324.typewriter = typewriter+N+SG
# 325.claps = clap+N+PL
# 326.droves = drove+N+PL
# 327.homesickness = Invalid Word
# 328.cornerstone = cornerstone+N+SG
# 329.curtain = curtain+N+SG
# 330.barflies = Invalid Word
# 331.coaches = coach+N+PL
# 332.gatherings = gathering+N+PL
# 333.quarts = quart+N+PL
# 334.wires = wire+N+PL
# 335.view = view+N+SG
# 336.judge = judge+N+SG
# 337.impunity = impunity+N+SG
# 338.gapt = gapt+N+SG
# 339.diagonals = diagonal+N+PL
# 340.12a = 12a+N+SG
# 341.clinches = Invalid Word
# 342.train = train+N+SG
# 343.theaters = theater+N+PL
# 344.herpetology = herpetology+N+SG
# 345.burglars = burglar+N+PL
# 346.coriander = coriander+N+SG
# 347.qualification = qualification+N+SG
# 348.pins = pin+N+PL
# 349.matrix = matrix+N+SG
# 350.clarinet = clarinet+N+SG
# 351.narrator = narrator+N+SG
# 352.salads = salad+N+PL
# 353.inceptor = inceptor+N+SG
# 354.faculties = faculty+N+PL
# 355.sums = sum+N+PL
# 356.clown = clown+N+SG
# 357.bounty = bounty+N+SG
# 358.premiere = premiere+N+SG
# 359.umbrellas = umbrella+N+PL
# 360.uptake = uptake+N+SG
# 361.validation = validation+N+SG
# 362.promises = Invalid Word
# 363.decompression = decompression+N+SG
# 364.salutation = salutation+N+SG
# 365.deliberation = deliberation+N+SG
# 366.$22 = $22+N+SG
# 367.vendors = vendor+N+PL
# 368.commando = commando+N+SG
# 369.eclipse = eclipse+N+SG
# 370.anaesthesia = anaesthesia+N+SG
# 371.necktie = necktie+N+SG
# 372.exertions = exertion+N+PL
# 373.booth = booth+N+SG
# 374.situs = situ+N+PL
# 375.fibrin = fibrin+N+SG
# 376.corridors = corridor+N+PL
# 377.exaltation = exaltation+N+SG
# 378.accordance = accordance+N+SG
# 379.concessionaire = concessionaire+N+SG
# 380.troupes = troupe+N+PL
# 381.tailin' = tailin'+N+SG
# 382.searching = searching+N+SG
# 383.blackboard = blackboard+N+SG
# 384.duplication = duplication+N+SG
# 385.ton = ton+N+SG
# 386.buffer = buffer+N+SG
# 387.rack = rack+N+SG
# 388.steamboat = steamboat+N+SG
# 389.cumin = cumin+N+SG
# 390.combination = combination+N+SG
# 391.forcefulness = Invalid Word
# 392.renderings = rendering+N+PL
# 393.fee = fee+N+SG
# 394.kitchen = kitchen+N+SG
# 395.cheetah = cheetah+N+SG
# 396.myofibrils = myofibril+N+PL
# 397.patroness = Invalid Word
# 398.arylesterase = arylesterase+N+SG
# 399.thiihng = thiihng+N+SG
# 400.directivity = directivity+N+SG
# 401.tourist = tourist+N+SG
# 402.phenothiazine = phenothiazine+N+SG
# 403.amanuensis = amanuensi+N+PL
# 404.hallelujahs = hallelujah+N+PL
# 405.barbell = barbell+N+SG
# 406.industralization = industralization+N+SG
# 407.vaudeville = vaudeville+N+SG
# 408.hour = hour+N+SG
# 409.sovereigns = sovereign+N+PL
# 410.cuk**ya = cuk**ya+N+SG
# 411.trains = train+N+PL
# 412.kob = kob+N+SG
# 413.disputes = dispute+N+PL
# 414.hairpin = hairpin+N+SG
# 415.meditation = meditation+N+SG
# 416.negligence = negligence+N+SG
# 417.remains = remain+N+PL
# 418.hasps = hasp+N+PL
# 419.founders = founder+N+PL
# 420.bateau = bateau+N+SG
# 421.clothesbrush = clothesbrush+N+SG
# 422.replication = replication+N+SG
# 423.glamour = glamour+N+SG
# 424.philosophers = philosopher+N+PL
# 425.panoramas = panorama+N+PL
# 426.speedboat = speedboat+N+SG
# 427.furnace = furnace+N+SG
# 428.veldt = veldt+N+SG
# 429.troopships = troopship+N+PL
# 430.opus = opu+N+PL
# 431.cutback = cutback+N+SG
# 432.hangovers = hangover+N+PL
# 433.snapback = snapback+N+SG
# 434.muscles = muscle+N+PL
# 435.tart = tart+N+SG
# 436.discourse = discourse+N+SG
# 437.filagree = filagree+N+SG
# 438.duck = duck+N+SG
# 439.turmoil = turmoil+N+SG
# 440.eies = Invalid Word
# 441.gamut = gamut+N+SG
# 442.blowfish = blowfish+N+SG
# 443.airplanes = airplane+N+PL
# 444.insignificances = insignificance+N+PL
# 445.turntable = turntable+N+SG
# 446.subways = subway+N+PL
# 447.ship = ship+N+SG
# 448.seedlings = seedling+N+PL
# 449.masseur = masseur+N+SG
# 450.code,dtf = code,dtf+N+SG
# 451.trucks = truck+N+PL
# 452.frog = frog+N+SG
# 453.tip = tip+N+SG
# 454.outcasts = outcast+N+PL
# 455.character = character+N+SG
# 456.misery = misery+N+SG
# 457.nullity = nullity+N+SG
# 458.accuracy = accuracy+N+SG
# 459.$310 = $310+N+SG
# 460.vent = vent+N+SG
# 461.knives = knife+N+PL
# 462.diversion = diversion+N+SG
# 463.drawers = drawer+N+PL
# 464.righthander = righthander+N+SG
# 465.hirelings = hireling+N+PL
# 466.murmur = murmur+N+SG
# 467.bachelors = bachelor+N+PL
# 468.alert = alert+N+SG
# 469.gravy = gravy+N+SG
# 470.drapes = drape+N+PL
# 471.interrogation = interrogation+N+SG
# 472.scrimmage = scrimmage+N+SG
# 473.sensors = sensor+N+PL
# 474.launcher = launcher+N+SG
# 475.belting = belting+N+SG
# 476.equine = equine+N+SG
# 477.figment = figment+N+SG
# 478.$1.7 = $1.7+N+SG
# 479.agreeableness = Invalid Word
# 480.junction = junction+N+SG
# 481.eucalyptus = eucalyptu+N+PL
# 482.avenues = avenue+N+PL
# 483.abstention = abstention+N+SG
# 484.discussions = discussion+N+PL
# 485.critics = critic+N+PL
# 486.renunciations = renunciation+N+PL
# 487.splash = splash+N+SG
# 488.bean = bean+N+SG
# 489.cancers = cancer+N+PL
# 490.foreigner = foreigner+N+SG
# 491.retainers = retainer+N+PL
# 492.screams = scream+N+PL
# 493.genes = gene+N+PL
# 494.devices = device+N+PL
# 495.representation = representation+N+SG
# 496.effect = effect+N+SG
# 497.kindnesses = kindness+N+PL
# 498.clam = clam+N+SG
# 499.threesome = threesome+N+SG
# 500.reimbursements = reimbursement+N+PL
# 501.glitter = glitter+N+SG
# 502.expose = expose+N+SG
# 503.secrecy = secrecy+N+SG
# 504.ties = Invalid Word
# 505.pauses = Invalid Word
# 506.straightaway = straightaway+N+SG
# 507.involvement = involvement+N+SG
# 508.scanning = scanning+N+SG
# 509.stigmata = stigmata+N+SG
# 510.propulsions = propulsion+N+PL
# 511.i.d. = i.d.+N+SG
# 512.icicle = icicle+N+SG
# 513.illusion = illusion+N+SG
# 514.wood = wood+N+SG
# 515.climax = climax+N+SG
# 516.emphasis = emphasi+N+PL
# 517.mosquito = mosquito+N+SG
# 518.bazaar = bazaar+N+SG
# 519.clays = clay+N+PL
# 520.zest = zest+N+SG
# 521.abasement = abasement+N+SG
# 522.solitude = solitude+N+SG
# 523.steppes = steppe+N+PL
# 524.deferent = deferent+N+SG
# 525.nails = nail+N+PL
# 526.lacquer = lacquer+N+SG
# 527.horoscope = horoscope+N+SG
# 528.sensibility = sensibility+N+SG
# 529.polities = polity+N+PL
# 530.mysticisms = mysticism+N+PL
# 531.whodunnit = whodunnit+N+SG
# 532.bells = bell+N+PL
# 533.pitchers = pitcher+N+PL
# 534.reagents = reagent+N+PL
# 535.phrasing = phrasing+N+SG
# 536.allure = allure+N+SG
# 537.occlusion = occlusion+N+SG
# 538.hostilities = hostility+N+PL
# 539.stipulation = stipulation+N+SG
# 540.megalomania = megalomania+N+SG
# 541.vitals = vital+N+PL
# 542.busses = buss+N+PL
# 543.banter = banter+N+SG
# 544.boils = boil+N+PL
# 545.hurts = hurt+N+PL
# 546.mc. = mc.+N+SG
# 547.backyard = backyard+N+SG
# 548.gnome = gnome+N+SG
# 549.cells = cell+N+PL
# 550.trend = trend+N+SG
# 551.healing = healing+N+SG
# 552.ambiguity = ambiguity+N+SG
# 553.deodorant = deodorant+N+SG
# 554.keel = keel+N+SG
# 555.buckaroos = buckaroo+N+PL
# 556.revivals = revival+N+PL
# 557.itinerary = itinerary+N+SG
# 558.parallels = parallel+N+PL
# 559.barge = barge+N+SG
# 560.crankshaft = crankshaft+N+SG
# 561.finals = final+N+PL
# 562.lovering = lovering+N+SG
# 563.anomie = anomie+N+SG
# 564.kilowatts = kilowatt+N+PL
# 565.spoof = spoof+N+SG
# 566.antique = antique+N+SG
# 567.lice = lice+N+SG
# 568.adolescent = adolescent+N+SG
# 569.arrival = arrival+N+SG
# 570.sandbars = sandbar+N+PL
# 571.arbitration = arbitration+N+SG
# 572.dice = dice+N+SG
# 573.intestines = intestine+N+PL
# 574.deprivation = deprivation+N+SG
# 575.showdown = showdown+N+SG
# 576.bravura = bravura+N+SG
# 577.putout = putout+N+SG
# 578.dud = dud+N+SG
# 579.spoilage = spoilage+N+SG
# 580.volatilization = volatilization+N+SG
# 581.paleoexplosion = paleoexplosion+N+SG
# 582.steamer = steamer+N+SG
# 583.determinability = determinability+N+SG
# 584.begging = begging+N+SG
# 585.boucle = boucle+N+SG
# 586.orientation = orientation+N+SG
# 587.copolymers = copolymer+N+PL
# 588.switches = switch+N+PL
# 589.operators = operator+N+PL
# 590.pegs = peg+N+PL
# 591.drawbridge = drawbridge+N+SG
# 592.split = split+N+SG
# 593.office = office+N+SG
# 594.grassers = grasser+N+PL
# 595.scenes = scene+N+PL
# 596.squeals = squeal+N+PL
# 597.exploiters = exploiter+N+PL
# 598.folklore = folklore+N+SG
# 599.imbalance = imbalance+N+SG
# 600.differentiability = differentiability+N+SG
# 601.salves = salve+N+PL
# 602.arm = arm+N+SG
# 603.residence = residence+N+SG
# 604.expectation = expectation+N+SG
# 605.solutions = solution+N+PL
# 606.farms = farm+N+PL
# 607.rivals = rival+N+PL
# 608.expansion = expansion+N+SG
# 609.sreserve = sreserve+N+SG
# 610.minorities = minority+N+PL
# 611.palatability = palatability+N+SG
# 612.slitter = slitter+N+SG
# 613.substitutes = substitute+N+PL
# 614.prosperity = prosperity+N+SG
# 615.ommission = ommission+N+SG
# 616.bronchioles = bronchiole+N+PL
# 617.nahb = nahb+N+SG
# 618.match = match+N+SG
# 619.insistence = insistence+N+SG
# 620.shadowing = shadowing+N+SG
# 621.drinker = drinker+N+SG
# 622.perplexity = perplexity+N+SG
# 623.noblesse = noblesse+N+SG
# 624.currant = currant+N+SG
# 625.firemen = firemen+N+SG
# 626.shirts = shirt+N+PL
# 627.planter = planter+N+SG
# 628.monolith = monolith+N+SG
# 629.hunter = hunter+N+SG
# 630.prechlorination = prechlorination+N+SG
# 631.godliness = Invalid Word
# 632.acquiescence = acquiescence+N+SG
# 633.couplers = coupler+N+PL
# 634.disrepair = disrepair+N+SG
# 635.bathos = batho+N+PL
# 636.oxyhydroxides = oxyhydroxide+N+PL
# 637.toilets = toilet+N+PL
# 638.underarm = underarm+N+SG
# 639.fda = fda+N+SG
# 640.sieve = sieve+N+SG
# 641.amide = amide+N+SG
# 642.cousin = cousin+N+SG
# 643.artfulness = Invalid Word
# 644.canvases = canvas+N+PL
# 645.hackers = hacker+N+PL
# 646.fairness = Invalid Word
# 647.$57,500 = $57,500+N+SG
# 648.turkeys = turkey+N+PL
# 649.looks = look+N+PL
# 650.sunspot = sunspot+N+SG
# 651.kwhr = kwhr+N+SG
# 652.marble = marble+N+SG
# 653.deepening = deepening+N+SG
# 654.ransom = ransom+N+SG
# 655.kibbutzim = kibbutzim+N+SG
# 656.discipleship = discipleship+N+SG
# 657.complexity = complexity+N+SG
# 658.monopolization = monopolization+N+SG
# 659.megatons = megaton+N+PL
# 660.robbery = robbery+N+SG
# 661.sword = sword+N+SG
# 662.soul = soul+N+SG
# 663.horses = Invalid Word
# 664.ingredients = ingredient+N+PL
# 665.majority = majority+N+SG
# 666.undergraduate = undergraduate+N+SG
# 667.mean = mean+N+SG
# 668.gashes = gash+N+PL
# 669.pouches = pouch+N+PL
# 670.disadvantages = disadvantage+N+PL
# 671.unfoldment = unfoldment+N+SG
# 672.fanfare = fanfare+N+SG
# 673.conqueror = conqueror+N+SG
# 674.fidelity = fidelity+N+SG
# 675.chase = chase+N+SG
# 676.gambits = gambit+N+PL
# 677.10'' = 10''+N+SG
# 678.pencils = pencil+N+PL
# 679.threes = three+N+PL
# 680.problem = problem+N+SG
# 681.artificiality = artificiality+N+SG
# 682.portions = portion+N+PL
# 683.agglutination = agglutination+N+SG
# 684.group = group+N+SG
# 685.cosmos = cosmo+N+PL
# 686.seminar = seminar+N+SG
# 687.$18 = $18+N+SG
# 688.ivy = ivy+N+SG
# 689.resurgence = resurgence+N+SG
# 690.mistrial = mistrial+N+SG
# 691.ions = ion+N+PL
# 692.coolness = Invalid Word
# 693.method = method+N+SG
# 694.tremor = tremor+N+SG
# 695.violins = violin+N+PL
# 696.lactate = lactate+N+SG
# 697.sax = sax+N+SG
# 698.wrestlings = wrestling+N+PL
# 699.livestock = livestock+N+SG
# 700.grey = grey+N+SG
# 701.railways = railway+N+PL
# 702.rectangle = rectangle+N+SG
# 703.heaviness = Invalid Word
# 704.choking = choking+N+SG
# 705.resorts = resort+N+PL
# 706.dives = dive+N+PL
# 707.ventilator = ventilator+N+SG
# 708.vampires = vampire+N+PL
# 709.booklists = booklist+N+PL
# 710.cruiser = cruiser+N+SG
# 711.markings = marking+N+PL
# 712.cotillion = cotillion+N+SG
# 713.moisture = moisture+N+SG
# 714.resumption = resumption+N+SG
# 715.potentialities = potentiality+N+PL
# 716.oxcart = oxcart+N+SG
# 717.aspirant = aspirant+N+SG
# 718.intercept = intercept+N+SG
# 719.marijuana = marijuana+N+SG
# 720.pillows = pillow+N+PL
# 721.crackling = crackling+N+SG
# 722.balcony = balcony+N+SG
# 723.intervention = intervention+N+SG
# 724.divinity = divinity+N+SG
# 725.dustbin = dustbin+N+SG
# 726.sanctions = sanction+N+PL
# 727.queasiness = Invalid Word
# 728.miles = mile+N+PL
# 729.pfc = pfc+N+SG
# 730.modules = module+N+PL
# 731.coils = coil+N+PL
# 732.manner = manner+N+SG
# 733.driers = drier+N+PL
# 734.syndicates = syndicate+N+PL
# 735.delegates = delegate+N+PL
# 736.underbelly = underbelly+N+SG
# 737.trenches = trench+N+PL
# 738.sarcasms = sarcasm+N+PL
# 739.rookie = rookie+N+SG
# 740.agreement = agreement+N+SG
# 741.modernism = modernism+N+SG
# 742.galvanism = galvanism+N+SG
# 743.$2,300,000 = $2,300,000+N+SG
# 744.flour = flour+N+SG
# 745.consanguinity = consanguinity+N+SG
# 746.statesmen = statesmen+N+SG
# 747.lows = low+N+PL
# 748.appropriateness = Invalid Word
# 749.guitarist = guitarist+N+SG
# 750.solipsism = solipsism+N+SG
# 751.complex = complex+N+SG
# 752.salesmanship = salesmanship+N+SG
# 753.paucity = paucity+N+SG
# 754.miscalculation = miscalculation+N+SG
# 755.refraction = refraction+N+SG
# 756.fleas = flea+N+PL
# 757.fln = fln+N+SG
# 758.imaginations = imagination+N+PL
# 759.boulevard = boulevard+N+SG
# 760.nondriver = nondriver+N+SG
# 761.impurity = impurity+N+SG
# 762.schoolers = schooler+N+PL
# 763.emigration = emigration+N+SG
# 764.colloquy = colloquy+N+SG
# 765.cream = cream+N+SG
# 766.heights = height+N+PL
# 767.nickel = nickel+N+SG
# 768.bearer = bearer+N+SG
# 769.growths = growth+N+PL
# 770.amateur = amateur+N+SG
# 771.contrary = contrary+N+SG
# 772.assumption = assumption+N+SG
# 773.fathers = father+N+PL
# 774.epitaph = epitaph+N+SG
# 775.hose = hose+N+SG
# 776.foe = foe+N+SG
# 777.conceptions = conception+N+PL
# 778.cage = cage+N+SG
# 779.warfare = warfare+N+SG
# 780.ginghams = gingham+N+PL
# 781.kick = kick+N+SG
# 782.twitch = twitch+N+SG
# 783.autumn = autumn+N+SG
# 784.stirrup = stirrup+N+SG
# 785.planting = planting+N+SG
# 786.influx = influx+N+SG
# 787.trucking = trucking+N+SG
# 788.sellin' = sellin'+N+SG
# 789.modernity = modernity+N+SG
# 790.pangs = pang+N+PL
# 791.dline = dline+N+SG
# 792.incipiency = incipiency+N+SG
# 793.python = python+N+SG
# 794.lute = lute+N+SG
# 795.claims = claim+N+PL
# 796.corporations = corporation+N+PL
# 797.mores = more+N+PL
# 798.flyways = flyway+N+PL
# 799.heartbeat = heartbeat+N+SG
# 800.ass = Invalid Word
# 801.posse = posse+N+SG
# 802.woodcarver = woodcarver+N+SG
# 803.hash = hash+N+SG
# 804.tropidoclonion = tropidoclonion+N+SG
# 805.onrush = onrush+N+SG
# 806.rinse = rinse+N+SG
# 807.champions = champion+N+PL
# 808.imminence = imminence+N+SG
# 809.tint = tint+N+SG
# 810.swig = swig+N+SG
# 811.act = act+N+SG
# 812.squabbling = squabbling+N+SG
# 813.retrace = retrace+N+SG
# 814.adventures = adventure+N+PL
# 815.poultry = poultry+N+SG
# 816.clover = clover+N+SG
# 817.roundness = Invalid Word
# 818.laying = laying+N+SG
# 819.calfskin = calfskin+N+SG
# 820.boxer = boxer+N+SG
# 821.woodshed = woodshed+N+SG
# 822.lapses = laps+N+PL
# 823.wilt = wilt+N+SG
# 824.mike = mike+N+SG
# 825.tombs = tomb+N+PL
# 826.decrease = decrease+N+SG
# 827.$750,000 = $750,000+N+SG
# 828.acrylic = acrylic+N+SG
# 829.calamity = calamity+N+SG
# 830.renunciation = renunciation+N+SG
# 831.primaries = primary+N+PL
# 832.sins = sin+N+PL
# 833.sentence = sentence+N+SG
# 834.$80 = $80+N+SG
# 835.dispossession = dispossession+N+SG
# 836.store = store+N+SG
# 837.sphere = sphere+N+SG
# 838.patio = patio+N+SG
# 839.bill = bill+N+SG
# 840.stick = stick+N+SG
# 841.plane = plane+N+SG
# 842.rosettes = rosette+N+PL
# 843.tramp = tramp+N+SG
# 844.business = Invalid Word
# 845.correctness = Invalid Word
# 846.success = Invalid Word
# 847.find = find+N+SG
# 848.butterflies = butterfly+N+PL
# 849.wagon = wagon+N+SG
# 850.benevolence = benevolence+N+SG
# 851.society = society+N+SG
# 852.marrow = marrow+N+SG
# 853.devils = devil+N+PL
# 854.weeklies = weekly+N+PL
# 855.bunt = bunt+N+SG
# 856.brutalities = brutality+N+PL
# 857.calipers = caliper+N+PL
# 858.dominance = dominance+N+SG
# 859.wanderings = wandering+N+PL
# 860.infestation = infestation+N+SG
# 861.utilities = utility+N+PL
# 862.engrg = engrg+N+SG
# 863.morgue = morgue+N+SG
# 864.subsection = subsection+N+SG
# 865.bandwidth = bandwidth+N+SG
# 866.denomination = denomination+N+SG
# 867.imitations = imitation+N+PL
# 868.crests = crest+N+PL
# 869.commentators = commentator+N+PL
# 870.secant = secant+N+SG
# 871.binding = binding+N+SG
# 872.survivalists = survivalist+N+PL
# 873.accelerometers = accelerometer+N+PL
# 874.granting = granting+N+SG
# 875.dollars = dollar+N+PL
# 876.tappet = tappet+N+SG
# 877.defacing = defacing+N+SG
# 878.eclipses = Invalid Word
# 879.wandering = wandering+N+SG
# 880.reappearance = reappearance+N+SG
# 881.lurch = lurch+N+SG
# 882.rejections = rejection+N+PL
# 883.verdict = verdict+N+SG
# 884.triple = triple+N+SG
# 885.matting = matting+N+SG
# 886.departure = departure+N+SG
# 887.harrumphing = harrumphing+N+SG
# 888.managements = management+N+PL
# 889.dragger = dragger+N+SG
# 890.roughcast = roughcast+N+SG
# 891.soapsuds = soapsud+N+PL
# 892.gossamer = gossamer+N+SG
# 893.railroading = railroading+N+SG
# 894.kingdom = kingdom+N+SG
# 895.party = party+N+SG
# 896.execution = execution+N+SG
# 897.verisimilitude = verisimilitude+N+SG
# 898.adjectives = adjective+N+PL
# 899.blueberry = blueberry+N+SG
# 900.publicists = publicist+N+PL
# 901.pluralism = pluralism+N+SG
# 902.speeds = speed+N+PL
# 903.accesses = access+N+PL
# 904.monochromes = monochrome+N+PL
# 905.disciple = disciple+N+SG
# 906.atomisation = atomisation+N+SG
# 907.dive = dive+N+SG
# 908.lumps = lump+N+PL
# 909.gayety = gayety+N+SG
# 910.paralysis = paralysi+N+PL
# 911.solder = solder+N+SG
# 912.retrovision = retrovision+N+SG
# 913.hillbilly = hillbilly+N+SG
# 914.bedspread = bedspread+N+SG
# 915.underbracing = underbracing+N+SG
# 916.bebop = bebop+N+SG
# 917.academic = academic+N+SG
# 918.enactment = enactment+N+SG
# 919.allurement = allurement+N+SG
# 920.knocks = knock+N+PL
# 921.orthophosphate = orthophosphate+N+SG
# 922.unanimity = unanimity+N+SG
# 923.castles = castle+N+PL
# 924.fetes = fete+N+PL
# 925.allegations = allegation+N+PL
# 926.autocrats = autocrat+N+PL
# 927.exuberance = exuberance+N+SG
# 928.interrogatives = interrogative+N+PL
# 929.shepherds = shepherd+N+PL
# 930.grandparents = grandparent+N+PL
# 931.birch = birch+N+SG
# 932.pastilles = pastille+N+PL
# 933.condenser = condenser+N+SG
# 934.supernaturalism = supernaturalism+N+SG
# 935.potentials = potential+N+PL
# 936.ritiuality = ritiuality+N+SG
# 937.dept. = dept.+N+SG
# 938.abortions = abortion+N+PL
# 939.illustrator = illustrator+N+SG
# 940.retirement = retirement+N+SG
# 941.newsmen = newsmen+N+SG
# 942.censures = censure+N+PL
# 943.surplus = surplu+N+PL
# 944.blower = blower+N+SG
# 945.content = content+N+SG
# 946.drawl = drawl+N+SG
# 947.cock = cock+N+SG
# 948.calendars = calendar+N+PL
# 949.habit = habit+N+SG
# 950.takeing = takeing+N+SG
# 951.vanity = vanity+N+SG
# 952.playwrights = playwright+N+PL
# 953.intermissions = intermission+N+PL
# 954.copies = copy+N+PL
# 955.rehabilitation = rehabilitation+N+SG
# 956.airport = airport+N+SG
# 957.mackintosh = mackintosh+N+SG
# 958.hundreds = hundred+N+PL
# 959.handwriting = handwriting+N+SG
# 960.twilight = twilight+N+SG
# 961.inhibitors = inhibitor+N+PL
# 962.duet = duet+N+SG
# 963.dispatch = dispatch+N+SG
# 964.house = house+N+SG
# 965.senator = senator+N+SG
# 966.velvet = velvet+N+SG
# 967.seedbed = seedbed+N+SG
# 968.melioration = melioration+N+SG
# 969.blasphemies = blasphemy+N+PL
# 970.phs = ph+N+PL
# 971.bandit = bandit+N+SG
# 972.periwinkles = periwinkle+N+PL
# 973.effects = effect+N+PL
# 974.mushrooms = mushroom+N+PL
# 975.improvement = improvement+N+SG
# 976.objects = object+N+PL
# 977.vitamins = vitamin+N+PL
# 978.filets = filet+N+PL
# 979.absenteeism = absenteeism+N+SG
# 980.error = error+N+SG
# 981.ranch = ranch+N+SG
# 982.nighters = nighter+N+PL
# 983.bindle = bindle+N+SG
# 984.skirt = skirt+N+SG
# 985.lbs. = lbs.+N+SG
# 986.agencies = agency+N+PL
# 987.denyin' = denyin'+N+SG
# 988.roses = Invalid Word
# 989.appearances = appearance+N+PL
# 990.newcomers = newcomer+N+PL
# 991.repulsions = repulsion+N+PL
# 992.duets = duet+N+PL
# 993.$2.80 = $2.80+N+SG
# 994.stopper = stopper+N+SG
# 995.hallucinations = hallucination+N+PL
# 996.centimeter = centimeter+N+SG
# 997.retrospect = retrospect+N+SG
# 998.tapes = tape+N+PL
# 999.nose = nose+N+SG
# 1000.watchdog = watchdog+N+SG
# 1001.spreads = spread+N+PL
# 1002.panic = panic+N+SG
# 1003.mistrust = mistrust+N+SG
# 1004.surface = surface+N+SG
# 1005.roundhouse = roundhouse+N+SG
# 1006.respiration = respiration+N+SG
# 1007.miscalculations = miscalculation+N+PL
# 1008.prospects = prospect+N+PL
# 1009.rows = row+N+PL
# 1010.pranks = prank+N+PL
# 1011.planner = planner+N+SG
# 1012.creepers = creeper+N+PL
# 1013.ledgers = ledger+N+PL
# 1014.slides = slide+N+PL
# 1015.technicians = technician+N+PL
# 1016.headboard = headboard+N+SG
# 1017.highlights = highlight+N+PL
# 1018.sec. = sec.+N+SG
# 1019.parsonage = parsonage+N+SG
# 1020.tuc = tuc+N+SG
# 1021.testings = testing+N+PL
# 1022.solo = solo+N+SG
# 1023.tour = tour+N+SG
# 1024.estimates = estimate+N+PL
# 1025.motet = motet+N+SG
# 1026.cowboys = cowboy+N+PL
# 1027.croupier = croupier+N+SG
# 1028.peace = peace+N+SG
# 1029.indium = indium+N+SG
# 1030.pounding = pounding+N+SG
# 1031.prisons = prison+N+PL
# 1032.spacesuits = spacesuit+N+PL
# 1033.actress = Invalid Word
# 1034.geography = geography+N+SG
# 1035.acreage = acreage+N+SG
# 1036.layoffs = layoff+N+PL
# 1037.forearm = forearm+N+SG
# 1038.coach = coach+N+SG
# 1039.fruits = fruit+N+PL
# 1040.platoon = platoon+N+SG
# 1041.rafters = rafter+N+PL
# 1042.helpmate = helpmate+N+SG
# 1043.fiesta = fiesta+N+SG
# 1044.canteen = canteen+N+SG
# 1045.despairing = despairing+N+SG
# 1046.interdependence = interdependence+N+SG
# 1047.excavation = excavation+N+SG
# 1048.$40 = $40+N+SG
# 1049.focus = focu+N+PL
# 1050.booking = booking+N+SG
# 1051.hostler = hostler+N+SG
# 1052.hooves = hoove+N+PL
# 1053.mediocrities = mediocrity+N+PL
# 1054.saga = saga+N+SG
# 1055.synonyms = synonym+N+PL
# 1056.prayers = prayer+N+PL
# 1057.nun = nun+N+SG
# 1058.topcoats = topcoat+N+PL
# 1059.picturing = picturing+N+SG
# 1060.collation = collation+N+SG
# 1061.disregard = disregard+N+SG
# 1062.sedative = sedative+N+SG
# 1063.literatures = literature+N+PL
# 1064.rounds = round+N+PL
# 1065.age = age+N+SG
# 1066.rotations = rotation+N+PL
# 1067.alizarin = alizarin+N+SG
# 1068.bustle = bustle+N+SG
# 1069.pageantry = pageantry+N+SG
# 1070.interpolations = interpolation+N+PL
# 1071.rundown = rundown+N+SG
# 1072.thrombi = thrombi+N+SG
# 1073.industrialist = industrialist+N+SG
# 1074.architects = architect+N+PL
# 1075.snapdragons = snapdragon+N+PL
# 1076.stance = stance+N+SG
# 1077.comparison = comparison+N+SG
# 1078.bulb = bulb+N+SG
# 1079.overnight = overnight+N+SG
# 1080.jalopy = jalopy+N+SG
# 1081.shill = shill+N+SG
# 1082.alternatives = alternative+N+PL
# 1083.rectifier = rectifier+N+SG
# 1084.thruways = thruway+N+PL
# 1085.milieu = milieu+N+SG
# 1086.carryovers = carryover+N+PL
# 1087.intern = intern+N+SG
# 1088.radar = radar+N+SG
# 1089.yeast = yeast+N+SG
# 1090.runways = runway+N+PL
# 1091.limelight = limelight+N+SG
# 1092.expansionist = expansionist+N+SG
# 1093.rights = right+N+PL
# 1094.equalizing = equalizing+N+SG
# 1095.peasanthood = peasanthood+N+SG
# 1096.alleviation = alleviation+N+SG
# 1097.battle = battle+N+SG
# 1098.eyewitness = Invalid Word
# 1099.jolt = jolt+N+SG
# 1100.candies = candy+N+PL
# 1101.p(q) = p(q)+N+SG
# 1102.sandalwood = sandalwood+N+SG
# 1103.technology = technology+N+SG
# 1104.staccato = staccato+N+SG
# 1105.ovation = ovation+N+SG
# 1106.praise = praise+N+SG
# 1107.racketeers = racketeer+N+PL
# 1108.apostle = apostle+N+SG
# 1109.cushions = cushion+N+PL
# 1110.trauma = trauma+N+SG
# 1111.fall = fall+N+SG
# 1112.slaughter = slaughter+N+SG
# 1113.telegrams = telegram+N+PL
# 1114.buses = bus+N+PL
# 1115.denying = denying+N+SG
# 1116.reactionaries = reactionary+N+PL
# 1117.soldiers = soldier+N+PL
# 1118.historians = historian+N+PL
# 1119.educations = education+N+PL
# 1120.$172,000 = $172,000+N+SG
# 1121.manslaughter = manslaughter+N+SG
# 1122.watching = watching+N+SG
# 1123.credit = credit+N+SG
# 1124.spurs = spur+N+PL
# 1125.metrazol = metrazol+N+SG
# 1126.archenemy = archenemy+N+SG
# 1127.severing = severing+N+SG
# 1128.velocities = velocity+N+PL
# 1129.growing = growing+N+SG
# 1130.pars = par+N+PL
# 1131.headwalls = headwall+N+PL
# 1132.bgs = bg+N+PL
# 1133.witch = witch+N+SG
# 1134.manipulations = manipulation+N+PL
# 1135.cannon = cannon+N+SG
# 1136.personages = personage+N+PL
# 1137.supermarkets = supermarket+N+PL
# 1138.diversions = diversion+N+PL
# 1139.deficit = deficit+N+SG
# 1140.possibility = possibility+N+SG
# 1141.christening = christening+N+SG
# 1142.vintner = vintner+N+SG
# 1143.glass = Invalid Word
# 1144.invasion = invasion+N+SG
# 1145.sacrifices = sacrifice+N+PL
# 1146.decorativeness = Invalid Word
# 1147.ballfields = ballfield+N+PL
# 1148.game = game+N+SG
# 1149.scribe = scribe+N+SG
# 1150.photocathode = photocathode+N+SG
# 1151.information = information+N+SG
# 1152.parent = parent+N+SG
# 1153.rift = rift+N+SG
# 1154.body = body+N+SG
# 1155.shag = shag+N+SG
# 1156.apprehensions = apprehension+N+PL
# 1157.immobility = immobility+N+SG
# 1158.liking = liking+N+SG
# 1159.migrants = migrant+N+PL
# 1160.picture = picture+N+SG
# 1161.chuckle = chuckle+N+SG
# 1162.footballs = football+N+PL
# 1163.pantheon = pantheon+N+SG
# 1164.simile = simile+N+SG
# 1165.beatnik = beatnik+N+SG
# 1166.joblot = joblot+N+SG
# 1167.hydroxides = hydroxide+N+PL
# 1168.distillers = distiller+N+PL
# 1169.deed = deed+N+SG
# 1170.wwrl = wwrl+N+SG
# 1171.cloakrooms = cloakroom+N+PL
# 1172.driver = driver+N+SG
# 1173.eyelets = eyelet+N+PL
# 1174.divers = diver+N+PL
# 1175.bibliographies = bibliography+N+PL
# 1176.epigrams = epigram+N+PL
# 1177.subcommittee = subcommittee+N+SG
# 1178.crushers = crusher+N+PL
# 1179.ethic = ethic+N+SG
# 1180.standard = standard+N+SG
# 1181.command = command+N+SG
# 1182.coldness = Invalid Word
# 1183.glint = glint+N+SG
# 1184.tongue = tongue+N+SG
# 1185.biology = biology+N+SG
# 1186.turrets = turret+N+PL
# 1187.distance = distance+N+SG
# 1188.birdie = birdie+N+SG
# 1189.absentia = absentia+N+SG
# 1190.nonreactivity = nonreactivity+N+SG
# 1191.hacksaw = hacksaw+N+SG
# 1192.underwriters = underwriter+N+PL
# 1193.sovereign = sovereign+N+SG
# 1194.protozoa = protozoa+N+SG
# 1195.socialization = socialization+N+SG
# 1196.insides = inside+N+PL
# 1197.soirees = soiree+N+PL
# 1198.peacock = peacock+N+SG
# 1199.mammas = mamma+N+PL
# 1200.implements = implement+N+PL
# 1201.microseconds = microsecond+N+PL
# 1202.stare = stare+N+SG
# 1203.selectors = selector+N+PL
# 1204.crime = crime+N+SG
# 1205.hubbub = hubbub+N+SG
# 1206.skeptics = skeptic+N+PL
# 1207.windmill = windmill+N+SG
# 1208.yard = yard+N+SG
# 1209.tadpoles = tadpole+N+PL
# 1210.rigidity = rigidity+N+SG
# 1211.earphones = earphone+N+PL
# 1212.dogmas = dogma+N+PL
# 1213.simplicity = simplicity+N+SG
# 1214.album = album+N+SG
# 1215.anarchy = anarchy+N+SG
# 1216.rector = rector+N+SG
# 1217.brashness = Invalid Word
# 1218.canisters = canister+N+PL
# 1219.infidelity = infidelity+N+SG
# 1220.broods = brood+N+PL
# 1221.progression = progression+N+SG
# 1222.bulkhead = bulkhead+N+SG
# 1223.turbofan = turbofan+N+SG
# 1224.duration = duration+N+SG
# 1225.plateau = plateau+N+SG
# 1226.coals = coal+N+PL
# 1227.regulator = regulator+N+SG
# 1228.plugugly = plugugly+N+SG
# 1229.juniors = junior+N+PL
# 1230.slate = slate+N+SG
# 1231.scabbard = scabbard+N+SG
# 1232.insulator = insulator+N+SG
# 1233.onlookers = onlooker+N+PL
# 1234.spokesmen = spokesmen+N+SG
# 1235.caravans = caravan+N+PL
# 1236.originals = original+N+PL
# 1237.legato = legato+N+SG
# 1238.dogleg = dogleg+N+SG
# 1239.laments = lament+N+PL
# 1240.farm = farm+N+SG
# 1241.perforations = perforation+N+PL
# 1242.harem = harem+N+SG
# 1243.logistics = logistic+N+PL
# 1244.disapprobation = disapprobation+N+SG
# 1245.gravity = gravity+N+SG
# 1246.butler = butler+N+SG
# 1247.decimals = decimal+N+PL
# 1248.margins = margin+N+PL
# 1249.interviewing = interviewing+N+SG
# 1250.worms = worm+N+PL
# 1251.wheel = wheel+N+SG
# 1252.presentations = presentation+N+PL
# 1253.toothbrush = toothbrush+N+SG
# 1254.deans = dean+N+PL
# 1255.glycols = glycol+N+PL
# 1256.gaps = gap+N+PL
# 1257.mycobacteria = mycobacteria+N+SG
# 1258.possum = possum+N+SG
# 1259.keynotes = keynote+N+PL
# 1260.refrain = refrain+N+SG
# 1261.gymnasts = gymnast+N+PL
# 1262.elite = elite+N+SG
# 1263.thick = thick+N+SG
# 1264.post = post+N+SG
# 1265.centum = centum+N+SG
# 1266.ruse = ruse+N+SG
# 1267.squadron = squadron+N+SG
# 1268.earrings = earring+N+PL
# 1269.mishap = mishap+N+SG
# 1270.drives = drive+N+PL
# 1271.crowbait = crowbait+N+SG
# 1272.$1.80 = $1.80+N+SG
# 1273.effluvium = effluvium+N+SG
# 1274.rehearsal = rehearsal+N+SG
# 1275.leafmold = leafmold+N+SG
# 1276.conversations = conversation+N+PL
# 1277.indignities = Invalid Word
# 1278.poker = poker+N+SG
# 1279.dedication = dedication+N+SG
# 1280.slogan = slogan+N+SG
# 1281.citizenship = citizenship+N+SG
# 1282.gibes = gibe+N+PL
# 1283.redefinition = redefinition+N+SG
# 1284.dyerear = dyerear+N+SG
# 1285.degradation = degradation+N+SG
# 1286.parasite = parasite+N+SG
# 1287.trail = trail+N+SG
# 1288.nagging = nagging+N+SG
# 1289.reviews = review+N+PL
# 1290.hurdle = hurdle+N+SG
# 1291.$7,500,000 = $7,500,000+N+SG
# 1292.grunting = grunting+N+SG
# 1293.pastel = pastel+N+SG
# 1294.$25 = $25+N+SG
# 1295.$90 = $90+N+SG
# 1296.thoughts = thought+N+PL
# 1297.scores = score+N+PL
# 1298.ration = ration+N+SG
# 1299.spume = spume+N+SG
# 1300.stew = stew+N+SG
# 1301.backers = backer+N+PL
# 1302.frills = frill+N+PL
# 1303.touchdowns = touchdown+N+PL
# 1304.cannonball = cannonball+N+SG
# 1305.positivism = positivism+N+SG
# 1306.veto = veto+N+SG
# 1307.stub = stub+N+SG
# 1308.questioners = questioner+N+PL
# 1309.mistress = Invalid Word
# 1310.encounter = encounter+N+SG
# 1311.thermistor = thermistor+N+SG
# 1312.cavalrymen = cavalrymen+N+SG
# 1313.sortie = sortie+N+SG
# 1314.pennants = pennant+N+PL
# 1315.miracle = miracle+N+SG
# 1316.containment = containment+N+SG
# 1317.ringings = ringing+N+PL
# 1318.roommate = roommate+N+SG
# 1319.signs = sign+N+PL
# 1320.$187 = $187+N+SG
# 1321.loneliness = Invalid Word
# 1322.fundamentalist = fundamentalist+N+SG
# 1323.survivor = survivor+N+SG
# 1324.preradiation = preradiation+N+SG
# 1325.baron = baron+N+SG
# 1326.interest = interest+N+SG
# 1327.axes = Invalid Word
# 1328.fielders = fielder+N+PL
# 1329.welcome = welcome+N+SG
# 1330.prevalence = prevalence+N+SG
# 1331.classic = classic+N+SG
# 1332.banishment = banishment+N+SG
# 1333.cord = cord+N+SG
# 1334.5/16'' = 5/16''+N+SG
# 1335.anxieties = anxiety+N+PL
# 1336.beginning = beginning+N+SG
# 1337.electrophorus = electrophoru+N+PL
# 1338.advertising = advertising+N+SG
# 1339.traits = trait+N+PL
# 1340.thinkers = thinker+N+PL
# 1341.rate = rate+N+SG
# 1342.sportsmanship = sportsmanship+N+SG
# 1343.pfennig = pfennig+N+SG
# 1344.consensus = consensu+N+PL
# 1345.misunderstanding = misunderstanding+N+SG
# 1346.ranks = rank+N+PL
# 1347.spades = spade+N+PL
# 1348.tennis = tenni+N+PL
# 1349.chat = chat+N+SG
# 1350.withes = withe+N+PL
# 1351.diaphragm = diaphragm+N+SG
# 1352.hollowware = hollowware+N+SG
# 1353.flush = flush+N+SG
# 1354.career = career+N+SG
# 1355.creature = creature+N+SG
# 1356.retrieval = retrieval+N+SG
# 1357.reflections = reflection+N+PL
# 1358.magnification = magnification+N+SG
# 1359.finalists = finalist+N+PL
# 1360.truths = truth+N+PL
# 1361.bloom = bloom+N+SG
# 1362.trench = trench+N+SG
# 1363.regiments = regiment+N+PL
# 1364.remembrance = remembrance+N+SG
# 1365.science = science+N+SG
# 1366.sigh = sigh+N+SG
# 1367.intima = intima+N+SG
# 1368.decking = decking+N+SG
# 1369.kidneys = kidney+N+PL
# 1370.retardation = retardation+N+SG
# 1371.drdw = drdw+N+SG
# 1372.clock = clock+N+SG
# 1373.impromptu = impromptu+N+SG
# 1374.brawl = brawl+N+SG
# 1375.coachman = coachman+N+SG
# 1376.policies = policy+N+PL
# 1377.stepson = stepson+N+SG
# 1378.athletes = athlete+N+PL
# 1379.plains = plain+N+PL
# 1380.visit = visit+N+SG
# 1381.boarder = boarder+N+SG
# 1382.heiress = Invalid Word
# 1383.wording = wording+N+SG
# 1384.graduation = graduation+N+SG
# 1385.jerks = jerk+N+PL
# 1386.contradiction = contradiction+N+SG
# 1387.unconscious = unconsciou+N+PL
# 1388.scandals = scandal+N+PL
# 1389.funnel = funnel+N+SG
# 1390.stockade = stockade+N+SG
# 1391.puzzler = puzzler+N+SG
# 1392.breakdown = breakdown+N+SG
# 1393.newlywed = newlywed+N+SG
# 1394.shape = shape+N+SG
# 1395.panelization = panelization+N+SG
# 1396.dressing = dressing+N+SG
# 1397.endings = ending+N+PL
# 1398.timetables = timetable+N+PL
# 1399.precincts = precinct+N+PL
# 1400.critic = critic+N+SG
# 1401.delinquents = delinquent+N+PL
# 1402.boundary = boundary+N+SG
# 1403.magnificence = magnificence+N+SG
# 1404.builder = builder+N+SG
# 1405.formulations = formulation+N+PL
# 1406.bivouac = bivouac+N+SG
# 1407.beryllium = beryllium+N+SG
# 1408.mayhem = mayhem+N+SG
# 1409.alumni = alumni+N+SG
# 1410.corticotropin = corticotropin+N+SG
# 1411.chaplain = chaplain+N+SG
# 1412.spandrels = spandrel+N+PL
# 1413.solicitousness = Invalid Word
# 1414.alibi = alibi+N+SG
# 1415.potpourri = potpourri+N+SG
# 1416.mop = mop+N+SG
# 1417.hemlocks = hemlock+N+PL
# 1418.designs = design+N+PL
# 1419.lags = lag+N+PL
# 1420.feuds = feud+N+PL
# 1421.extinction = extinction+N+SG
# 1422.mineralogy = mineralogy+N+SG
# 1423.forgiveness = Invalid Word
# 1424.reprobate = reprobate+N+SG
# 1425.chasing = chasing+N+SG
# 1426.terror = terror+N+SG
# 1427.tolylene = tolylene+N+SG
# 1428.compartment = compartment+N+SG
# 1429.cinder = cinder+N+SG
# 1430.southernisms = southernism+N+PL
# 1431.gallants = gallant+N+PL
# 1432.lamp = lamp+N+SG
# 1433.firearms = firearm+N+PL
# 1434.thumb = thumb+N+SG
# 1435.list = list+N+SG
# 1436.derriere = derriere+N+SG
# 1437.curbside = curbside+N+SG
# 1438.bleachers = bleacher+N+PL
# 1439.cradles = cradle+N+PL
# 1440.priming = priming+N+SG
# 1441.hunts = hunt+N+PL
# 1442.upsurge = upsurge+N+SG
# 1443.zebra = zebra+N+SG
# 1444.markets = market+N+PL
# 1445.buoys = buoy+N+PL
# 1446.infatuation = infatuation+N+SG
# 1447.deae = deae+N+SG
# 1448.primers = primer+N+PL
# 1449.temples = temple+N+PL
# 1450.center = center+N+SG
# 1451.midsummer = midsummer+N+SG
# 1452.exhaust = exhaust+N+SG
# 1453.cartoonist = cartoonist+N+SG
# 1454.nullifiers = nullifier+N+PL
# 1455.folks = folk+N+PL
# 1456.meats = meat+N+PL
# 1457.resonances = resonance+N+PL
# 1458.contents = content+N+PL
# 1459.forma = forma+N+SG
# 1460.chores = chore+N+PL
# 1461.prestidigitator = prestidigitator+N+SG
# 1462.noradrenalin = noradrenalin+N+SG
# 1463.grape = grape+N+SG
# 1464.fountainhead = fountainhead+N+SG
# 1465.creak = creak+N+SG
# 1466.fishmongers = fishmonger+N+PL
# 1467.memorials = memorial+N+PL
# 1468.king = king+N+SG
# 1469.spur = spur+N+SG
# 1470.circumscriptions = circumscription+N+PL
# 1471.scours = scour+N+PL
# 1472.eardrums = eardrum+N+PL
# 1473.flicker = flicker+N+SG
# 1474.subsystem = subsystem+N+SG
# 1475.secessionist = secessionist+N+SG
# 1476.epigraph = epigraph+N+SG
# 1477.aridity = aridity+N+SG
# 1478.serenade = serenade+N+SG
# 1479.brucellosis = brucellosi+N+PL
# 1480.curiosity = curiosity+N+SG
# 1481.boxcar = boxcar+N+SG
# 1482.aku = aku+N+SG
# 1483.breakthrough = breakthrough+N+SG
# 1484.minus = minu+N+PL
# 1485.revellers = reveller+N+PL
# 1486.orgasms = orgasm+N+PL
# 1487.riddle = riddle+N+SG
# 1488.cushioning = cushioning+N+SG
# 1489.motherhood = motherhood+N+SG
# 1490.inaugural = inaugural+N+SG
# 1491.combatants = combatant+N+PL
# 1492.dogs = dog+N+PL
# 1493.ropes = rope+N+PL
# 1494.outskirts = outskirt+N+PL
# 1495.swastika = swastika+N+SG
# 1496.drunkenness = Invalid Word
# 1497.foundations = foundation+N+PL
# 1498.flatiron = flatiron+N+SG
# 1499.shareholders = shareholder+N+PL
# 1500.hogs = hog+N+PL
# 1501.hexagon = hexagon+N+SG
# 1502.salve = salve+N+SG
# 1503.spirituals = spiritual+N+PL
# 1504.handcuffs = handcuff+N+PL
# 1505.shaking = shaking+N+SG
# 1506.fatalities = fatality+N+PL
# 1507.plates = plate+N+PL
# 1508.computations = computation+N+PL
# 1509.dysplasia = dysplasia+N+SG
# 1510.mustache = mustache+N+SG
# 1511.manifold = manifold+N+SG
# 1512.cheer = cheer+N+SG
# 1513.90% = 90%+N+SG
# 1514.suspensions = suspension+N+PL
# 1515.forages = forage+N+PL
# 1516.assessment = assessment+N+SG
# 1517.$457,000 = $457,000+N+SG
# 1518.attainments = attainment+N+PL
# 1519.congruence = congruence+N+SG
# 1520.tactics = tactic+N+PL
# 1521.con = con+N+SG
# 1522.phenonenon = phenonenon+N+SG
# 1523.constables = constable+N+PL
# 1524.$1,800 = $1,800+N+SG
# 1525.shrub = shrub+N+SG
# 1526.choices = choice+N+PL
# 1527.ridge = ridge+N+SG
# 1528.time = time+N+SG
# 1529.landlords = landlord+N+PL
# 1530.impairment = impairment+N+SG
# 1531.magnum = magnum+N+SG
# 1532.adoption = adoption+N+SG
# 1533.estates = estate+N+PL
# 1534.coyotes = coyote+N+PL
# 1535.outlook = outlook+N+SG
# 1536.crayons = crayon+N+PL
# 1537.zero = zero+N+SG
# 1538.lovie = lovie+N+SG
# 1539.frescos = fresco+N+PL
# 1540.heap = heap+N+SG
# 1541.weekend = weekend+N+SG
# 1542.ornament = ornament+N+SG
# 1543.slices = slice+N+PL
# 1544.carrying = carrying+N+SG
# 1545.reservations = reservation+N+PL
# 1546.bulk = bulk+N+SG
# 1547.$7.50 = $7.50+N+SG
# 1548.fixture = fixture+N+SG
# 1549.financing = financing+N+SG
# 1550.mittens = mitten+N+PL
# 1551.accusation = accusation+N+SG
# 1552.jewishness = Invalid Word
# 1553.dinnertime = dinnertime+N+SG
# 1554.nomination = nomination+N+SG
# 1555.equipment = equipment+N+SG
# 1556.ditches = ditch+N+PL
# 1557.ld060 = ld060+N+SG
# 1558.patent = patent+N+SG
# 1559.cuts = cut+N+PL
# 1560.commendation = commendation+N+SG
# 1561.tinkering = tinkering+N+SG
# 1562.maturation = maturation+N+SG
# 1563.participant = participant+N+SG
# 1564.circular = circular+N+SG
# 1565.rides = ride+N+PL
# 1566.thankfulness = Invalid Word
# 1567.thud = thud+N+SG
# 1568.reverence = reverence+N+SG
# 1569.whiz = whiz+N+SG
# 1570.alabaster = alabaster+N+SG
# 1571.wiring = wiring+N+SG
# 1572.outsiders = outsider+N+PL
# 1573.adultery = adultery+N+SG
# 1574.signers = signer+N+PL
# 1575.criteria = criteria+N+SG
# 1576.gestures = gesture+N+PL
# 1577.terrorists = terrorist+N+PL
# 1578.transvestitism = transvestitism+N+SG
# 1579.horsemen = horsemen+N+SG
# 1580.disgrace = disgrace+N+SG
# 1581.schoolwork = schoolwork+N+SG
# 1582.$2,170 = $2,170+N+SG
# 1583.stilts = stilt+N+PL
# 1584.intelligentsia = intelligentsia+N+SG
# 1585.armistice = armistice+N+SG
# 1586.drag = drag+N+SG
# 1587.airs = air+N+PL
# 1588.$46.7 = $46.7+N+SG
# 1589.bind = bind+N+SG
# 1590.mountainside = mountainside+N+SG
# 1591.tissues = tissue+N+PL
# 1592.surprise = surprise+N+SG
# 1593.people = people+N+SG
# 1594.deferment = deferment+N+SG
# 1595.confirmation = confirmation+N+SG
# 1596.detractor = detractor+N+SG
# 1597.tilth = tilth+N+SG
# 1598.zlotys = zloty+N+PL
# 1599.crannies = Invalid Word
# 1600.reconstruction = reconstruction+N+SG
# 1601.annihilation = annihilation+N+SG
# 1602.pistols = pistol+N+PL
# 1603.exponents = exponent+N+PL
# 1604.prowess = Invalid Word
# 1605.divertimento = divertimento+N+SG
# 1606.helplessness = Invalid Word
# 1607.reportage = reportage+N+SG
# 1608.trellises = Invalid Word
# 1609.pores = pore+N+PL
# 1610.linguist = linguist+N+SG
# 1611.monstrosity = monstrosity+N+SG
# 1612.tubs = tub+N+PL
# 1613.fluke = fluke+N+SG
# 1614.gullies = gully+N+PL
# 1615.blocks = block+N+PL
# 1616.ringing = ringing+N+SG
# 1617.$12.1 = $12.1+N+SG
# 1618.equivalence = equivalence+N+SG
# 1619.relish = relish+N+SG
# 1620.inspection = inspection+N+SG
# 1621.crossover = crossover+N+SG
# 1622.social = social+N+SG
# 1623.supranationalism = supranationalism+N+SG
# 1624.sizes = Invalid Word
# 1625.march = march+N+SG
# 1626.pizza = pizza+N+SG
# 1627.amplifiers = amplifier+N+PL
# 1628.friendships = friendship+N+PL
# 1629.pleasure = pleasure+N+SG
# 1630.imaging = imaging+N+SG
# 1631.assailants = assailant+N+PL
# 1632.troupe = troupe+N+SG
# 1633.forties = Invalid Word
# 1634.robbers = robber+N+PL
# 1635.swivel = swivel+N+SG
# 1636.typhoon = typhoon+N+SG
# 1637.butterfat = butterfat+N+SG
# 1638.belfry = belfry+N+SG
# 1639.cheekbone = cheekbone+N+SG
# 1640.volunteer = volunteer+N+SG
# 1641.shells = shell+N+PL
# 1642.twosome = twosome+N+SG
# 1643.$14,000 = $14,000+N+SG
# 1644.pesticides = pesticide+N+PL
# 1645.principals = principal+N+PL
# 1646.aroma = aroma+N+SG
# 1647.intellectuals = intellectual+N+PL
# 1648.reason = reason+N+SG
# 1649.subservience = subservience+N+SG
# 1650.wrongdoer = wrongdoer+N+SG
# 1651.suability = suability+N+SG
# 1652.jar = jar+N+SG
# 1653.epoxy = epoxy+N+SG
# 1654.trolley = trolley+N+SG
# 1655.challenges = challenge+N+PL
# 1656.benzene = benzene+N+SG
# 1657.utility = utility+N+SG
# 1658.founding = founding+N+SG
# 1659.caucuses = caucus+N+PL
# 1660.wetlands = wetland+N+PL
# 1661.ash = ash+N+SG
# 1662.idleness = Invalid Word
# 1663.aspen = aspen+N+SG
# 1664.multiversity = multiversity+N+SG
# 1665.mixtures = mixture+N+PL
# 1666.forge = forge+N+SG
# 1667.patties = Invalid Word
# 1668.gift = gift+N+SG
# 1669.ketchup = ketchup+N+SG
# 1670.equating = equating+N+SG
# 1671.multifigure = multifigure+N+SG
# 1672.scuffle = scuffle+N+SG
# 1673.reds = red+N+PL
# 1674.neuropathology = neuropathology+N+SG
# 1675.similarity = similarity+N+SG
# 1676.instigator = instigator+N+SG
# 1677.kraut = kraut+N+SG
# 1678.nuclei = nuclei+N+SG
# 1679.visitor = visitor+N+SG
# 1680.intercrisis = intercrisi+N+PL
# 1681.buffaloes = buffaloe+N+PL
# 1682.believers = believer+N+PL
# 1683.wages = wage+N+PL
# 1684.urbanism = urbanism+N+SG
# 1685.senators = senator+N+PL
# 1686.sidemen = sidemen+N+SG
# 1687.immediacy = immediacy+N+SG
# 1688.septa = septa+N+SG
# 1689.sitter = sitter+N+SG
# 1690.groping = groping+N+SG
# ...
# 17363.bounce = bounce+N+SG
# 17364.collector = collector+N+SG
# 17365.sonogram = sonogram+N+SG
# 17366.text = text+N+SG
# 17367.hbo = hbo+N+SG
# 17368.glasses = glass+N+PL
# 17369.entomologist = entomologist+N+SG
# 17370.blister = blister+N+SG
# 17371.kelp = kelp+N+SG
# 17372.orthodontics = orthodontic+N+PL
# 17373.stress = Invalid Word
# 17374.strictures = stricture+N+PL
# 17375.squeak = squeak+N+SG
# 17376.suspense = suspense+N+SG
# 17377.doubte = doubte+N+SG
# 17378.eyeful = eyeful+N+SG
# 17379.marts = mart+N+PL
# 17380.lecturer = lecturer+N+SG
# 17381.allegiances = allegiance+N+PL
# 17382.groves = grove+N+PL
# 17383.crown = crown+N+SG
# 17384.phase = phase+N+SG
# 17385.pal = pal+N+SG
# 17386.resolutions = resolution+N+PL
# 17387.historiography = historiography+N+SG
# 17388.obediences = obedience+N+PL
# 17389.ants = ant+N+PL
# 17390.gamebird = gamebird+N+SG
# 17391.longhorn = longhorn+N+SG
# 17392.growth = growth+N+SG
# 17393.footnotes = footnote+N+PL
# 17394.bigots = bigot+N+PL
# 17395.penury = penury+N+SG
# 17396.bakery = bakery+N+SG
# 17397.calluses = Invalid Word
# 17398.infrared = infrared+N+SG
# 17399.copings = coping+N+PL
# 17400.playback = playback+N+SG
# 17401.quotations = quotation+N+PL
# 17402.octopus = octopu+N+PL
# 17403.rage = rage+N+SG
# 17404.overshoes = overshoe+N+PL
# 17405.mrad = mrad+N+SG
# 17406.belch = belch+N+SG
# 17407.ingratitoode = ingratitoode+N+SG
# 17408.grating = grating+N+SG
# 17409.bang = bang+N+SG
# 17410.asses = ass+N+PL
# 17411.interchanges = interchange+N+PL
# 17412.micelle = micelle+N+SG
# 17413.parking = parking+N+SG
# 17414.kenning = kenning+N+SG
# 17415.alternation = alternation+N+SG
# 17416.running = running+N+SG
# 17417.appraisals = appraisal+N+PL
# 17418.strivings = striving+N+PL
# 17419.flint = flint+N+SG
# 17420.**yg = **yg+N+SG
# 17421.accomplishment = accomplishment+N+SG
# 17422.reassurance = reassurance+N+SG
# 17423.civilizations = civilization+N+PL
# 17424.commentator = commentator+N+SG
# 17425.brothers = brother+N+PL
# 17426.diphosphopyridine = diphosphopyridine+N+SG
# 17427.acid = acid+N+SG
# 17428.auditorium = auditorium+N+SG
# 17429.pompousness = Invalid Word
# 17430.shinbone = shinbone+N+SG
# 17431.splinters = splinter+N+PL
# 17432.flowerpot = flowerpot+N+SG
# 17433.calves = calve+N+PL
# 17434.predicator = predicator+N+SG
# 17435.realm = realm+N+SG
# 17436.processes = process+N+PL
# 17437.blockade = blockade+N+SG
# 17438.amplitude = amplitude+N+SG
# 17439.wrongdoing = wrongdoing+N+SG
# 17440.refusal = refusal+N+SG
# 17441.caliper = caliper+N+SG
# 17442.glare = glare+N+SG
# 17443.grub = grub+N+SG
# 17444.battles = battle+N+PL
# 17445.affections = affection+N+PL
# 17446.archfool = archfool+N+SG
# 17447.ignoramus = ignoramu+N+PL
# 17448.interpretations = interpretation+N+PL
# 17449.severalty = severalty+N+SG
# 17450.warrants = warrant+N+PL
# 17451.switching = switching+N+SG
# 17452.statement = statement+N+SG
# 17453.brawle = brawle+N+SG
# 17454.saami's = saami'+N+PL
# 17455.stagnation = stagnation+N+SG
# 17456.$139.3 = $139.3+N+SG
# 17457.contention = contention+N+SG
# 17458.conquest = conquest+N+SG
# 17459.defendant = defendant+N+SG
# 17460.hopes = hope+N+PL
# 17461.miracles = miracle+N+PL
# 17462.epilogue = epilogue+N+SG
# 17463.offense = offense+N+SG
# 17464.ablation = ablation+N+SG
# 17465.orderliness = Invalid Word
# 17466.gig = gig+N+SG
# 17467.rocket = rocket+N+SG
# 17468.sheen = sheen+N+SG
# 17469.spaceship = spaceship+N+SG
# 17470.breakoff = breakoff+N+SG
# 17471.$625,561 = $625,561+N+SG
# 17472.ponds = pond+N+PL
# 17473.vision = vision+N+SG
# 17474.driveways = driveway+N+PL
# 17475.banana = banana+N+SG
# 17476.initials = initial+N+PL
# 17477.whispering = whispering+N+SG
# 17478.ghettos = ghetto+N+PL
# 17479.dissenter = dissenter+N+SG
# 17480.epicycle = epicycle+N+SG
# 17481.porridge = porridge+N+SG
# 17482.trot = trot+N+SG
# 17483.pantheist = pantheist+N+SG
# 17484.axis = axi+N+PL
# 17485.diehards = diehard+N+PL
# 17486.hasher = hasher+N+SG
# 17487.brewers = brewer+N+PL
# 17488.thyroid = thyroid+N+SG
# 17489.adventure = adventure+N+SG
# 17490.$2.98 = $2.98+N+SG
# 17491.boastings = boasting+N+PL
# 17492.forerunner = forerunner+N+SG
# 17493.6'.7 = 6'.7+N+SG
# 17494.lyriist = lyriist+N+SG
# 17495.dissociation = dissociation+N+SG
# 17496.spacers = spacer+N+PL
# 17497.dwellings = dwelling+N+PL
# 17498.qualities = quality+N+PL
# 17499.hut = hut+N+SG
# 17500.stacks = stack+N+PL
# 17501.proposition = proposition+N+SG
# 17502.wax = wax+N+SG
# 17503.profile = profile+N+SG
# 17504.circumstance = circumstance+N+SG
# 17505.suitor = suitor+N+SG
# 17506.prop = prop+N+SG
# 17507.bandits = bandit+N+PL
# 17508.call = call+N+SG
# 17509.respects = respect+N+PL
# 17510.hydraulics = hydraulic+N+PL
# 17511.bouts = bout+N+PL
# 17512.snails = snail+N+PL
# 17513.exacerbations = exacerbation+N+PL
# 17514.nymphomaniac = nymphomaniac+N+SG
# 17515.song = song+N+SG
# 17516.sleeves = sleeve+N+PL
# 17517.knot = knot+N+SG
# 17518.appliances = appliance+N+PL
# 17519.cyclorama = cyclorama+N+SG
# 17520.baking = baking+N+SG
# 17521.girth = girth+N+SG
# 17522.cornbread = cornbread+N+SG
# 17523.schooldays = schoolday+N+PL
# 17524.assemblages = assemblage+N+PL
# 17525.handmaiden = handmaiden+N+SG
# 17526.yelling = yelling+N+SG
# 17527.outbursts = outburst+N+PL
# 17528.absinthe = absinthe+N+SG
# 17529.detours = detour+N+PL
# 17530.ma'am = ma'am+N+SG
# 17531.shackles = shackle+N+PL
# 17532.interludes = interlude+N+PL
# 17533.hearse = hearse+N+SG
# 17534.gauze = gauze+N+SG
# 17535.signatures = signature+N+PL
# 17536.data = data+N+SG
# 17537.parables = parable+N+PL
# 17538.visits = visit+N+PL
# 17539.marketability = marketability+N+SG
# 17540.decorator = decorator+N+SG
# 17541.stiffening = stiffening+N+SG
# 17542.effort = effort+N+SG
# 17543.adjustment = adjustment+N+SG
# 17544.cowman = cowman+N+SG
# 17545.bookkeeping = bookkeeping+N+SG
# 17546.enthusiast = enthusiast+N+SG
# 17547.irritant = irritant+N+SG
# 17548.assignments = assignment+N+PL
# 17549.foraging = foraging+N+SG
# 17550.cavern = cavern+N+SG
# 17551.platoons = platoon+N+PL
# 17552.hydrocarbon = hydrocarbon+N+SG
# 17553.checkbook = checkbook+N+SG
# 17554.inaccuracies = inaccuracy+N+PL
# 17555.fishes = fish+N+PL
# 17556.sketches = sketch+N+PL
# 17557.riddance = riddance+N+SG
# 17558.beams = beam+N+PL
# 17559.extras = extra+N+PL
# 17560.shortsightedness = Invalid Word
# 17561.wetting = wetting+N+SG
# 17562.cribs = crib+N+PL
# 17563.spread = spread+N+SG
# 17564.savior = savior+N+SG
# 17565.workshop = workshop+N+SG
# 17566.phosphorus = phosphoru+N+PL
# 17567.eyesight = eyesight+N+SG
# 17568.excursus = excursu+N+PL
# 17569.scops = scop+N+PL
# 17570.surprises = Invalid Word
# 17571.aorta = aorta+N+SG
# 17572.dagers = dager+N+PL
# 17573.steak = steak+N+SG
# 17574.poison = poison+N+SG
# 17575.irradiation = irradiation+N+SG
# 17576.sprouting = sprouting+N+SG
# 17577.joys = joy+N+PL
# 17578.helicopter = helicopter+N+SG
# 17579.glum = glum+N+SG
# 17580.booster = booster+N+SG
# 17581.employers = employer+N+PL
# 17582.depletion = depletion+N+SG
# 17583.talent = talent+N+SG
# 17584.kisses = kiss+N+PL
# 17585.domesticity = domesticity+N+SG
# 17586.substantiation = substantiation+N+SG
# 17587.superiors = superior+N+PL
# 17588.schoolboy = schoolboy+N+SG
# 17589.fragrance = fragrance+N+SG
# 17590.creep = creep+N+SG
# 17591.depressions = depression+N+PL
# 17592.meaning = meaning+N+SG
# 17593.fingers = finger+N+PL
# 17594.solitary = solitary+N+SG
# 17595.enlightenment = enlightenment+N+SG
# 17596.verve = verve+N+SG
# 17597.quivers = quiver+N+PL
# 17598.point = point+N+SG
# 17599.colonnade = colonnade+N+SG
# 17600.alignments = alignment+N+PL
# 17601.preacher = preacher+N+SG
# 17602.vents = vent+N+PL
# 17603.fraternities = fraternity+N+PL
# 17604.gardens = garden+N+PL
# 17605.hyperplasia = hyperplasia+N+SG
# 17606.throbbing = throbbing+N+SG
# 17607.reduction = reduction+N+SG
# 17608.tolerance = tolerance+N+SG
# 17609.overpopulation = overpopulation+N+SG
# 17610.$10.3 = $10.3+N+SG
# 17611.internationalists = internationalist+N+PL
# 17612.dashes = dash+N+PL
# 17613.sable = sable+N+SG
# 17614.baldness = Invalid Word
# 17615.definitions = definition+N+PL
# 17616.spleen = spleen+N+SG
# 17617.fractions = fraction+N+PL
# 17618.presidents = president+N+PL
# 17619.hostages = hostage+N+PL
# 17620.litigants = litigant+N+PL
# 17621.spat = spat+N+SG
# 17622.fundamentalism = fundamentalism+N+SG
# 17623.therapists = therapist+N+PL
# 17624.avarice = avarice+N+SG
# 17625.trapdoors = trapdoor+N+PL
# 17626.shelter = shelter+N+SG
# 17627.spans = span+N+PL
# 17628.panjandrum = panjandrum+N+SG
# 17629.melancholy = melancholy+N+SG
# 17630.pta = pta+N+SG
# 17631.sforzando = sforzando+N+SG
# 17632.mists = mist+N+PL
# 17633.laborers = laborer+N+PL
# 17634.soda = soda+N+SG
# 17635.cutlass = Invalid Word
# 17636.bone = bone+N+SG
# 17637.trough = trough+N+SG
# 17638.1/2'' = 1/2''+N+SG
# 17639.icc = icc+N+SG
# 17640.huddle = huddle+N+SG
# 17641.plasma = plasma+N+SG
# 17642.scherzo = scherzo+N+SG
# 17643.creaking = creaking+N+SG
# 17644.harm = harm+N+SG
# 17645.relatedness = Invalid Word
# 17646.bluefish = bluefish+N+SG
# 17647.storyteller = storyteller+N+SG
# 17648.purpose = purpose+N+SG
# 17649.neocortex = neocortex+N+SG
# 17650.polynomials = polynomial+N+PL
# 17651.baggage = baggage+N+SG
# 17652.deference = deference+N+SG
# 17653.bale = bale+N+SG
# 17654.tract = tract+N+SG
# 17655.warmth = warmth+N+SG
# 17656.democracy = democracy+N+SG
# 17657.mountain = mountain+N+SG
# 17658.feedings = feeding+N+PL
# 17659.republics = republic+N+PL
# 17660.cathode = cathode+N+SG
# 17661.toast = toast+N+SG
# 17662.mosquitoes = mosquitoe+N+PL
# 17663.scrapings = scraping+N+PL
# 17664.throttle = throttle+N+SG
# 17665.amount = amount+N+SG
# 17666.magnetism = magnetism+N+SG
# 17667.tan = tan+N+SG
# 17668.myth = myth+N+SG
# 17669.chisel = chisel+N+SG
# 17670.treatise = treatise+N+SG
# 17671.indication = indication+N+SG
# 17672.provision = provision+N+SG
# 17673.sheets = sheet+N+PL
# 17674.abbreviations = abbreviation+N+PL
# 17675.townsmen = townsmen+N+SG
# 17676.pagoda = pagoda+N+SG
# 17677.rot = rot+N+SG
# 17678.human = human+N+SG
# 17679.paraoxon = paraoxon+N+SG
# 17680.tumbles = tumble+N+PL
# 17681.states = state+N+PL
# 17682.doubts = doubt+N+PL
# 17683.spokesman = spokesman+N+SG
# 17684.movers = mover+N+PL
# 17685.break = break+N+SG
# 17686.regiment = regiment+N+SG
# 17687.patrolmen = patrolmen+N+SG
# 17688.grades = grade+N+PL
# 17689.clemency = clemency+N+SG
# 17690.penman = penman+N+SG
# 17691.identity = identity+N+SG
# 17692.streetlight = streetlight+N+SG
# 17693.interrelation = interrelation+N+SG
# 17694.snivelings = sniveling+N+PL
# 17695.percentage = percentage+N+SG
# 17696.norad = norad+N+SG
# 17697.washbowl = washbowl+N+SG
# 17698.carbide = carbide+N+SG
# 17699.speculator = speculator+N+SG
# 17700.paratroopers = paratrooper+N+PL
# 17701.expectancy = expectancy+N+SG
# 17702.redwoods = redwood+N+PL
# 17703.tee = tee+N+SG
# 17704.rainstorm = rainstorm+N+SG
# 17705.tenant = tenant+N+SG
# 17706.oblige = oblige+N+SG
# 17707.kiosk = kiosk+N+SG
# 17708.ague = ague+N+SG
# 17709.scrape = scrape+N+SG
# 17710.foreknowledge = foreknowledge+N+SG
# 17711.amorist = amorist+N+SG
# 17712.extruder = extruder+N+SG
# 17713.practitioners = practitioner+N+PL
# 17714.longevity = longevity+N+SG
# 17715.aviary = aviary+N+SG
# 17716.barn = barn+N+SG
# 17717.diagnosticians = diagnostician+N+PL
# 17718.production = production+N+SG
# 17719.enclaves = enclave+N+PL
# 17720.millennia = millennia+N+SG
# 17721.boast = boast+N+SG
# 17722.tally = tally+N+SG
# 17723.konga = konga+N+SG
# 17724.greensward = greensward+N+SG
# 17725.bodyguard = bodyguard+N+SG
# 17726.showmen = showmen+N+SG
# 17727.sum = sum+N+SG
# 17728.externalization = externalization+N+SG
# 17729.reharmonization = reharmonization+N+SG
# 17730.progeny = progeny+N+SG
# 17731.lieder = lieder+N+SG
# 17732.dryness = Invalid Word
# 17733.fertility = fertility+N+SG
# 17734.sonny = sonny+N+SG
# 17735.disrepute = disrepute+N+SG
# 17736.intelligence = intelligence+N+SG
# 17737.$85 = $85+N+SG
# 17738.technicalities = Invalid Word
# 17739.starvation = starvation+N+SG
# 17740.houseboats = houseboat+N+PL
# 17741.concerts = concert+N+PL
# 17742.convulsions = convulsion+N+PL
# 17743.nutrition = nutrition+N+SG
# 17744.troubie = troubie+N+SG
# 17745.uptrend = uptrend+N+SG
# 17746.breakaway = breakaway+N+SG
# 17747.bayonets = bayonet+N+PL
# 17748.holdups = holdup+N+PL
# 17749.disbelief = disbelief+N+SG
# 17750.veils = veil+N+PL
# 17751.sari = sari+N+SG
# 17752.stockbroker = stockbroker+N+SG
# 17753.graces = grace+N+PL
# 17754.subsections = subsection+N+PL
# 17755.phosphates = phosphate+N+PL
# 17756.telephone = telephone+N+SG
# 17757.baskets = basket+N+PL
# 17758.sound = sound+N+SG
# 17759.bogeys = bogey+N+PL
# 17760.capitulation = capitulation+N+SG
# 17761.academeh = academeh+N+SG
# 17762.shoelaces = shoelace+N+PL
# 17763.parishioners = parishioner+N+PL
# 17764.procreativity = procreativity+N+SG
# 17765.reformism = reformism+N+SG
# 17766.bellwethers = bellwether+N+PL
# 17767.2.295% = 2.295%+N+SG
# 17768.0.85% = 0.85%+N+SG
# 17769.sprinkle = sprinkle+N+SG
# 17770.couples = couple+N+PL
# 17771.undoing = undoing+N+SG
# 17772.blooming = blooming+N+SG
# 17773.mispronunciation = mispronunciation+N+SG
# 17774.singers = singer+N+PL
# 17775.thug = thug+N+SG
# 17776.mantlepiece = mantlepiece+N+SG
# 17777.padding = padding+N+SG
# 17778.run = run+N+SG
# 17779.enthusiasts = enthusiast+N+PL
# 17780.errand = errand+N+SG
# 17781.makers = maker+N+PL
# 17782.gaucheries = Invalid Word
# 17783.madrigal = madrigal+N+SG
# 17784.gallery = gallery+N+SG
# 17785.forearms = forearm+N+PL
# 17786.saying = saying+N+SG
# 17787.nrlda's = nrlda'+N+PL
# 17788.blow = blow+N+SG
# 17789.scan = scan+N+SG
# 17790.cheek = cheek+N+SG
# 17791.birth = birth+N+SG
# 17792.seaside = seaside+N+SG
# 17793.$12,500 = $12,500+N+SG
# 17794.$157,460 = $157,460+N+SG
# 17795.helper = helper+N+SG
# 17796.procreation = procreation+N+SG
# 17797.tales = tale+N+PL
# 17798.inlet = inlet+N+SG
# 17799.cityscapes = cityscape+N+PL
# 17800.baying = baying+N+SG
# 17801.stickpin = stickpin+N+SG
# 17802.quadrupling = quadrupling+N+SG
# 17803.intrigue = intrigue+N+SG
# 17804.tonalities = Invalid Word
# 17805.notebook = notebook+N+SG
# 17806.microphone = microphone+N+SG
# 17807.railroader = railroader+N+SG
# 17808.$75,000,000 = $75,000,000+N+SG
# 17809.prey = prey+N+SG
# 17810.politico = politico+N+SG
# 17811.representations = representation+N+PL
# 17812.artisans = artisan+N+PL
# 17813.authors = author+N+PL
# 17814.inventions = invention+N+PL
# 17815.hande = hande+N+SG
# 17816.complexities = complexity+N+PL
# 17817.alcohols = alcohol+N+PL
# 17818.$2,300 = $2,300+N+SG
# 17819.arteriolosclerosis = arteriolosclerosi+N+PL
# 17820.monitor = monitor+N+SG
# 17821.antithesis = antithesi+N+PL
# 17822.boomerang = boomerang+N+SG
# 17823.patients = patient+N+PL
# 17824.parisology = parisology+N+SG
# 17825.climate = climate+N+SG
# 17826.86% = 86%+N+SG
# 17827.$14.00 = $14.00+N+SG
# 17828.tangency = tangency+N+SG
# 17829.colony = colony+N+SG
# 17830.fella = fella+N+SG
# 17831.ire = ire+N+SG
# 17832.nugget = nugget+N+SG
# 17833.cottages = cottage+N+PL
# 17834.background = background+N+SG
# 17835.dowel = dowel+N+SG
# 17836.siege = siege+N+SG
# 17837.47.1% = 47.1%+N+SG
# 17838.geology = geology+N+SG
# 17839.courtier = courtier+N+SG
# 17840.desirability = desirability+N+SG
# 17841.consideration = consideration+N+SG
# 17842.green = green+N+SG
# 17843.aryl = aryl+N+SG
# 17844.hint = hint+N+SG
# 17845.polish = polish+N+SG
# 17846.bag = bag+N+SG
# 17847.fooling = fooling+N+SG
# 17848.troubles = trouble+N+PL
# 17849.charcoal = charcoal+N+SG
# 17850.sites = site+N+PL
# 17851.dynamite = dynamite+N+SG
# 17852.syrup = syrup+N+SG
# 17853.kitchens = kitchen+N+PL
# 17854.cumara = cumara+N+SG
# 17855.aloofness = Invalid Word
# 17856.arsines = arsine+N+PL
# 17857.restaurants = restaurant+N+PL
# 17858.charity = charity+N+SG
# 17859.library = library+N+SG
# 17860.consultations = consultation+N+PL
# 17861.auto = auto+N+SG
# 17862.prolixity = prolixity+N+SG
# 17863.enforcement = enforcement+N+SG
# 17864.gut = gut+N+SG
# 17865.millimeter = millimeter+N+SG
# 17866.sight = sight+N+SG
# 17867.warranty = warranty+N+SG
# 17868.interregnum = interregnum+N+SG
# 17869.composition = composition+N+SG
# 17870.ring = ring+N+SG
# 17871.bailiff = bailiff+N+SG
# 17872.sportswriter = sportswriter+N+SG
# 17873.nurture = nurture+N+SG
# 17874.invoices = invoice+N+PL
# 17875.laudanum = laudanum+N+SG
# 17876.spirit = spirit+N+SG
# 17877.furs = fur+N+PL
# 17878.average = average+N+SG
# 17879.embassies = embassy+N+PL
# 17880.airports = airport+N+PL
# 17881.ooh = ooh+N+SG
# 17882.vacations = vacation+N+PL
# 17883.comings = coming+N+PL
# 17884.rasp = rasp+N+SG
# 17885.punditry = punditry+N+SG
# 17886.$15,000 = $15,000+N+SG
# 17887.singularity = singularity+N+SG
# 17888.rehearsals = rehearsal+N+PL
# 17889.socialist = socialist+N+SG
# 17890.sequins = sequin+N+PL
# 17891.gangland = gangland+N+SG
# 17892.homesteads = homestead+N+PL

# %%
# Define input and output alphabets
input_alphabet = set("abcdefghijklmnopqrstuvwxyz")
output_alphabet = input_alphabet.union({"+N+SG", "+N+PL"})

# Define states
states = {
    "START",       # start reading the word
    "STEM",        # reading root letters
    "END_S",       # possible plural S
    "END_ES",      # plural ES
    "END_IES",     # plural IES
    "FINAL_SG",    # singular accept state
    "FINAL_PL"     # plural accept state
}
start_state = "START"
final_states = {"FINAL_SG", "FINAL_PL"}

# Define transitions: (state, input) -> (next_state, output)
transitions = {}

# Generic letter reading (build stem)
for ch in input_alphabet:
    transitions[("START", ch)] = ("STEM", ch)
    transitions[("STEM", ch)] = ("STEM", ch)

# Rule 1: E insertion after -s, -z, -x, -ch, -sh before adding "es"
# We'll detect these endings in the FST
special_es_endings = ["s", "z", "x"]
special_es_pairs = ["ch", "sh"]

# Rule 2: Y replacement (consonant + y → ies)
# Will handle in code logic (needs context: prev char consonant)

# Rule 3: S addition (default plural rule)

def run_fst(word):
    # First, handle plural vs singular classification manually
    if word in input_alphabet:
        return "Invalid Word"  # too short

    # Singular case: if it's in our noun list and no plural ending
    if not (word.endswith("s") or word.endswith("es") or word.endswith("ies")):
        return f"{word}+N+SG"

    # Plural cases:
    # Case 1: Ends with 'ies' → Y replacement
    if word.endswith("ies") and len(word) > 3:
        stem = word[:-3] + "y"
        # Ensure before 'y' is a consonant
        if stem[-2] not in "aeiou":
            return f"{stem}+N+PL"
        else:
            return "Invalid Word"

    # Case 2: Ends with 'es' and matches E-insertion rule
    if word.endswith("es"):
        stem = word[:-2]
        if any(stem.endswith(e) for e in special_es_endings) or any(stem.endswith(e) for e in special_es_pairs):
            return f"{stem}+N+PL"
        

    # Case 3: Ends with 's' → default plural
    if word.endswith("s"):
        stem = word[:-1]
        # reject if stem should have had 'es'
        if any(stem.endswith(e) for e in special_es_endings) or any(stem.endswith(e) for e in special_es_pairs):
            return "Invalid Word"
        # reject if stem should have had 'ies'
        if stem.endswith("y") and stem[-2] not in "aeiou":
            return "Invalid Word"
        return f"{stem}+N+PL"

    return "Invalid Word"



lexicon = set()    #unordered
if os.path.exists("brown_nouns.txt"):
    with open("brown_nouns.txt", "r") as f:
        lexicon = {line.strip().lower() for line in f if line.strip()}
 
print('Total words: ',len(lexicon),'\n')
for i,w in enumerate(lexicon):
    print(f"{i+1}. {w} -> {run_fst(w)}")

#print(f"associates-> {run_fst('associates')}")
# Out:
# Total words:  17892
#
# 1. landing -> landing+N+SG
# 2. optics -> optic+N+PL
# 3. scrim -> scrim+N+SG
# 4. associates -> associate+N+PL
# 5. similarities -> similarity+N+PL
# 6. video -> video+N+SG
# 7. bluebush -> bluebush+N+SG
# 8. stretcher -> stretcher+N+SG
# 9. alteration -> alteration+N+SG
# 10. swallows -> swallow+N+PL
# 11. grubs -> grub+N+PL
# 12. downs -> down+N+PL
# 13. ucla -> ucla+N+SG
# 14. groundwork -> groundwork+N+SG
# 15. bobby -> bobby+N+SG
# 16. shit -> shit+N+SG
# 17. horsepower -> horsepower+N+SG
# 18. ducks -> duck+N+PL
# 19. stampede -> stampede+N+SG
# 20. bromphenol -> bromphenol+N+SG
# 21. fruit -> fruit+N+SG
# 22. remark -> remark+N+SG
# 23. delusion -> delusion+N+SG
# 24. esters -> ester+N+PL
# 25. electrolysis -> electrolysi+N+PL
# 26. slowness -> Invalid Word
# 27. shrubbery -> shrubbery+N+SG
# 28. evangelists -> evangelist+N+PL
# 29. threads -> thread+N+PL
# 30. favors -> favor+N+PL
# 31. doorkeeper -> doorkeeper+N+SG
# 32. roar -> roar+N+SG
# 33. bus -> bu+N+PL
# 34. check -> check+N+SG
# 35. acquisitions -> acquisition+N+PL
# 36. staff -> staff+N+SG
# 37. bun -> bun+N+SG
# 38. head -> head+N+SG
# 39. attentions -> attention+N+PL
# 40. prairie -> prairie+N+SG
# 41. thousands -> thousand+N+PL
# 42. glen -> glen+N+SG
# 43. phonetics -> phonetic+N+PL
# 44. bloat -> bloat+N+SG
# 45. standby -> standby+N+SG
# 46. subspace -> subspace+N+SG
# 47. walks -> walk+N+PL
# 48. snuffer -> snuffer+N+SG
# 49. chaperon -> chaperon+N+SG
# 50. swim -> swim+N+SG
# 51. depression -> depression+N+SG
# 52. cane -> cane+N+SG
# 53. breakwater -> breakwater+N+SG
# 54. omelet -> omelet+N+SG
# 55. optimum -> optimum+N+SG
# 56. reproduction -> reproduction+N+SG
# 57. shipmates -> shipmate+N+PL
# 58. liabilities -> liability+N+PL
# 59. curettage -> curettage+N+SG
# 60. sensation -> sensation+N+SG
# 61. aspiration -> aspiration+N+SG
# 62. hail -> hail+N+SG
# 63. grudges -> grudge+N+PL
# 64. guiftes -> guifte+N+PL
# 65. foreigners -> foreigner+N+PL
# 66. provisons -> provison+N+PL
# 67. demagnification -> demagnification+N+SG
# 68. seeds -> seed+N+PL
# 69. niece -> niece+N+SG
# 70. pothole -> pothole+N+SG
# 71. black -> black+N+SG
# 72. transferral -> transferral+N+SG
# 73. modifications -> modification+N+PL
# 74. assault -> assault+N+SG
# 75. ads -> ad+N+PL
# 76. sheaf -> sheaf+N+SG
# 77. calypso -> calypso+N+SG
# 78. catcher -> catcher+N+SG
# 79. bypass -> Invalid Word
# 80. improviser -> improviser+N+SG
# 81. rainbow -> rainbow+N+SG
# 82. inns -> inn+N+PL
# 83. gargle -> gargle+N+SG
# 84. trestles -> trestle+N+PL
# 85. leaflet -> leaflet+N+SG
# 86. valley -> valley+N+SG
# 87. overseas -> oversea+N+PL
# 88. leg -> leg+N+SG
# 89. steps -> step+N+PL
# 90. catkin -> catkin+N+SG
# 91. monopolists -> monopolist+N+PL
# 92. craters -> crater+N+PL
# 93. freak -> freak+N+SG
# 94. oranges -> orange+N+PL
# 95. frogs -> frog+N+PL
# 96. connexion -> connexion+N+SG
# 97. roasts -> roast+N+PL
# 98. incomprehension -> incomprehension+N+SG
# 99. enigma -> enigma+N+SG
# 100. lionesses -> lioness+N+PL
# 101. ibm -> ibm+N+SG
# 102. patterns -> pattern+N+PL
# 103. craze -> craze+N+SG
# 104. peaches -> peach+N+PL
# 105. saliva -> saliva+N+SG
# 106. teen -> teen+N+SG
# 107. solidity -> solidity+N+SG
# 108. attributes -> attribute+N+PL
# 109. islands -> island+N+PL
# 110. shavings -> shaving+N+PL
# 111. airmen -> airmen+N+SG
# 112. memorial -> memorial+N+SG
# 113. parsley -> parsley+N+SG
# 114. comedies -> comedy+N+PL
# 115. distiller -> distiller+N+SG
# 116. indoctrinating -> indoctrinating+N+SG
# 117. rake -> rake+N+SG
# 118. debating -> debating+N+SG
# 119. wagons -> wagon+N+PL
# 120. goose -> goose+N+SG
# 121. redcoats -> redcoat+N+PL
# 122. expansiveness -> Invalid Word
# 123. sinking -> sinking+N+SG
# 124. name -> name+N+SG
# 125. grace -> grace+N+SG
# 126. rich -> rich+N+SG
# 127. lubrication -> lubrication+N+SG
# 128. exacerbation -> exacerbation+N+SG
# 129. epitome -> epitome+N+SG
# 130. anisotropy -> anisotropy+N+SG
# 131. power -> power+N+SG
# 132. chiefdoms -> chiefdom+N+PL
# 133. coaching -> coaching+N+SG
# 134. $.027 -> $.027+N+SG
# 135. diocs -> dioc+N+PL
# 136. litters -> litter+N+PL
# 137. noise -> noise+N+SG
# 138. offersey -> offersey+N+SG
# 139. captures -> capture+N+PL
# 140. curriculum -> curriculum+N+SG
# 141. mysteries -> mystery+N+PL
# 142. chute -> chute+N+SG
# 143. reference -> reference+N+SG
# 144. apartment -> apartment+N+SG
# 145. 9/32'' -> 9/32''+N+SG
# 146. **b -> **b+N+SG
# 147. 'thirties -> 'thirty+N+PL
# 148. sweetness -> Invalid Word
# 149. glover -> glover+N+SG
# 150. intent -> intent+N+SG
# 151. least -> least+N+SG
# 152. curls -> curl+N+PL
# 153. thong -> thong+N+SG
# 154. blushes -> blush+N+PL
# 155. sewer -> sewer+N+SG
# 156. boatload -> boatload+N+SG
# 157. vocalization -> vocalization+N+SG
# 158. promoter -> promoter+N+SG
# 159. switchboard -> switchboard+N+SG
# 160. nester -> nester+N+SG
# 161. races -> race+N+PL
# 162. pistoleers -> pistoleer+N+PL
# 163. sea -> sea+N+SG
# 164. gage -> gage+N+SG
# 165. 48'' -> 48''+N+SG
# 166. waves -> wave+N+PL
# 167. speedometer -> speedometer+N+SG
# 168. radiation -> radiation+N+SG
# 169. tithes -> tithe+N+PL
# 170. dancer -> dancer+N+SG
# 171. ladder -> ladder+N+SG
# 172. wars -> war+N+PL
# 173. obviousness -> Invalid Word
# 174. deathbed -> deathbed+N+SG
# 175. wells -> well+N+PL
# 176. antagonist -> antagonist+N+SG
# 177. carriers -> carrier+N+PL
# 178. insulin -> insulin+N+SG
# 179. school -> school+N+SG
# 180. highpoint -> highpoint+N+SG
# 181. grapevines -> grapevine+N+PL
# 182. algorithm -> algorithm+N+SG
# 183. botany -> botany+N+SG
# 184. tumbrels -> tumbrel+N+PL
# 185. burglary -> burglary+N+SG
# 186. provocation -> provocation+N+SG
# 187. underwriting -> underwriting+N+SG
# 188. magnums -> magnum+N+PL
# 189. paratroops -> paratroop+N+PL
# 190. licensing -> licensing+N+SG
# 191. hills -> hill+N+PL
# 192. doldrums -> doldrum+N+PL
# 193. writs -> writ+N+PL
# 194. obligations -> obligation+N+PL
# 195. metamorphosis -> metamorphosi+N+PL
# 196. breakers -> breaker+N+PL
# 197. infraction -> infraction+N+SG
# 198. line -> line+N+SG
# 199. abaringe -> abaringe+N+SG
# 200. sneak -> sneak+N+SG
# 201. $11.50 -> $11.50+N+SG
# 202. intuitions -> intuition+N+PL
# 203. restaurateur -> restaurateur+N+SG
# 204. necessities -> necessity+N+PL
# 205. mantrap -> mantrap+N+SG
# 206. caramel -> caramel+N+SG
# 207. crudities -> crudity+N+PL
# 208. workmen -> workmen+N+SG
# 209. guard -> guard+N+SG
# 210. 13% -> 13%+N+SG
# 211. $.12 -> $.12+N+SG
# 212. enjoyment -> enjoyment+N+SG
# 213. tannin -> tannin+N+SG
# 214. bulletins -> bulletin+N+PL
# 215. pool -> pool+N+SG
# 216. rosebuds -> rosebud+N+PL
# 217. poppies -> poppy+N+PL
# 218. geldings -> gelding+N+PL
# 219. burrow -> burrow+N+SG
# 220. sojourners -> sojourner+N+PL
# 221. rotor -> rotor+N+SG
# 222. funerals -> funeral+N+PL
# 223. raincoats -> raincoat+N+PL
# 224. substitute -> substitute+N+SG
# 225. food -> food+N+SG
# 226. wristwatch -> wristwatch+N+SG
# 227. descriptions -> description+N+PL
# 228. listing -> listing+N+SG
# 229. planeload -> planeload+N+SG
# 230. learning -> learning+N+SG
# 231. stumpage -> stumpage+N+SG
# 232. smear -> smear+N+SG
# 233. stake -> stake+N+SG
# 234. regard -> regard+N+SG
# 235. rigger -> rigger+N+SG
# 236. frangipani -> frangipani+N+SG
# 237. aggregation -> aggregation+N+SG
# 238. motorscooters -> motorscooter+N+PL
# 239. candidacy -> candidacy+N+SG
# 240. stronghold -> stronghold+N+SG
# 241. repeater -> repeater+N+SG
# 242. cavemen -> cavemen+N+SG
# 243. $.054/mbf -> $.054/mbf+N+SG
# 244. midday -> midday+N+SG
# 245. avail -> avail+N+SG
# 246. patient -> patient+N+SG
# 247. drums -> drum+N+PL
# 248. shield -> shield+N+SG
# 249. intolerance -> intolerance+N+SG
# 250. sternum -> sternum+N+SG
# 251. plagiarism -> plagiarism+N+SG
# 252. killers -> killer+N+PL
# 253. gentian -> gentian+N+SG
# 254. carbon -> carbon+N+SG
# 255. $70 -> $70+N+SG
# 256. fresco -> fresco+N+SG
# 257. $2,000,000 -> $2,000,000+N+SG
# 258. height -> height+N+SG
# 259. bull -> bull+N+SG
# 260. ica's -> ica'+N+PL
# 261. gauss -> Invalid Word
# 262. exchanges -> exchange+N+PL
# 263. theses -> thes+N+PL
# 264. bathroom -> bathroom+N+SG
# 265. misstep -> misstep+N+SG
# 266. $5,000 -> $5,000+N+SG
# 267. radios -> radio+N+PL
# 268. objective -> objective+N+SG
# 269. intransigents -> intransigent+N+PL
# 270. hosses -> hoss+N+PL
# 271. recording -> recording+N+SG
# 272. qualms -> qualm+N+PL
# 273. convexity -> convexity+N+SG
# 274. prophecy -> prophecy+N+SG
# 275. xxxx -> xxxx+N+SG
# 276. peg -> peg+N+SG
# 277. defeat -> defeat+N+SG
# 278. soviet -> soviet+N+SG
# 279. greetings -> greeting+N+PL
# 280. redheads -> redhead+N+PL
# 281. nucleotide -> nucleotide+N+SG
# 282. schoolchildren -> schoolchildren+N+SG
# 283. pocket -> pocket+N+SG
# 284. flood -> flood+N+SG
# 285. immersion -> immersion+N+SG
# 286. qualifications -> qualification+N+PL
# 287. pacifier -> pacifier+N+SG
# 288. pavilions -> pavilion+N+PL
# 289. teacher -> teacher+N+SG
# 290. stationmaster -> stationmaster+N+SG
# 291. ecliptic -> ecliptic+N+SG
# 292. dualism -> dualism+N+SG
# 293. acquisitiveness -> Invalid Word
# 294. unrealism -> unrealism+N+SG
# 295. jumper -> jumper+N+SG
# 296. stallion -> stallion+N+SG
# 297. fennel -> fennel+N+SG
# 298. champs -> champ+N+PL
# 299. backs -> back+N+PL
# 300. 7/16'' -> 7/16''+N+SG
# 301. brokers -> broker+N+PL
# 302. sham -> sham+N+SG
# 303. chum -> chum+N+SG
# 304. fireman -> fireman+N+SG
# 305. naivete -> naivete+N+SG
# 306. mixing -> mixing+N+SG
# 307. isolation -> isolation+N+SG
# 308. entry -> entry+N+SG
# 309. swell -> swell+N+SG
# 310. snapping -> snapping+N+SG
# 311. mungus -> mungu+N+PL
# 312. sideboards -> sideboard+N+PL
# 313. sharks -> shark+N+PL
# 314. triplication -> triplication+N+SG
# 315. royalties -> royalty+N+PL
# 316. orthography -> orthography+N+SG
# 317. tenure -> tenure+N+SG
# 318. domain -> domain+N+SG
# 319. continuities -> continuity+N+PL
# 320. remorse -> remorse+N+SG
# 321. galls -> gall+N+PL
# 322. mistake -> mistake+N+SG
# 323. hayfields -> hayfield+N+PL
# 324. typewriter -> typewriter+N+SG
# 325. claps -> clap+N+PL
# 326. droves -> drove+N+PL
# 327. homesickness -> Invalid Word
# 328. cornerstone -> cornerstone+N+SG
# 329. curtain -> curtain+N+SG
# 330. barflies -> barfly+N+PL
# 331. coaches -> coach+N+PL
# 332. gatherings -> gathering+N+PL
# 333. quarts -> quart+N+PL
# 334. wires -> wire+N+PL
# 335. view -> view+N+SG
# 336. judge -> judge+N+SG
# 337. impunity -> impunity+N+SG
# 338. gapt -> gapt+N+SG
# 339. diagonals -> diagonal+N+PL
# 340. 12a -> 12a+N+SG
# 341. clinches -> clinch+N+PL
# 342. train -> train+N+SG
# 343. theaters -> theater+N+PL
# 344. herpetology -> herpetology+N+SG
# 345. burglars -> burglar+N+PL
# 346. coriander -> coriander+N+SG
# 347. qualification -> qualification+N+SG
# 348. pins -> pin+N+PL
# 349. matrix -> matrix+N+SG
# 350. clarinet -> clarinet+N+SG
# 351. narrator -> narrator+N+SG
# 352. salads -> salad+N+PL
# 353. inceptor -> inceptor+N+SG
# 354. faculties -> faculty+N+PL
# 355. sums -> sum+N+PL
# 356. clown -> clown+N+SG
# 357. bounty -> bounty+N+SG
# 358. premiere -> premiere+N+SG
# 359. umbrellas -> umbrella+N+PL
# 360. uptake -> uptake+N+SG
# 361. validation -> validation+N+SG
# 362. promises -> promis+N+PL
# 363. decompression -> decompression+N+SG
# 364. salutation -> salutation+N+SG
# 365. deliberation -> deliberation+N+SG
# 366. $22 -> $22+N+SG
# 367. vendors -> vendor+N+PL
# 368. commando -> commando+N+SG
# 369. eclipse -> eclipse+N+SG
# 370. anaesthesia -> anaesthesia+N+SG
# 371. necktie -> necktie+N+SG
# 372. exertions -> exertion+N+PL
# 373. booth -> booth+N+SG
# 374. situs -> situ+N+PL
# 375. fibrin -> fibrin+N+SG
# 376. corridors -> corridor+N+PL
# 377. exaltation -> exaltation+N+SG
# 378. accordance -> accordance+N+SG
# 379. concessionaire -> concessionaire+N+SG
# 380. troupes -> troupe+N+PL
# 381. tailin' -> tailin'+N+SG
# 382. searching -> searching+N+SG
# 383. blackboard -> blackboard+N+SG
# 384. duplication -> duplication+N+SG
# 385. ton -> ton+N+SG
# 386. buffer -> buffer+N+SG
# 387. rack -> rack+N+SG
# 388. steamboat -> steamboat+N+SG
# 389. cumin -> cumin+N+SG
# 390. combination -> combination+N+SG
# 391. forcefulness -> Invalid Word
# 392. renderings -> rendering+N+PL
# 393. fee -> fee+N+SG
# 394. kitchen -> kitchen+N+SG
# 395. cheetah -> cheetah+N+SG
# 396. myofibrils -> myofibril+N+PL
# 397. patroness -> Invalid Word
# 398. arylesterase -> arylesterase+N+SG
# 399. thiihng -> thiihng+N+SG
# 400. directivity -> directivity+N+SG
# 401. tourist -> tourist+N+SG
# 402. phenothiazine -> phenothiazine+N+SG
# 403. amanuensis -> amanuensi+N+PL
# 404. hallelujahs -> hallelujah+N+PL
# 405. barbell -> barbell+N+SG
# 406. industralization -> industralization+N+SG
# 407. vaudeville -> vaudeville+N+SG
# 408. hour -> hour+N+SG
# 409. sovereigns -> sovereign+N+PL
# 410. cuk**ya -> cuk**ya+N+SG
# 411. trains -> train+N+PL
# 412. kob -> kob+N+SG
# 413. disputes -> dispute+N+PL
# 414. hairpin -> hairpin+N+SG
# 415. meditation -> meditation+N+SG
# 416. negligence -> negligence+N+SG
# 417. remains -> remain+N+PL
# 418. hasps -> hasp+N+PL
# 419. founders -> founder+N+PL
# 420. bateau -> bateau+N+SG
# 421. clothesbrush -> clothesbrush+N+SG
# 422. replication -> replication+N+SG
# 423. glamour -> glamour+N+SG
# 424. philosophers -> philosopher+N+PL
# 425. panoramas -> panorama+N+PL
# 426. speedboat -> speedboat+N+SG
# 427. furnace -> furnace+N+SG
# 428. veldt -> veldt+N+SG
# 429. troopships -> troopship+N+PL
# 430. opus -> opu+N+PL
# 431. cutback -> cutback+N+SG
# 432. hangovers -> hangover+N+PL
# 433. snapback -> snapback+N+SG
# 434. muscles -> muscle+N+PL
# 435. tart -> tart+N+SG
# 436. discourse -> discourse+N+SG
# 437. filagree -> filagree+N+SG
# 438. duck -> duck+N+SG
# 439. turmoil -> turmoil+N+SG
# 440. eies -> Invalid Word
# 441. gamut -> gamut+N+SG
# 442. blowfish -> blowfish+N+SG
# 443. airplanes -> airplane+N+PL
# 444. insignificances -> insignificance+N+PL
# 445. turntable -> turntable+N+SG
# 446. subways -> subway+N+PL
# 447. ship -> ship+N+SG
# 448. seedlings -> seedling+N+PL
# 449. masseur -> masseur+N+SG
# 450. code,dtf -> code,dtf+N+SG
# 451. trucks -> truck+N+PL
# 452. frog -> frog+N+SG
# 453. tip -> tip+N+SG
# 454. outcasts -> outcast+N+PL
# 455. character -> character+N+SG
# 456. misery -> misery+N+SG
# 457. nullity -> nullity+N+SG
# 458. accuracy -> accuracy+N+SG
# 459. $310 -> $310+N+SG
# 460. vent -> vent+N+SG
# 461. knives -> knive+N+PL
# 462. diversion -> diversion+N+SG
# 463. drawers -> drawer+N+PL
# 464. righthander -> righthander+N+SG
# 465. hirelings -> hireling+N+PL
# 466. murmur -> murmur+N+SG
# 467. bachelors -> bachelor+N+PL
# 468. alert -> alert+N+SG
# 469. gravy -> gravy+N+SG
# 470. drapes -> drape+N+PL
# 471. interrogation -> interrogation+N+SG
# 472. scrimmage -> scrimmage+N+SG
# 473. sensors -> sensor+N+PL
# 474. launcher -> launcher+N+SG
# 475. belting -> belting+N+SG
# 476. equine -> equine+N+SG
# 477. figment -> figment+N+SG
# 478. $1.7 -> $1.7+N+SG
# 479. agreeableness -> Invalid Word
# 480. junction -> junction+N+SG
# 481. eucalyptus -> eucalyptu+N+PL
# 482. avenues -> avenue+N+PL
# 483. abstention -> abstention+N+SG
# 484. discussions -> discussion+N+PL
# 485. critics -> critic+N+PL
# 486. renunciations -> renunciation+N+PL
# 487. splash -> splash+N+SG
# 488. bean -> bean+N+SG
# 489. cancers -> cancer+N+PL
# 490. foreigner -> foreigner+N+SG
# 491. retainers -> retainer+N+PL
# 492. screams -> scream+N+PL
# 493. genes -> gene+N+PL
# 494. devices -> device+N+PL
# 495. representation -> representation+N+SG
# 496. effect -> effect+N+SG
# 497. kindnesses -> kindness+N+PL
# 498. clam -> clam+N+SG
# 499. threesome -> threesome+N+SG
# 500. reimbursements -> reimbursement+N+PL
# 501. glitter -> glitter+N+SG
# 502. expose -> expose+N+SG
# 503. secrecy -> secrecy+N+SG
# 504. ties -> ty+N+PL
# 505. pauses -> paus+N+PL
# 506. straightaway -> straightaway+N+SG
# 507. involvement -> involvement+N+SG
# 508. scanning -> scanning+N+SG
# 509. stigmata -> stigmata+N+SG
# 510. propulsions -> propulsion+N+PL
# 511. i.d. -> i.d.+N+SG
# 512. icicle -> icicle+N+SG
# 513. illusion -> illusion+N+SG
# 514. wood -> wood+N+SG
# 515. climax -> climax+N+SG
# 516. emphasis -> emphasi+N+PL
# 517. mosquito -> mosquito+N+SG
# 518. bazaar -> bazaar+N+SG
# 519. clays -> clay+N+PL
# 520. zest -> zest+N+SG
# 521. abasement -> abasement+N+SG
# 522. solitude -> solitude+N+SG
# 523. steppes -> steppe+N+PL
# 524. deferent -> deferent+N+SG
# 525. nails -> nail+N+PL
# 526. lacquer -> lacquer+N+SG
# 527. horoscope -> horoscope+N+SG
# 528. sensibility -> sensibility+N+SG
# 529. polities -> polity+N+PL
# 530. mysticisms -> mysticism+N+PL
# 531. whodunnit -> whodunnit+N+SG
# 532. bells -> bell+N+PL
# 533. pitchers -> pitcher+N+PL
# 534. reagents -> reagent+N+PL
# 535. phrasing -> phrasing+N+SG
# 536. allure -> allure+N+SG
# 537. occlusion -> occlusion+N+SG
# 538. hostilities -> hostility+N+PL
# 539. stipulation -> stipulation+N+SG
# 540. megalomania -> megalomania+N+SG
# 541. vitals -> vital+N+PL
# 542. busses -> buss+N+PL
# 543. banter -> banter+N+SG
# 544. boils -> boil+N+PL
# 545. hurts -> hurt+N+PL
# 546. mc. -> mc.+N+SG
# 547. backyard -> backyard+N+SG
# 548. gnome -> gnome+N+SG
# 549. cells -> cell+N+PL
# 550. trend -> trend+N+SG
# 551. healing -> healing+N+SG
# 552. ambiguity -> ambiguity+N+SG
# 553. deodorant -> deodorant+N+SG
# 554. keel -> keel+N+SG
# 555. buckaroos -> buckaroo+N+PL
# 556. revivals -> revival+N+PL
# 557. itinerary -> itinerary+N+SG
# 558. parallels -> parallel+N+PL
# 559. barge -> barge+N+SG
# 560. crankshaft -> crankshaft+N+SG
# 561. finals -> final+N+PL
# 562. lovering -> lovering+N+SG
# 563. anomie -> anomie+N+SG
# 564. kilowatts -> kilowatt+N+PL
# 565. spoof -> spoof+N+SG
# 566. antique -> antique+N+SG
# 567. lice -> lice+N+SG
# 568. adolescent -> adolescent+N+SG
# 569. arrival -> arrival+N+SG
# 570. sandbars -> sandbar+N+PL
# 571. arbitration -> arbitration+N+SG
# 572. dice -> dice+N+SG
# 573. intestines -> intestine+N+PL
# 574. deprivation -> deprivation+N+SG
# 575. showdown -> showdown+N+SG
# 576. bravura -> bravura+N+SG
# 577. putout -> putout+N+SG
# 578. dud -> dud+N+SG
# 579. spoilage -> spoilage+N+SG
# 580. volatilization -> volatilization+N+SG
# 581. paleoexplosion -> paleoexplosion+N+SG
# 582. steamer -> steamer+N+SG
# 583. determinability -> determinability+N+SG
# 584. begging -> begging+N+SG
# 585. boucle -> boucle+N+SG
# 586. orientation -> orientation+N+SG
# 587. copolymers -> copolymer+N+PL
# 588. switches -> switch+N+PL
# 589. operators -> operator+N+PL
# 590. pegs -> peg+N+PL
# 591. drawbridge -> drawbridge+N+SG
# 592. split -> split+N+SG
# 593. office -> office+N+SG
# 594. grassers -> grasser+N+PL
# 595. scenes -> scene+N+PL
# 596. squeals -> squeal+N+PL
# 597. exploiters -> exploiter+N+PL
# 598. folklore -> folklore+N+SG
# 599. imbalance -> imbalance+N+SG
# 600. differentiability -> differentiability+N+SG
# 601. salves -> salve+N+PL
# 602. arm -> arm+N+SG
# 603. residence -> residence+N+SG
# 604. expectation -> expectation+N+SG
# 605. solutions -> solution+N+PL
# 606. farms -> farm+N+PL
# 607. rivals -> rival+N+PL
# 608. expansion -> expansion+N+SG
# 609. sreserve -> sreserve+N+SG
# 610. minorities -> minority+N+PL
# 611. palatability -> palatability+N+SG
# 612. slitter -> slitter+N+SG
# 613. substitutes -> substitute+N+PL
# 614. prosperity -> prosperity+N+SG
# 615. ommission -> ommission+N+SG
# 616. bronchioles -> bronchiole+N+PL
# 617. nahb -> nahb+N+SG
# 618. match -> match+N+SG
# 619. insistence -> insistence+N+SG
# 620. shadowing -> shadowing+N+SG
# 621. drinker -> drinker+N+SG
# 622. perplexity -> perplexity+N+SG
# 623. noblesse -> noblesse+N+SG
# 624. currant -> currant+N+SG
# 625. firemen -> firemen+N+SG
# 626. shirts -> shirt+N+PL
# 627. planter -> planter+N+SG
# 628. monolith -> monolith+N+SG
# 629. hunter -> hunter+N+SG
# 630. prechlorination -> prechlorination+N+SG
# 631. godliness -> Invalid Word
# 632. acquiescence -> acquiescence+N+SG
# 633. couplers -> coupler+N+PL
# 634. disrepair -> disrepair+N+SG
# 635. bathos -> batho+N+PL
# 636. oxyhydroxides -> oxyhydroxide+N+PL
# 637. toilets -> toilet+N+PL
# 638. underarm -> underarm+N+SG
# 639. fda -> fda+N+SG
# 640. sieve -> sieve+N+SG
# 641. amide -> amide+N+SG
# 642. cousin -> cousin+N+SG
# 643. artfulness -> Invalid Word
# 644. canvases -> canvas+N+PL
# 645. hackers -> hacker+N+PL
# 646. fairness -> Invalid Word
# 647. $57,500 -> $57,500+N+SG
# 648. turkeys -> turkey+N+PL
# 649. looks -> look+N+PL
# 650. sunspot -> sunspot+N+SG
# 651. kwhr -> kwhr+N+SG
# 652. marble -> marble+N+SG
# 653. deepening -> deepening+N+SG
# 654. ransom -> ransom+N+SG
# 655. kibbutzim -> kibbutzim+N+SG
# 656. discipleship -> discipleship+N+SG
# 657. complexity -> complexity+N+SG
# 658. monopolization -> monopolization+N+SG
# 659. megatons -> megaton+N+PL
# 660. robbery -> robbery+N+SG
# 661. sword -> sword+N+SG
# 662. soul -> soul+N+SG
# 663. horses -> hors+N+PL
# 664. ingredients -> ingredient+N+PL
# 665. majority -> majority+N+SG
# 666. undergraduate -> undergraduate+N+SG
# 667. mean -> mean+N+SG
# 668. gashes -> gash+N+PL
# 669. pouches -> pouch+N+PL
# 670. disadvantages -> disadvantage+N+PL
# 671. unfoldment -> unfoldment+N+SG
# 672. fanfare -> fanfare+N+SG
# 673. conqueror -> conqueror+N+SG
# 674. fidelity -> fidelity+N+SG
# 675. chase -> chase+N+SG
# 676. gambits -> gambit+N+PL
# 677. 10'' -> 10''+N+SG
# 678. pencils -> pencil+N+PL
# 679. threes -> three+N+PL
# 680. problem -> problem+N+SG
# 681. artificiality -> artificiality+N+SG
# 682. portions -> portion+N+PL
# 683. agglutination -> agglutination+N+SG
# 684. group -> group+N+SG
# 685. cosmos -> cosmo+N+PL
# 686. seminar -> seminar+N+SG
# 687. $18 -> $18+N+SG
# 688. ivy -> ivy+N+SG
# 689. resurgence -> resurgence+N+SG
# 690. mistrial -> mistrial+N+SG
# 691. ions -> ion+N+PL
# 692. coolness -> Invalid Word
# 693. method -> method+N+SG
# 694. tremor -> tremor+N+SG
# 695. violins -> violin+N+PL
# 696. lactate -> lactate+N+SG
# 697. sax -> sax+N+SG
# 698. wrestlings -> wrestling+N+PL
# 699. livestock -> livestock+N+SG
# 700. grey -> grey+N+SG
# 701. railways -> railway+N+PL
# 702. rectangle -> rectangle+N+SG
# 703. heaviness -> Invalid Word
# 704. choking -> choking+N+SG
# 705. resorts -> resort+N+PL
# 706. dives -> dive+N+PL
# 707. ventilator -> ventilator+N+SG
# 708. vampires -> vampire+N+PL
# 709. booklists -> booklist+N+PL
# 710. cruiser -> cruiser+N+SG
# 711. markings -> marking+N+PL
# 712. cotillion -> cotillion+N+SG
# 713. moisture -> moisture+N+SG
# 714. resumption -> resumption+N+SG
# 715. potentialities -> potentiality+N+PL
# 716. oxcart -> oxcart+N+SG
# 717. aspirant -> aspirant+N+SG
# 718. intercept -> intercept+N+SG
# 719. marijuana -> marijuana+N+SG
# 720. pillows -> pillow+N+PL
# 721. crackling -> crackling+N+SG
# 722. balcony -> balcony+N+SG
# 723. intervention -> intervention+N+SG
# 724. divinity -> divinity+N+SG
# 725. dustbin -> dustbin+N+SG
# 726. sanctions -> sanction+N+PL
# 727. queasiness -> Invalid Word
# 728. miles -> mile+N+PL
# 729. pfc -> pfc+N+SG
# 730. modules -> module+N+PL
# 731. coils -> coil+N+PL
# 732. manner -> manner+N+SG
# 733. driers -> drier+N+PL
# 734. syndicates -> syndicate+N+PL
# 735. delegates -> delegate+N+PL
# 736. underbelly -> underbelly+N+SG
# 737. trenches -> trench+N+PL
# 738. sarcasms -> sarcasm+N+PL
# 739. rookie -> rookie+N+SG
# 740. agreement -> agreement+N+SG
# 741. modernism -> modernism+N+SG
# 742. galvanism -> galvanism+N+SG
# 743. $2,300,000 -> $2,300,000+N+SG
# 744. flour -> flour+N+SG
# 745. consanguinity -> consanguinity+N+SG
# 746. statesmen -> statesmen+N+SG
# 747. lows -> low+N+PL
# 748. appropriateness -> Invalid Word
# 749. guitarist -> guitarist+N+SG
# 750. solipsism -> solipsism+N+SG
# 751. complex -> complex+N+SG
# 752. salesmanship -> salesmanship+N+SG
# 753. paucity -> paucity+N+SG
# 754. miscalculation -> miscalculation+N+SG
# 755. refraction -> refraction+N+SG
# 756. fleas -> flea+N+PL
# 757. fln -> fln+N+SG
# 758. imaginations -> imagination+N+PL
# 759. boulevard -> boulevard+N+SG
# 760. nondriver -> nondriver+N+SG
# 761. impurity -> impurity+N+SG
# 762. schoolers -> schooler+N+PL
# 763. emigration -> emigration+N+SG
# 764. colloquy -> colloquy+N+SG
# 765. cream -> cream+N+SG
# 766. heights -> height+N+PL
# 767. nickel -> nickel+N+SG
# 768. bearer -> bearer+N+SG
# 769. growths -> growth+N+PL
# 770. amateur -> amateur+N+SG
# 771. contrary -> contrary+N+SG
# 772. assumption -> assumption+N+SG
# 773. fathers -> father+N+PL
# 774. epitaph -> epitaph+N+SG
# 775. hose -> hose+N+SG
# 776. foe -> foe+N+SG
# 777. conceptions -> conception+N+PL
# 778. cage -> cage+N+SG
# 779. warfare -> warfare+N+SG
# 780. ginghams -> gingham+N+PL
# 781. kick -> kick+N+SG
# 782. twitch -> twitch+N+SG
# 783. autumn -> autumn+N+SG
# 784. stirrup -> stirrup+N+SG
# 785. planting -> planting+N+SG
# 786. influx -> influx+N+SG
# 787. trucking -> trucking+N+SG
# 788. sellin' -> sellin'+N+SG
# 789. modernity -> modernity+N+SG
# 790. pangs -> pang+N+PL
# 791. dline -> dline+N+SG
# 792. incipiency -> incipiency+N+SG
# 793. python -> python+N+SG
# 794. lute -> lute+N+SG
# 795. claims -> claim+N+PL
# 796. corporations -> corporation+N+PL
# 797. mores -> more+N+PL
# 798. flyways -> flyway+N+PL
# 799. heartbeat -> heartbeat+N+SG
# 800. ass -> Invalid Word
# 801. posse -> posse+N+SG
# 802. woodcarver -> woodcarver+N+SG
# 803. hash -> hash+N+SG
# 804. tropidoclonion -> tropidoclonion+N+SG
# 805. onrush -> onrush+N+SG
# 806. rinse -> rinse+N+SG
# 807. champions -> champion+N+PL
# 808. imminence -> imminence+N+SG
# 809. tint -> tint+N+SG
# 810. swig -> swig+N+SG
# 811. act -> act+N+SG
# 812. squabbling -> squabbling+N+SG
# 813. retrace -> retrace+N+SG
# 814. adventures -> adventure+N+PL
# 815. poultry -> poultry+N+SG
# 816. clover -> clover+N+SG
# 817. roundness -> Invalid Word
# 818. laying -> laying+N+SG
# 819. calfskin -> calfskin+N+SG
# 820. boxer -> boxer+N+SG
# 821. woodshed -> woodshed+N+SG
# 822. lapses -> laps+N+PL
# 823. wilt -> wilt+N+SG
# 824. mike -> mike+N+SG
# 825. tombs -> tomb+N+PL
# 826. decrease -> decrease+N+SG
# 827. $750,000 -> $750,000+N+SG
# 828. acrylic -> acrylic+N+SG
# 829. calamity -> calamity+N+SG
# 830. renunciation -> renunciation+N+SG
# 831. primaries -> primary+N+PL
# 832. sins -> sin+N+PL
# 833. sentence -> sentence+N+SG
# 834. $80 -> $80+N+SG
# 835. dispossession -> dispossession+N+SG
# 836. store -> store+N+SG
# 837. sphere -> sphere+N+SG
# 838. patio -> patio+N+SG
# 839. bill -> bill+N+SG
# 840. stick -> stick+N+SG
# 841. plane -> plane+N+SG
# 842. rosettes -> rosette+N+PL
# 843. tramp -> tramp+N+SG
# 844. business -> Invalid Word
# 845. correctness -> Invalid Word
# 846. success -> Invalid Word
# 847. find -> find+N+SG
# 848. butterflies -> butterfly+N+PL
# 849. wagon -> wagon+N+SG
# 850. benevolence -> benevolence+N+SG
# 851. society -> society+N+SG
# 852. marrow -> marrow+N+SG
# 853. devils -> devil+N+PL
# 854. weeklies -> weekly+N+PL
# 855. bunt -> bunt+N+SG
# 856. brutalities -> brutality+N+PL
# 857. calipers -> caliper+N+PL
# 858. dominance -> dominance+N+SG
# 859. wanderings -> wandering+N+PL
# 860. infestation -> infestation+N+SG
# 861. utilities -> utility+N+PL
# 862. engrg -> engrg+N+SG
# 863. morgue -> morgue+N+SG
# 864. subsection -> subsection+N+SG
# 865. bandwidth -> bandwidth+N+SG
# 866. denomination -> denomination+N+SG
# 867. imitations -> imitation+N+PL
# 868. crests -> crest+N+PL
# 869. commentators -> commentator+N+PL
# 870. secant -> secant+N+SG
# 871. binding -> binding+N+SG
# 872. survivalists -> survivalist+N+PL
# 873. accelerometers -> accelerometer+N+PL
# 874. granting -> granting+N+SG
# 875. dollars -> dollar+N+PL
# 876. tappet -> tappet+N+SG
# 877. defacing -> defacing+N+SG
# 878. eclipses -> eclips+N+PL
# 879. wandering -> wandering+N+SG
# 880. reappearance -> reappearance+N+SG
# 881. lurch -> lurch+N+SG
# 882. rejections -> rejection+N+PL
# 883. verdict -> verdict+N+SG
# 884. triple -> triple+N+SG
# 885. matting -> matting+N+SG
# 886. departure -> departure+N+SG
# 887. harrumphing -> harrumphing+N+SG
# 888. managements -> management+N+PL
# 889. dragger -> dragger+N+SG
# 890. roughcast -> roughcast+N+SG
# 891. soapsuds -> soapsud+N+PL
# 892. gossamer -> gossamer+N+SG
# 893. railroading -> railroading+N+SG
# 894. kingdom -> kingdom+N+SG
# 895. party -> party+N+SG
# 896. execution -> execution+N+SG
# 897. verisimilitude -> verisimilitude+N+SG
# 898. adjectives -> adjective+N+PL
# 899. blueberry -> blueberry+N+SG
# 900. publicists -> publicist+N+PL
# 901. pluralism -> pluralism+N+SG
# 902. speeds -> speed+N+PL
# 903. accesses -> access+N+PL
# 904. monochromes -> monochrome+N+PL
# 905. disciple -> disciple+N+SG
# 906. atomisation -> atomisation+N+SG
# 907. dive -> dive+N+SG
# 908. lumps -> lump+N+PL
# 909. gayety -> gayety+N+SG
# 910. paralysis -> paralysi+N+PL
# 911. solder -> solder+N+SG
# 912. retrovision -> retrovision+N+SG
# 913. hillbilly -> hillbilly+N+SG
# 914. bedspread -> bedspread+N+SG
# 915. underbracing -> underbracing+N+SG
# 916. bebop -> bebop+N+SG
# 917. academic -> academic+N+SG
# 918. enactment -> enactment+N+SG
# 919. allurement -> allurement+N+SG
# 920. knocks -> knock+N+PL
# 921. orthophosphate -> orthophosphate+N+SG
# 922. unanimity -> unanimity+N+SG
# 923. castles -> castle+N+PL
# 924. fetes -> fete+N+PL
# 925. allegations -> allegation+N+PL
# 926. autocrats -> autocrat+N+PL
# 927. exuberance -> exuberance+N+SG
# 928. interrogatives -> interrogative+N+PL
# 929. shepherds -> shepherd+N+PL
# 930. grandparents -> grandparent+N+PL
# 931. birch -> birch+N+SG
# 932. pastilles -> pastille+N+PL
# 933. condenser -> condenser+N+SG
# 934. supernaturalism -> supernaturalism+N+SG
# 935. potentials -> potential+N+PL
# 936. ritiuality -> ritiuality+N+SG
# 937. dept. -> dept.+N+SG
# 938. abortions -> abortion+N+PL
# 939. illustrator -> illustrator+N+SG
# 940. retirement -> retirement+N+SG
# 941. newsmen -> newsmen+N+SG
# 942. censures -> censure+N+PL
# 943. surplus -> surplu+N+PL
# 944. blower -> blower+N+SG
# 945. content -> content+N+SG
# 946. drawl -> drawl+N+SG
# 947. cock -> cock+N+SG
# 948. calendars -> calendar+N+PL
# 949. habit -> habit+N+SG
# 950. takeing -> takeing+N+SG
# 951. vanity -> vanity+N+SG
# 952. playwrights -> playwright+N+PL
# 953. intermissions -> intermission+N+PL
# 954. copies -> copy+N+PL
# 955. rehabilitation -> rehabilitation+N+SG
# 956. airport -> airport+N+SG
# 957. mackintosh -> mackintosh+N+SG
# 958. hundreds -> hundred+N+PL
# 959. handwriting -> handwriting+N+SG
# 960. twilight -> twilight+N+SG
# 961. inhibitors -> inhibitor+N+PL
# 962. duet -> duet+N+SG
# 963. dispatch -> dispatch+N+SG
# 964. house -> house+N+SG
# 965. senator -> senator+N+SG
# 966. velvet -> velvet+N+SG
# 967. seedbed -> seedbed+N+SG
# 968. melioration -> melioration+N+SG
# 969. blasphemies -> blasphemy+N+PL
# 970. phs -> ph+N+PL
# 971. bandit -> bandit+N+SG
# 972. periwinkles -> periwinkle+N+PL
# 973. effects -> effect+N+PL
# 974. mushrooms -> mushroom+N+PL
# 975. improvement -> improvement+N+SG
# 976. objects -> object+N+PL
# 977. vitamins -> vitamin+N+PL
# 978. filets -> filet+N+PL
# 979. absenteeism -> absenteeism+N+SG
# 980. error -> error+N+SG
# 981. ranch -> ranch+N+SG
# 982. nighters -> nighter+N+PL
# 983. bindle -> bindle+N+SG
# 984. skirt -> skirt+N+SG
# 985. lbs. -> lbs.+N+SG
# 986. agencies -> agency+N+PL
# 987. denyin' -> denyin'+N+SG
# 988. roses -> ros+N+PL
# 989. appearances -> appearance+N+PL
# 990. newcomers -> newcomer+N+PL
# 991. repulsions -> repulsion+N+PL
# 992. duets -> duet+N+PL
# 993. $2.80 -> $2.80+N+SG
# 994. stopper -> stopper+N+SG
# 995. hallucinations -> hallucination+N+PL
# 996. centimeter -> centimeter+N+SG
# 997. retrospect -> retrospect+N+SG
# 998. tapes -> tape+N+PL
# 999. nose -> nose+N+SG
# 1000. watchdog -> watchdog+N+SG
# 1001. spreads -> spread+N+PL
# 1002. panic -> panic+N+SG
# 1003. mistrust -> mistrust+N+SG
# 1004. surface -> surface+N+SG
# 1005. roundhouse -> roundhouse+N+SG
# 1006. respiration -> respiration+N+SG
# 1007. miscalculations -> miscalculation+N+PL
# 1008. prospects -> prospect+N+PL
# 1009. rows -> row+N+PL
# 1010. pranks -> prank+N+PL
# 1011. planner -> planner+N+SG
# 1012. creepers -> creeper+N+PL
# 1013. ledgers -> ledger+N+PL
# 1014. slides -> slide+N+PL
# 1015. technicians -> technician+N+PL
# 1016. headboard -> headboard+N+SG
# 1017. highlights -> highlight+N+PL
# 1018. sec. -> sec.+N+SG
# 1019. parsonage -> parsonage+N+SG
# 1020. tuc -> tuc+N+SG
# 1021. testings -> testing+N+PL
# 1022. solo -> solo+N+SG
# 1023. tour -> tour+N+SG
# 1024. estimates -> estimate+N+PL
# 1025. motet -> motet+N+SG
# 1026. cowboys -> cowboy+N+PL
# 1027. croupier -> croupier+N+SG
# 1028. peace -> peace+N+SG
# 1029. indium -> indium+N+SG
# 1030. pounding -> pounding+N+SG
# 1031. prisons -> prison+N+PL
# 1032. spacesuits -> spacesuit+N+PL
# 1033. actress -> Invalid Word
# 1034. geography -> geography+N+SG
# 1035. acreage -> acreage+N+SG
# 1036. layoffs -> layoff+N+PL
# 1037. forearm -> forearm+N+SG
# 1038. coach -> coach+N+SG
# 1039. fruits -> fruit+N+PL
# 1040. platoon -> platoon+N+SG
# 1041. rafters -> rafter+N+PL
# 1042. helpmate -> helpmate+N+SG
# 1043. fiesta -> fiesta+N+SG
# 1044. canteen -> canteen+N+SG
# 1045. despairing -> despairing+N+SG
# 1046. interdependence -> interdependence+N+SG
# 1047. excavation -> excavation+N+SG
# 1048. $40 -> $40+N+SG
# 1049. focus -> focu+N+PL
# 1050. booking -> booking+N+SG
# 1051. hostler -> hostler+N+SG
# 1052. hooves -> hoove+N+PL
# 1053. mediocrities -> mediocrity+N+PL
# 1054. saga -> saga+N+SG
# 1055. synonyms -> synonym+N+PL
# 1056. prayers -> prayer+N+PL
# 1057. nun -> nun+N+SG
# 1058. topcoats -> topcoat+N+PL
# 1059. picturing -> picturing+N+SG
# 1060. collation -> collation+N+SG
# 1061. disregard -> disregard+N+SG
# 1062. sedative -> sedative+N+SG
# 1063. literatures -> literature+N+PL
# 1064. rounds -> round+N+PL
# 1065. age -> age+N+SG
# 1066. rotations -> rotation+N+PL
# 1067. alizarin -> alizarin+N+SG
# 1068. bustle -> bustle+N+SG
# 1069. pageantry -> pageantry+N+SG
# 1070. interpolations -> interpolation+N+PL
# 1071. rundown -> rundown+N+SG
# 1072. thrombi -> thrombi+N+SG
# 1073. industrialist -> industrialist+N+SG
# 1074. architects -> architect+N+PL
# 1075. snapdragons -> snapdragon+N+PL
# 1076. stance -> stance+N+SG
# 1077. comparison -> comparison+N+SG
# 1078. bulb -> bulb+N+SG
# 1079. overnight -> overnight+N+SG
# 1080. jalopy -> jalopy+N+SG
# 1081. shill -> shill+N+SG
# 1082. alternatives -> alternative+N+PL
# 1083. rectifier -> rectifier+N+SG
# 1084. thruways -> thruway+N+PL
# 1085. milieu -> milieu+N+SG
# 1086. carryovers -> carryover+N+PL
# 1087. intern -> intern+N+SG
# 1088. radar -> radar+N+SG
# 1089. yeast -> yeast+N+SG
# 1090. runways -> runway+N+PL
# 1091. limelight -> limelight+N+SG
# 1092. expansionist -> expansionist+N+SG
# 1093. rights -> right+N+PL
# 1094. equalizing -> equalizing+N+SG
# 1095. peasanthood -> peasanthood+N+SG
# 1096. alleviation -> alleviation+N+SG
# 1097. battle -> battle+N+SG
# 1098. eyewitness -> Invalid Word
# 1099. jolt -> jolt+N+SG
# 1100. candies -> candy+N+PL
# 1101. p(q) -> p(q)+N+SG
# 1102. sandalwood -> sandalwood+N+SG
# 1103. technology -> technology+N+SG
# 1104. staccato -> staccato+N+SG
# 1105. ovation -> ovation+N+SG
# 1106. praise -> praise+N+SG
# 1107. racketeers -> racketeer+N+PL
# 1108. apostle -> apostle+N+SG
# 1109. cushions -> cushion+N+PL
# 1110. trauma -> trauma+N+SG
# 1111. fall -> fall+N+SG
# 1112. slaughter -> slaughter+N+SG
# 1113. telegrams -> telegram+N+PL
# 1114. buses -> bus+N+PL
# 1115. denying -> denying+N+SG
# 1116. reactionaries -> reactionary+N+PL
# 1117. soldiers -> soldier+N+PL
# 1118. historians -> historian+N+PL
# 1119. educations -> education+N+PL
# 1120. $172,000 -> $172,000+N+SG
# 1121. manslaughter -> manslaughter+N+SG
# 1122. watching -> watching+N+SG
# 1123. credit -> credit+N+SG
# 1124. spurs -> spur+N+PL
# 1125. metrazol -> metrazol+N+SG
# 1126. archenemy -> archenemy+N+SG
# 1127. severing -> severing+N+SG
# 1128. velocities -> velocity+N+PL
# 1129. growing -> growing+N+SG
# 1130. pars -> par+N+PL
# 1131. headwalls -> headwall+N+PL
# 1132. bgs -> bg+N+PL
# 1133. witch -> witch+N+SG
# 1134. manipulations -> manipulation+N+PL
# 1135. cannon -> cannon+N+SG
# 1136. personages -> personage+N+PL
# 1137. supermarkets -> supermarket+N+PL
# 1138. diversions -> diversion+N+PL
# 1139. deficit -> deficit+N+SG
# 1140. possibility -> possibility+N+SG
# 1141. christening -> christening+N+SG
# 1142. vintner -> vintner+N+SG
# 1143. glass -> Invalid Word
# 1144. invasion -> invasion+N+SG
# 1145. sacrifices -> sacrifice+N+PL
# 1146. decorativeness -> Invalid Word
# 1147. ballfields -> ballfield+N+PL
# 1148. game -> game+N+SG
# 1149. scribe -> scribe+N+SG
# 1150. photocathode -> photocathode+N+SG
# 1151. information -> information+N+SG
# 1152. parent -> parent+N+SG
# 1153. rift -> rift+N+SG
# 1154. body -> body+N+SG
# 1155. shag -> shag+N+SG
# 1156. apprehensions -> apprehension+N+PL
# 1157. immobility -> immobility+N+SG
# 1158. liking -> liking+N+SG
# 1159. migrants -> migrant+N+PL
# 1160. picture -> picture+N+SG
# 1161. chuckle -> chuckle+N+SG
# 1162. footballs -> football+N+PL
# 1163. pantheon -> pantheon+N+SG
# 1164. simile -> simile+N+SG
# 1165. beatnik -> beatnik+N+SG
# 1166. joblot -> joblot+N+SG
# 1167. hydroxides -> hydroxide+N+PL
# 1168. distillers -> distiller+N+PL
# 1169. deed -> deed+N+SG
# 1170. wwrl -> wwrl+N+SG
# 1171. cloakrooms -> cloakroom+N+PL
# 1172. driver -> driver+N+SG
# 1173. eyelets -> eyelet+N+PL
# 1174. divers -> diver+N+PL
# 1175. bibliographies -> bibliography+N+PL
# 1176. epigrams -> epigram+N+PL
# 1177. subcommittee -> subcommittee+N+SG
# 1178. crushers -> crusher+N+PL
# 1179. ethic -> ethic+N+SG
# 1180. standard -> standard+N+SG
# 1181. command -> command+N+SG
# 1182. coldness -> Invalid Word
# 1183. glint -> glint+N+SG
# 1184. tongue -> tongue+N+SG
# 1185. biology -> biology+N+SG
# 1186. turrets -> turret+N+PL
# 1187. distance -> distance+N+SG
# 1188. birdie -> birdie+N+SG
# 1189. absentia -> absentia+N+SG
# 1190. nonreactivity -> nonreactivity+N+SG
# 1191. hacksaw -> hacksaw+N+SG
# 1192. underwriters -> underwriter+N+PL
# 1193. sovereign -> sovereign+N+SG
# 1194. protozoa -> protozoa+N+SG
# 1195. socialization -> socialization+N+SG
# 1196. insides -> inside+N+PL
# 1197. soirees -> soiree+N+PL
# 1198. peacock -> peacock+N+SG
# 1199. mammas -> mamma+N+PL
# 1200. implements -> implement+N+PL
# 1201. microseconds -> microsecond+N+PL
# 1202. stare -> stare+N+SG
# 1203. selectors -> selector+N+PL
# 1204. crime -> crime+N+SG
# 1205. hubbub -> hubbub+N+SG
# 1206. skeptics -> skeptic+N+PL
# 1207. windmill -> windmill+N+SG
# 1208. yard -> yard+N+SG
# 1209. tadpoles -> tadpole+N+PL
# 1210. rigidity -> rigidity+N+SG
# 1211. earphones -> earphone+N+PL
# 1212. dogmas -> dogma+N+PL
# 1213. simplicity -> simplicity+N+SG
# 1214. album -> album+N+SG
# 1215. anarchy -> anarchy+N+SG
# 1216. rector -> rector+N+SG
# 1217. brashness -> Invalid Word
# 1218. canisters -> canister+N+PL
# 1219. infidelity -> infidelity+N+SG
# 1220. broods -> brood+N+PL
# 1221. progression -> progression+N+SG
# 1222. bulkhead -> bulkhead+N+SG
# 1223. turbofan -> turbofan+N+SG
# 1224. duration -> duration+N+SG
# 1225. plateau -> plateau+N+SG
# 1226. coals -> coal+N+PL
# 1227. regulator -> regulator+N+SG
# 1228. plugugly -> plugugly+N+SG
# 1229. juniors -> junior+N+PL
# 1230. slate -> slate+N+SG
# 1231. scabbard -> scabbard+N+SG
# 1232. insulator -> insulator+N+SG
# 1233. onlookers -> onlooker+N+PL
# 1234. spokesmen -> spokesmen+N+SG
# 1235. caravans -> caravan+N+PL
# 1236. originals -> original+N+PL
# 1237. legato -> legato+N+SG
# 1238. dogleg -> dogleg+N+SG
# 1239. laments -> lament+N+PL
# 1240. farm -> farm+N+SG
# 1241. perforations -> perforation+N+PL
# 1242. harem -> harem+N+SG
# 1243. logistics -> logistic+N+PL
# 1244. disapprobation -> disapprobation+N+SG
# 1245. gravity -> gravity+N+SG
# 1246. butler -> butler+N+SG
# 1247. decimals -> decimal+N+PL
# 1248. margins -> margin+N+PL
# 1249. interviewing -> interviewing+N+SG
# 1250. worms -> worm+N+PL
# 1251. wheel -> wheel+N+SG
# 1252. presentations -> presentation+N+PL
# 1253. toothbrush -> toothbrush+N+SG
# 1254. deans -> dean+N+PL
# 1255. glycols -> glycol+N+PL
# 1256. gaps -> gap+N+PL
# 1257. mycobacteria -> mycobacteria+N+SG
# 1258. possum -> possum+N+SG
# 1259. keynotes -> keynote+N+PL
# 1260. refrain -> refrain+N+SG
# 1261. gymnasts -> gymnast+N+PL
# 1262. elite -> elite+N+SG
# 1263. thick -> thick+N+SG
# 1264. post -> post+N+SG
# 1265. centum -> centum+N+SG
# 1266. ruse -> ruse+N+SG
# 1267. squadron -> squadron+N+SG
# 1268. earrings -> earring+N+PL
# 1269. mishap -> mishap+N+SG
# 1270. drives -> drive+N+PL
# 1271. crowbait -> crowbait+N+SG
# 1272. $1.80 -> $1.80+N+SG
# 1273. effluvium -> effluvium+N+SG
# 1274. rehearsal -> rehearsal+N+SG
# 1275. leafmold -> leafmold+N+SG
# 1276. conversations -> conversation+N+PL
# 1277. indignities -> indignity+N+PL
# 1278. poker -> poker+N+SG
# 1279. dedication -> dedication+N+SG
# 1280. slogan -> slogan+N+SG
# 1281. citizenship -> citizenship+N+SG
# 1282. gibes -> gibe+N+PL
# 1283. redefinition -> redefinition+N+SG
# 1284. dyerear -> dyerear+N+SG
# 1285. degradation -> degradation+N+SG
# 1286. parasite -> parasite+N+SG
# 1287. trail -> trail+N+SG
# 1288. nagging -> nagging+N+SG
# 1289. reviews -> review+N+PL
# 1290. hurdle -> hurdle+N+SG
# 1291. $7,500,000 -> $7,500,000+N+SG
# 1292. grunting -> grunting+N+SG
# 1293. pastel -> pastel+N+SG
# 1294. $25 -> $25+N+SG
# 1295. $90 -> $90+N+SG
# 1296. thoughts -> thought+N+PL
# 1297. scores -> score+N+PL
# 1298. ration -> ration+N+SG
# 1299. spume -> spume+N+SG
# 1300. stew -> stew+N+SG
# 1301. backers -> backer+N+PL
# 1302. frills -> frill+N+PL
# 1303. touchdowns -> touchdown+N+PL
# 1304. cannonball -> cannonball+N+SG
# 1305. positivism -> positivism+N+SG
# 1306. veto -> veto+N+SG
# 1307. stub -> stub+N+SG
# 1308. questioners -> questioner+N+PL
# 1309. mistress -> Invalid Word
# 1310. encounter -> encounter+N+SG
# 1311. thermistor -> thermistor+N+SG
# 1312. cavalrymen -> cavalrymen+N+SG
# 1313. sortie -> sortie+N+SG
# 1314. pennants -> pennant+N+PL
# 1315. miracle -> miracle+N+SG
# 1316. containment -> containment+N+SG
# 1317. ringings -> ringing+N+PL
# 1318. roommate -> roommate+N+SG
# 1319. signs -> sign+N+PL
# 1320. $187 -> $187+N+SG
# 1321. loneliness -> Invalid Word
# 1322. fundamentalist -> fundamentalist+N+SG
# 1323. survivor -> survivor+N+SG
# 1324. preradiation -> preradiation+N+SG
# 1325. baron -> baron+N+SG
# 1326. interest -> interest+N+SG
# 1327. axes -> ax+N+PL
# 1328. fielders -> fielder+N+PL
# 1329. welcome -> welcome+N+SG
# 1330. prevalence -> prevalence+N+SG
# 1331. classic -> classic+N+SG
# 1332. banishment -> banishment+N+SG
# 1333. cord -> cord+N+SG
# 1334. 5/16'' -> 5/16''+N+SG
# 1335. anxieties -> anxiety+N+PL
# 1336. beginning -> beginning+N+SG
# 1337. electrophorus -> electrophoru+N+PL
# 1338. advertising -> advertising+N+SG
# 1339. traits -> trait+N+PL
# 1340. thinkers -> thinker+N+PL
# 1341. rate -> rate+N+SG
# 1342. sportsmanship -> sportsmanship+N+SG
# 1343. pfennig -> pfennig+N+SG
# 1344. consensus -> consensu+N+PL
# 1345. misunderstanding -> misunderstanding+N+SG
# 1346. ranks -> rank+N+PL
# 1347. spades -> spade+N+PL
# 1348. tennis -> tenni+N+PL
# 1349. chat -> chat+N+SG
# 1350. withes -> withe+N+PL
# 1351. diaphragm -> diaphragm+N+SG
# 1352. hollowware -> hollowware+N+SG
# 1353. flush -> flush+N+SG
# 1354. career -> career+N+SG
# 1355. creature -> creature+N+SG
# 1356. retrieval -> retrieval+N+SG
# 1357. reflections -> reflection+N+PL
# 1358. magnification -> magnification+N+SG
# 1359. finalists -> finalist+N+PL
# 1360. truths -> truth+N+PL
# 1361. bloom -> bloom+N+SG
# 1362. trench -> trench+N+SG
# 1363. regiments -> regiment+N+PL
# 1364. remembrance -> remembrance+N+SG
# 1365. science -> science+N+SG
# 1366. sigh -> sigh+N+SG
# 1367. intima -> intima+N+SG
# 1368. decking -> decking+N+SG
# 1369. kidneys -> kidney+N+PL
# 1370. retardation -> retardation+N+SG
# 1371. drdw -> drdw+N+SG
# 1372. clock -> clock+N+SG
# 1373. impromptu -> impromptu+N+SG
# 1374. brawl -> brawl+N+SG
# 1375. coachman -> coachman+N+SG
# 1376. policies -> policy+N+PL
# 1377. stepson -> stepson+N+SG
# 1378. athletes -> athlete+N+PL
# 1379. plains -> plain+N+PL
# 1380. visit -> visit+N+SG
# 1381. boarder -> boarder+N+SG
# 1382. heiress -> Invalid Word
# 1383. wording -> wording+N+SG
# 1384. graduation -> graduation+N+SG
# 1385. jerks -> jerk+N+PL
# 1386. contradiction -> contradiction+N+SG
# 1387. unconscious -> unconsciou+N+PL
# 1388. scandals -> scandal+N+PL
# 1389. funnel -> funnel+N+SG
# 1390. stockade -> stockade+N+SG
# 1391. puzzler -> puzzler+N+SG
# 1392. breakdown -> breakdown+N+SG
# 1393. newlywed -> newlywed+N+SG
# 1394. shape -> shape+N+SG
# 1395. panelization -> panelization+N+SG
# 1396. dressing -> dressing+N+SG
# 1397. endings -> ending+N+PL
# 1398. timetables -> timetable+N+PL
# 1399. precincts -> precinct+N+PL
# 1400. critic -> critic+N+SG
# 1401. delinquents -> delinquent+N+PL
# 1402. boundary -> boundary+N+SG
# 1403. magnificence -> magnificence+N+SG
# 1404. builder -> builder+N+SG
# 1405. formulations -> formulation+N+PL
# 1406. bivouac -> bivouac+N+SG
# 1407. beryllium -> beryllium+N+SG
# 1408. mayhem -> mayhem+N+SG
# 1409. alumni -> alumni+N+SG
# 1410. corticotropin -> corticotropin+N+SG
# 1411. chaplain -> chaplain+N+SG
# 1412. spandrels -> spandrel+N+PL
# 1413. solicitousness -> Invalid Word
# 1414. alibi -> alibi+N+SG
# 1415. potpourri -> potpourri+N+SG
# 1416. mop -> mop+N+SG
# 1417. hemlocks -> hemlock+N+PL
# 1418. designs -> design+N+PL
# 1419. lags -> lag+N+PL
# 1420. feuds -> feud+N+PL
# 1421. extinction -> extinction+N+SG
# 1422. mineralogy -> mineralogy+N+SG
# 1423. forgiveness -> Invalid Word
# 1424. reprobate -> reprobate+N+SG
# 1425. chasing -> chasing+N+SG
# 1426. terror -> terror+N+SG
# 1427. tolylene -> tolylene+N+SG
# 1428. compartment -> compartment+N+SG
# 1429. cinder -> cinder+N+SG
# 1430. southernisms -> southernism+N+PL
# 1431. gallants -> gallant+N+PL
# 1432. lamp -> lamp+N+SG
# 1433. firearms -> firearm+N+PL
# 1434. thumb -> thumb+N+SG
# 1435. list -> list+N+SG
# 1436. derriere -> derriere+N+SG
# 1437. curbside -> curbside+N+SG
# 1438. bleachers -> bleacher+N+PL
# 1439. cradles -> cradle+N+PL
# 1440. priming -> priming+N+SG
# 1441. hunts -> hunt+N+PL
# 1442. upsurge -> upsurge+N+SG
# 1443. zebra -> zebra+N+SG
# 1444. markets -> market+N+PL
# 1445. buoys -> buoy+N+PL
# 1446. infatuation -> infatuation+N+SG
# 1447. deae -> deae+N+SG
# 1448. primers -> primer+N+PL
# 1449. temples -> temple+N+PL
# 1450. center -> center+N+SG
# 1451. midsummer -> midsummer+N+SG
# 1452. exhaust -> exhaust+N+SG
# 1453. cartoonist -> cartoonist+N+SG
# 1454. nullifiers -> nullifier+N+PL
# 1455. folks -> folk+N+PL
# 1456. meats -> meat+N+PL
# 1457. resonances -> resonance+N+PL
# 1458. contents -> content+N+PL
# 1459. forma -> forma+N+SG
# 1460. chores -> chore+N+PL
# 1461. prestidigitator -> prestidigitator+N+SG
# 1462. noradrenalin -> noradrenalin+N+SG
# 1463. grape -> grape+N+SG
# 1464. fountainhead -> fountainhead+N+SG
# 1465. creak -> creak+N+SG
# 1466. fishmongers -> fishmonger+N+PL
# 1467. memorials -> memorial+N+PL
# 1468. king -> king+N+SG
# 1469. spur -> spur+N+SG
# 1470. circumscriptions -> circumscription+N+PL
# 1471. scours -> scour+N+PL
# 1472. eardrums -> eardrum+N+PL
# 1473. flicker -> flicker+N+SG
# 1474. subsystem -> subsystem+N+SG
# 1475. secessionist -> secessionist+N+SG
# 1476. epigraph -> epigraph+N+SG
# 1477. aridity -> aridity+N+SG
# 1478. serenade -> serenade+N+SG
# 1479. brucellosis -> brucellosi+N+PL
# 1480. curiosity -> curiosity+N+SG
# 1481. boxcar -> boxcar+N+SG
# 1482. aku -> aku+N+SG
# 1483. breakthrough -> breakthrough+N+SG
# 1484. minus -> minu+N+PL
# 1485. revellers -> reveller+N+PL
# 1486. orgasms -> orgasm+N+PL
# 1487. riddle -> riddle+N+SG
# 1488. cushioning -> cushioning+N+SG
# 1489. motherhood -> motherhood+N+SG
# 1490. inaugural -> inaugural+N+SG
# 1491. combatants -> combatant+N+PL
# 1492. dogs -> dog+N+PL
# 1493. ropes -> rope+N+PL
# 1494. outskirts -> outskirt+N+PL
# 1495. swastika -> swastika+N+SG
# 1496. drunkenness -> Invalid Word
# 1497. foundations -> foundation+N+PL
# 1498. flatiron -> flatiron+N+SG
# 1499. shareholders -> shareholder+N+PL
# 1500. hogs -> hog+N+PL
# 1501. hexagon -> hexagon+N+SG
# 1502. salve -> salve+N+SG
# 1503. spirituals -> spiritual+N+PL
# 1504. handcuffs -> handcuff+N+PL
# 1505. shaking -> shaking+N+SG
# 1506. fatalities -> fatality+N+PL
# 1507. plates -> plate+N+PL
# 1508. computations -> computation+N+PL
# 1509. dysplasia -> dysplasia+N+SG
# 1510. mustache -> mustache+N+SG
# 1511. manifold -> manifold+N+SG
# 1512. cheer -> cheer+N+SG
# 1513. 90% -> 90%+N+SG
# 1514. suspensions -> suspension+N+PL
# 1515. forages -> forage+N+PL
# 1516. assessment -> assessment+N+SG
# 1517. $457,000 -> $457,000+N+SG
# 1518. attainments -> attainment+N+PL
# 1519. congruence -> congruence+N+SG
# 1520. tactics -> tactic+N+PL
# 1521. con -> con+N+SG
# 1522. phenonenon -> phenonenon+N+SG
# 1523. constables -> constable+N+PL
# 1524. $1,800 -> $1,800+N+SG
# 1525. shrub -> shrub+N+SG
# 1526. choices -> choice+N+PL
# 1527. ridge -> ridge+N+SG
# 1528. time -> time+N+SG
# 1529. landlords -> landlord+N+PL
# 1530. impairment -> impairment+N+SG
# 1531. magnum -> magnum+N+SG
# 1532. adoption -> adoption+N+SG
# 1533. estates -> estate+N+PL
# 1534. coyotes -> coyote+N+PL
# 1535. outlook -> outlook+N+SG
# 1536. crayons -> crayon+N+PL
# 1537. zero -> zero+N+SG
# 1538. lovie -> lovie+N+SG
# 1539. frescos -> fresco+N+PL
# 1540. heap -> heap+N+SG
# 1541. weekend -> weekend+N+SG
# 1542. ornament -> ornament+N+SG
# 1543. slices -> slice+N+PL
# 1544. carrying -> carrying+N+SG
# 1545. reservations -> reservation+N+PL
# 1546. bulk -> bulk+N+SG
# 1547. $7.50 -> $7.50+N+SG
# 1548. fixture -> fixture+N+SG
# 1549. financing -> financing+N+SG
# 1550. mittens -> mitten+N+PL
# 1551. accusation -> accusation+N+SG
# 1552. jewishness -> Invalid Word
# 1553. dinnertime -> dinnertime+N+SG
# 1554. nomination -> nomination+N+SG
# 1555. equipment -> equipment+N+SG
# 1556. ditches -> ditch+N+PL
# 1557. ld060 -> ld060+N+SG
# 1558. patent -> patent+N+SG
# 1559. cuts -> cut+N+PL
# 1560. commendation -> commendation+N+SG
# 1561. tinkering -> tinkering+N+SG
# 1562. maturation -> maturation+N+SG
# 1563. participant -> participant+N+SG
# 1564. circular -> circular+N+SG
# 1565. rides -> ride+N+PL
# 1566. thankfulness -> Invalid Word
# 1567. thud -> thud+N+SG
# 1568. reverence -> reverence+N+SG
# 1569. whiz -> whiz+N+SG
# 1570. alabaster -> alabaster+N+SG
# 1571. wiring -> wiring+N+SG
# 1572. outsiders -> outsider+N+PL
# 1573. adultery -> adultery+N+SG
# 1574. signers -> signer+N+PL
# 1575. criteria -> criteria+N+SG
# 1576. gestures -> gesture+N+PL
# 1577. terrorists -> terrorist+N+PL
# 1578. transvestitism -> transvestitism+N+SG
# 1579. horsemen -> horsemen+N+SG
# 1580. disgrace -> disgrace+N+SG
# 1581. schoolwork -> schoolwork+N+SG
# 1582. $2,170 -> $2,170+N+SG
# ...
# 17398. infrared -> infrared+N+SG
# 17399. copings -> coping+N+PL
# 17400. playback -> playback+N+SG
# 17401. quotations -> quotation+N+PL
# 17402. octopus -> octopu+N+PL
# 17403. rage -> rage+N+SG
# 17404. overshoes -> overshoe+N+PL
# 17405. mrad -> mrad+N+SG
# 17406. belch -> belch+N+SG
# 17407. ingratitoode -> ingratitoode+N+SG
# 17408. grating -> grating+N+SG
# 17409. bang -> bang+N+SG
# 17410. asses -> ass+N+PL
# 17411. interchanges -> interchange+N+PL
# 17412. micelle -> micelle+N+SG
# 17413. parking -> parking+N+SG
# 17414. kenning -> kenning+N+SG
# 17415. alternation -> alternation+N+SG
# 17416. running -> running+N+SG
# 17417. appraisals -> appraisal+N+PL
# 17418. strivings -> striving+N+PL
# 17419. flint -> flint+N+SG
# 17420. **yg -> **yg+N+SG
# 17421. accomplishment -> accomplishment+N+SG
# 17422. reassurance -> reassurance+N+SG
# 17423. civilizations -> civilization+N+PL
# 17424. commentator -> commentator+N+SG
# 17425. brothers -> brother+N+PL
# 17426. diphosphopyridine -> diphosphopyridine+N+SG
# 17427. acid -> acid+N+SG
# 17428. auditorium -> auditorium+N+SG
# 17429. pompousness -> Invalid Word
# 17430. shinbone -> shinbone+N+SG
# 17431. splinters -> splinter+N+PL
# 17432. flowerpot -> flowerpot+N+SG
# 17433. calves -> calve+N+PL
# 17434. predicator -> predicator+N+SG
# 17435. realm -> realm+N+SG
# 17436. processes -> process+N+PL
# 17437. blockade -> blockade+N+SG
# 17438. amplitude -> amplitude+N+SG
# 17439. wrongdoing -> wrongdoing+N+SG
# 17440. refusal -> refusal+N+SG
# 17441. caliper -> caliper+N+SG
# 17442. glare -> glare+N+SG
# 17443. grub -> grub+N+SG
# 17444. battles -> battle+N+PL
# 17445. affections -> affection+N+PL
# 17446. archfool -> archfool+N+SG
# 17447. ignoramus -> ignoramu+N+PL
# 17448. interpretations -> interpretation+N+PL
# 17449. severalty -> severalty+N+SG
# 17450. warrants -> warrant+N+PL
# 17451. switching -> switching+N+SG
# 17452. statement -> statement+N+SG
# 17453. brawle -> brawle+N+SG
# 17454. saami's -> saami'+N+PL
# 17455. stagnation -> stagnation+N+SG
# 17456. $139.3 -> $139.3+N+SG
# 17457. contention -> contention+N+SG
# 17458. conquest -> conquest+N+SG
# 17459. defendant -> defendant+N+SG
# 17460. hopes -> hope+N+PL
# 17461. miracles -> miracle+N+PL
# 17462. epilogue -> epilogue+N+SG
# 17463. offense -> offense+N+SG
# 17464. ablation -> ablation+N+SG
# 17465. orderliness -> Invalid Word
# 17466. gig -> gig+N+SG
# 17467. rocket -> rocket+N+SG
# 17468. sheen -> sheen+N+SG
# 17469. spaceship -> spaceship+N+SG
# 17470. breakoff -> breakoff+N+SG
# 17471. $625,561 -> $625,561+N+SG
# 17472. ponds -> pond+N+PL
# 17473. vision -> vision+N+SG
# 17474. driveways -> driveway+N+PL
# 17475. banana -> banana+N+SG
# 17476. initials -> initial+N+PL
# 17477. whispering -> whispering+N+SG
# 17478. ghettos -> ghetto+N+PL
# 17479. dissenter -> dissenter+N+SG
# 17480. epicycle -> epicycle+N+SG
# 17481. porridge -> porridge+N+SG
# 17482. trot -> trot+N+SG
# 17483. pantheist -> pantheist+N+SG
# 17484. axis -> axi+N+PL
# 17485. diehards -> diehard+N+PL
# 17486. hasher -> hasher+N+SG
# 17487. brewers -> brewer+N+PL
# 17488. thyroid -> thyroid+N+SG
# 17489. adventure -> adventure+N+SG
# 17490. $2.98 -> $2.98+N+SG
# 17491. boastings -> boasting+N+PL
# 17492. forerunner -> forerunner+N+SG
# 17493. 6'.7 -> 6'.7+N+SG
# 17494. lyriist -> lyriist+N+SG
# 17495. dissociation -> dissociation+N+SG
# 17496. spacers -> spacer+N+PL
# 17497. dwellings -> dwelling+N+PL
# 17498. qualities -> quality+N+PL
# 17499. hut -> hut+N+SG
# 17500. stacks -> stack+N+PL
# 17501. proposition -> proposition+N+SG
# 17502. wax -> wax+N+SG
# 17503. profile -> profile+N+SG
# 17504. circumstance -> circumstance+N+SG
# 17505. suitor -> suitor+N+SG
# 17506. prop -> prop+N+SG
# 17507. bandits -> bandit+N+PL
# 17508. call -> call+N+SG
# 17509. respects -> respect+N+PL
# 17510. hydraulics -> hydraulic+N+PL
# 17511. bouts -> bout+N+PL
# 17512. snails -> snail+N+PL
# 17513. exacerbations -> exacerbation+N+PL
# 17514. nymphomaniac -> nymphomaniac+N+SG
# 17515. song -> song+N+SG
# 17516. sleeves -> sleeve+N+PL
# 17517. knot -> knot+N+SG
# 17518. appliances -> appliance+N+PL
# 17519. cyclorama -> cyclorama+N+SG
# 17520. baking -> baking+N+SG
# 17521. girth -> girth+N+SG
# 17522. cornbread -> cornbread+N+SG
# 17523. schooldays -> schoolday+N+PL
# 17524. assemblages -> assemblage+N+PL
# 17525. handmaiden -> handmaiden+N+SG
# 17526. yelling -> yelling+N+SG
# 17527. outbursts -> outburst+N+PL
# 17528. absinthe -> absinthe+N+SG
# 17529. detours -> detour+N+PL
# 17530. ma'am -> ma'am+N+SG
# 17531. shackles -> shackle+N+PL
# 17532. interludes -> interlude+N+PL
# 17533. hearse -> hearse+N+SG
# 17534. gauze -> gauze+N+SG
# 17535. signatures -> signature+N+PL
# 17536. data -> data+N+SG
# 17537. parables -> parable+N+PL
# 17538. visits -> visit+N+PL
# 17539. marketability -> marketability+N+SG
# 17540. decorator -> decorator+N+SG
# 17541. stiffening -> stiffening+N+SG
# 17542. effort -> effort+N+SG
# 17543. adjustment -> adjustment+N+SG
# 17544. cowman -> cowman+N+SG
# 17545. bookkeeping -> bookkeeping+N+SG
# 17546. enthusiast -> enthusiast+N+SG
# 17547. irritant -> irritant+N+SG
# 17548. assignments -> assignment+N+PL
# 17549. foraging -> foraging+N+SG
# 17550. cavern -> cavern+N+SG
# 17551. platoons -> platoon+N+PL
# 17552. hydrocarbon -> hydrocarbon+N+SG
# 17553. checkbook -> checkbook+N+SG
# 17554. inaccuracies -> inaccuracy+N+PL
# 17555. fishes -> fish+N+PL
# 17556. sketches -> sketch+N+PL
# 17557. riddance -> riddance+N+SG
# 17558. beams -> beam+N+PL
# 17559. extras -> extra+N+PL
# 17560. shortsightedness -> Invalid Word
# 17561. wetting -> wetting+N+SG
# 17562. cribs -> crib+N+PL
# 17563. spread -> spread+N+SG
# 17564. savior -> savior+N+SG
# 17565. workshop -> workshop+N+SG
# 17566. phosphorus -> phosphoru+N+PL
# 17567. eyesight -> eyesight+N+SG
# 17568. excursus -> excursu+N+PL
# 17569. scops -> scop+N+PL
# 17570. surprises -> surpris+N+PL
# 17571. aorta -> aorta+N+SG
# 17572. dagers -> dager+N+PL
# 17573. steak -> steak+N+SG
# 17574. poison -> poison+N+SG
# 17575. irradiation -> irradiation+N+SG
# 17576. sprouting -> sprouting+N+SG
# 17577. joys -> joy+N+PL
# 17578. helicopter -> helicopter+N+SG
# 17579. glum -> glum+N+SG
# 17580. booster -> booster+N+SG
# 17581. employers -> employer+N+PL
# 17582. depletion -> depletion+N+SG
# 17583. talent -> talent+N+SG
# 17584. kisses -> kiss+N+PL
# 17585. domesticity -> domesticity+N+SG
# 17586. substantiation -> substantiation+N+SG
# 17587. superiors -> superior+N+PL
# 17588. schoolboy -> schoolboy+N+SG
# 17589. fragrance -> fragrance+N+SG
# 17590. creep -> creep+N+SG
# 17591. depressions -> depression+N+PL
# 17592. meaning -> meaning+N+SG
# 17593. fingers -> finger+N+PL
# 17594. solitary -> solitary+N+SG
# 17595. enlightenment -> enlightenment+N+SG
# 17596. verve -> verve+N+SG
# 17597. quivers -> quiver+N+PL
# 17598. point -> point+N+SG
# 17599. colonnade -> colonnade+N+SG
# 17600. alignments -> alignment+N+PL
# 17601. preacher -> preacher+N+SG
# 17602. vents -> vent+N+PL
# 17603. fraternities -> fraternity+N+PL
# 17604. gardens -> garden+N+PL
# 17605. hyperplasia -> hyperplasia+N+SG
# 17606. throbbing -> throbbing+N+SG
# 17607. reduction -> reduction+N+SG
# 17608. tolerance -> tolerance+N+SG
# 17609. overpopulation -> overpopulation+N+SG
# 17610. $10.3 -> $10.3+N+SG
# 17611. internationalists -> internationalist+N+PL
# 17612. dashes -> dash+N+PL
# 17613. sable -> sable+N+SG
# 17614. baldness -> Invalid Word
# 17615. definitions -> definition+N+PL
# 17616. spleen -> spleen+N+SG
# 17617. fractions -> fraction+N+PL
# 17618. presidents -> president+N+PL
# 17619. hostages -> hostage+N+PL
# 17620. litigants -> litigant+N+PL
# 17621. spat -> spat+N+SG
# 17622. fundamentalism -> fundamentalism+N+SG
# 17623. therapists -> therapist+N+PL
# 17624. avarice -> avarice+N+SG
# 17625. trapdoors -> trapdoor+N+PL
# 17626. shelter -> shelter+N+SG
# 17627. spans -> span+N+PL
# 17628. panjandrum -> panjandrum+N+SG
# 17629. melancholy -> melancholy+N+SG
# 17630. pta -> pta+N+SG
# 17631. sforzando -> sforzando+N+SG
# 17632. mists -> mist+N+PL
# 17633. laborers -> laborer+N+PL
# 17634. soda -> soda+N+SG
# 17635. cutlass -> Invalid Word
# 17636. bone -> bone+N+SG
# 17637. trough -> trough+N+SG
# 17638. 1/2'' -> 1/2''+N+SG
# 17639. icc -> icc+N+SG
# 17640. huddle -> huddle+N+SG
# 17641. plasma -> plasma+N+SG
# 17642. scherzo -> scherzo+N+SG
# 17643. creaking -> creaking+N+SG
# 17644. harm -> harm+N+SG
# 17645. relatedness -> Invalid Word
# 17646. bluefish -> bluefish+N+SG
# 17647. storyteller -> storyteller+N+SG
# 17648. purpose -> purpose+N+SG
# 17649. neocortex -> neocortex+N+SG
# 17650. polynomials -> polynomial+N+PL
# 17651. baggage -> baggage+N+SG
# 17652. deference -> deference+N+SG
# 17653. bale -> bale+N+SG
# 17654. tract -> tract+N+SG
# 17655. warmth -> warmth+N+SG
# 17656. democracy -> democracy+N+SG
# 17657. mountain -> mountain+N+SG
# 17658. feedings -> feeding+N+PL
# 17659. republics -> republic+N+PL
# 17660. cathode -> cathode+N+SG
# 17661. toast -> toast+N+SG
# 17662. mosquitoes -> mosquitoe+N+PL
# 17663. scrapings -> scraping+N+PL
# 17664. throttle -> throttle+N+SG
# 17665. amount -> amount+N+SG
# 17666. magnetism -> magnetism+N+SG
# 17667. tan -> tan+N+SG
# 17668. myth -> myth+N+SG
# 17669. chisel -> chisel+N+SG
# 17670. treatise -> treatise+N+SG
# 17671. indication -> indication+N+SG
# 17672. provision -> provision+N+SG
# 17673. sheets -> sheet+N+PL
# 17674. abbreviations -> abbreviation+N+PL
# 17675. townsmen -> townsmen+N+SG
# 17676. pagoda -> pagoda+N+SG
# 17677. rot -> rot+N+SG
# 17678. human -> human+N+SG
# 17679. paraoxon -> paraoxon+N+SG
# 17680. tumbles -> tumble+N+PL
# 17681. states -> state+N+PL
# 17682. doubts -> doubt+N+PL
# 17683. spokesman -> spokesman+N+SG
# 17684. movers -> mover+N+PL
# 17685. break -> break+N+SG
# 17686. regiment -> regiment+N+SG
# 17687. patrolmen -> patrolmen+N+SG
# 17688. grades -> grade+N+PL
# 17689. clemency -> clemency+N+SG
# 17690. penman -> penman+N+SG
# 17691. identity -> identity+N+SG
# 17692. streetlight -> streetlight+N+SG
# 17693. interrelation -> interrelation+N+SG
# 17694. snivelings -> sniveling+N+PL
# 17695. percentage -> percentage+N+SG
# 17696. norad -> norad+N+SG
# 17697. washbowl -> washbowl+N+SG
# 17698. carbide -> carbide+N+SG
# 17699. speculator -> speculator+N+SG
# 17700. paratroopers -> paratrooper+N+PL
# 17701. expectancy -> expectancy+N+SG
# 17702. redwoods -> redwood+N+PL
# 17703. tee -> tee+N+SG
# 17704. rainstorm -> rainstorm+N+SG
# 17705. tenant -> tenant+N+SG
# 17706. oblige -> oblige+N+SG
# 17707. kiosk -> kiosk+N+SG
# 17708. ague -> ague+N+SG
# 17709. scrape -> scrape+N+SG
# 17710. foreknowledge -> foreknowledge+N+SG
# 17711. amorist -> amorist+N+SG
# 17712. extruder -> extruder+N+SG
# 17713. practitioners -> practitioner+N+PL
# 17714. longevity -> longevity+N+SG
# 17715. aviary -> aviary+N+SG
# 17716. barn -> barn+N+SG
# 17717. diagnosticians -> diagnostician+N+PL
# 17718. production -> production+N+SG
# 17719. enclaves -> enclave+N+PL
# 17720. millennia -> millennia+N+SG
# 17721. boast -> boast+N+SG
# 17722. tally -> tally+N+SG
# 17723. konga -> konga+N+SG
# 17724. greensward -> greensward+N+SG
# 17725. bodyguard -> bodyguard+N+SG
# 17726. showmen -> showmen+N+SG
# 17727. sum -> sum+N+SG
# 17728. externalization -> externalization+N+SG
# 17729. reharmonization -> reharmonization+N+SG
# 17730. progeny -> progeny+N+SG
# 17731. lieder -> lieder+N+SG
# 17732. dryness -> Invalid Word
# 17733. fertility -> fertility+N+SG
# 17734. sonny -> sonny+N+SG
# 17735. disrepute -> disrepute+N+SG
# 17736. intelligence -> intelligence+N+SG
# 17737. $85 -> $85+N+SG
# 17738. technicalities -> technicality+N+PL
# 17739. starvation -> starvation+N+SG
# 17740. houseboats -> houseboat+N+PL
# 17741. concerts -> concert+N+PL
# 17742. convulsions -> convulsion+N+PL
# 17743. nutrition -> nutrition+N+SG
# 17744. troubie -> troubie+N+SG
# 17745. uptrend -> uptrend+N+SG
# 17746. breakaway -> breakaway+N+SG
# 17747. bayonets -> bayonet+N+PL
# 17748. holdups -> holdup+N+PL
# 17749. disbelief -> disbelief+N+SG
# 17750. veils -> veil+N+PL
# 17751. sari -> sari+N+SG
# 17752. stockbroker -> stockbroker+N+SG
# 17753. graces -> grace+N+PL
# 17754. subsections -> subsection+N+PL
# 17755. phosphates -> phosphate+N+PL
# 17756. telephone -> telephone+N+SG
# 17757. baskets -> basket+N+PL
# 17758. sound -> sound+N+SG
# 17759. bogeys -> bogey+N+PL
# 17760. capitulation -> capitulation+N+SG
# 17761. academeh -> academeh+N+SG
# 17762. shoelaces -> shoelace+N+PL
# 17763. parishioners -> parishioner+N+PL
# 17764. procreativity -> procreativity+N+SG
# 17765. reformism -> reformism+N+SG
# 17766. bellwethers -> bellwether+N+PL
# 17767. 2.295% -> 2.295%+N+SG
# 17768. 0.85% -> 0.85%+N+SG
# 17769. sprinkle -> sprinkle+N+SG
# 17770. couples -> couple+N+PL
# 17771. undoing -> undoing+N+SG
# 17772. blooming -> blooming+N+SG
# 17773. mispronunciation -> mispronunciation+N+SG
# 17774. singers -> singer+N+PL
# 17775. thug -> thug+N+SG
# 17776. mantlepiece -> mantlepiece+N+SG
# 17777. padding -> padding+N+SG
# 17778. run -> run+N+SG
# 17779. enthusiasts -> enthusiast+N+PL
# 17780. errand -> errand+N+SG
# 17781. makers -> maker+N+PL
# 17782. gaucheries -> gauchery+N+PL
# 17783. madrigal -> madrigal+N+SG
# 17784. gallery -> gallery+N+SG
# 17785. forearms -> forearm+N+PL
# 17786. saying -> saying+N+SG
# 17787. nrlda's -> nrlda'+N+PL
# 17788. blow -> blow+N+SG
# 17789. scan -> scan+N+SG
# 17790. cheek -> cheek+N+SG
# 17791. birth -> birth+N+SG
# 17792. seaside -> seaside+N+SG
# 17793. $12,500 -> $12,500+N+SG
# 17794. $157,460 -> $157,460+N+SG
# 17795. helper -> helper+N+SG
# 17796. procreation -> procreation+N+SG
# 17797. tales -> tale+N+PL
# 17798. inlet -> inlet+N+SG
# 17799. cityscapes -> cityscape+N+PL
# 17800. baying -> baying+N+SG
# 17801. stickpin -> stickpin+N+SG
# 17802. quadrupling -> quadrupling+N+SG
# 17803. intrigue -> intrigue+N+SG
# 17804. tonalities -> tonality+N+PL
# 17805. notebook -> notebook+N+SG
# 17806. microphone -> microphone+N+SG
# 17807. railroader -> railroader+N+SG
# 17808. $75,000,000 -> $75,000,000+N+SG
# 17809. prey -> prey+N+SG
# 17810. politico -> politico+N+SG
# 17811. representations -> representation+N+PL
# 17812. artisans -> artisan+N+PL
# 17813. authors -> author+N+PL
# 17814. inventions -> invention+N+PL
# 17815. hande -> hande+N+SG
# 17816. complexities -> complexity+N+PL
# 17817. alcohols -> alcohol+N+PL
# 17818. $2,300 -> $2,300+N+SG
# 17819. arteriolosclerosis -> arteriolosclerosi+N+PL
# 17820. monitor -> monitor+N+SG
# 17821. antithesis -> antithesi+N+PL
# 17822. boomerang -> boomerang+N+SG
# 17823. patients -> patient+N+PL
# 17824. parisology -> parisology+N+SG
# 17825. climate -> climate+N+SG
# 17826. 86% -> 86%+N+SG
# 17827. $14.00 -> $14.00+N+SG
# 17828. tangency -> tangency+N+SG
# 17829. colony -> colony+N+SG
# 17830. fella -> fella+N+SG
# 17831. ire -> ire+N+SG
# 17832. nugget -> nugget+N+SG
# 17833. cottages -> cottage+N+PL
# 17834. background -> background+N+SG
# 17835. dowel -> dowel+N+SG
# 17836. siege -> siege+N+SG
# 17837. 47.1% -> 47.1%+N+SG
# 17838. geology -> geology+N+SG
# 17839. courtier -> courtier+N+SG
# 17840. desirability -> desirability+N+SG
# 17841. consideration -> consideration+N+SG
# 17842. green -> green+N+SG
# 17843. aryl -> aryl+N+SG
# 17844. hint -> hint+N+SG
# 17845. polish -> polish+N+SG
# 17846. bag -> bag+N+SG
# 17847. fooling -> fooling+N+SG
# 17848. troubles -> trouble+N+PL
# 17849. charcoal -> charcoal+N+SG
# 17850. sites -> site+N+PL
# 17851. dynamite -> dynamite+N+SG
# 17852. syrup -> syrup+N+SG
# 17853. kitchens -> kitchen+N+PL
# 17854. cumara -> cumara+N+SG
# 17855. aloofness -> Invalid Word
# 17856. arsines -> arsine+N+PL
# 17857. restaurants -> restaurant+N+PL
# 17858. charity -> charity+N+SG
# 17859. library -> library+N+SG
# 17860. consultations -> consultation+N+PL
# 17861. auto -> auto+N+SG
# 17862. prolixity -> prolixity+N+SG
# 17863. enforcement -> enforcement+N+SG
# 17864. gut -> gut+N+SG
# 17865. millimeter -> millimeter+N+SG
# 17866. sight -> sight+N+SG
# 17867. warranty -> warranty+N+SG
# 17868. interregnum -> interregnum+N+SG
# 17869. composition -> composition+N+SG
# 17870. ring -> ring+N+SG
# 17871. bailiff -> bailiff+N+SG
# 17872. sportswriter -> sportswriter+N+SG
# 17873. nurture -> nurture+N+SG
# 17874. invoices -> invoice+N+PL
# 17875. laudanum -> laudanum+N+SG
# 17876. spirit -> spirit+N+SG
# 17877. furs -> fur+N+PL
# 17878. average -> average+N+SG
# 17879. embassies -> embassy+N+PL
# 17880. airports -> airport+N+PL
# 17881. ooh -> ooh+N+SG
# 17882. vacations -> vacation+N+PL
# 17883. comings -> coming+N+PL
# 17884. rasp -> rasp+N+SG
# 17885. punditry -> punditry+N+SG
# 17886. $15,000 -> $15,000+N+SG
# 17887. singularity -> singularity+N+SG
# 17888. rehearsals -> rehearsal+N+PL
# 17889. socialist -> socialist+N+SG
# 17890. sequins -> sequin+N+PL
# 17891. gangland -> gangland+N+SG
# 17892. homesteads -> homestead+N+PL
