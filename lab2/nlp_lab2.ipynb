# %%
import re

def valid_eng_word(word):
    pattern = r'\b[a-z]+\b'  # start and end with lowercase letters only
    accept = re.fullmatch(pattern, word)
    if accept:
        print(accept.string,'Accepted')
    else:
        print('Not accepted')

# %%
valid_eng_word('dog'),
valid_eng_word('cat'),
valid_eng_word('a  '),
valid_eng_word('rani0')
valid_eng_word(' cat'),
valid_eng_word('_at')
# Out:
# dog Accepted
# cat Accepted
# Not accepted
# Not accepted
# Not accepted
# Not accepted

# %%
conda install -c conda-forge graphviz
# Out:
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
#  - anaconda
# Platform: win-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\rani\anaconda3\envs\machinelearning
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.8.3   |       h4c7d964_0         151 KB  conda-forge
#     cairo-1.18.4               |       he9e932c_0         637 KB
#     certifi-2025.8.3           |     pyhd8ed1ab_0         155 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.14.2          |       hbde0cde_0         186 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freeglut-3.4.0             |       h8a1e904_1         134 KB
#     freetype-2.13.3            |       h0620614_0         554 KB
#     fribidi-1.0.10             |       h8d14728_0          63 KB  conda-forge
#     getopt-win32-0.1           |       h6a83c73_3          26 KB  conda-forge
#     graphite2-1.3.14           |       hac47afa_2          94 KB  conda-forge
#     graphviz-11.0.0            |       h09e431a_0         1.1 MB  conda-forge
#     gts-0.7.6                  |       h6b5321d_4         184 KB  conda-forge
#     harfbuzz-10.2.0            |       he2f9f60_1         1.2 MB
#     lerc-4.0.0                 |       h6470a55_1         161 KB  conda-forge
#     libdeflate-1.22            |       h2466b09_0         152 KB  conda-forge
#     libexpat-2.7.1             |       hac47afa_0         138 KB  conda-forge
#     libgd-2.3.3                |       hd9a01a5_4         264 KB
#     libglib-2.84.2             |       h405b238_0         1.6 MB
#     libiconv-1.18              |       hc1393d2_2         681 KB  conda-forge
#     libtiff-4.7.0              |       h404307b_0         1.1 MB
#     libwebp-1.6.0              |       h4d5522a_0          71 KB  conda-forge
#     libwebp-base-1.6.0         |       h4d5522a_0         273 KB  conda-forge
#     libzlib-1.2.13             |       h2466b09_6          55 KB  conda-forge
#     openssl-3.5.2              |       h725018a_0         8.8 MB  conda-forge
#     pango-1.50.14              |       h07c897b_2         432 KB  conda-forge
#     pcre2-10.42                |       h17e33f8_0         860 KB  conda-forge
#     pixman-0.46.4              |       h5112557_1         530 KB  conda-forge
#     ucrt-10.0.26100.0          |       h57928b3_0         678 KB  conda-forge
#     vc14_runtime-14.44.35208   |      h818238b_31         666 KB  conda-forge
#     vcomp14-14.44.35208        |      h818238b_31         111 KB  conda-forge
#     vs2015_runtime-14.44.35208 |      h38c0c73_31          18 KB  conda-forge
#     zlib-1.2.13                |       h2466b09_6         105 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        23.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              pkgs/main/win-64::cairo-1.18.4-he9e932c_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/win-64::fontconfig-2.14.2-hbde0cde_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freeglut           pkgs/main/win-64::freeglut-3.4.0-h8a1e904_1
#   freetype           pkgs/main/win-64::freetype-2.13.3-h0620614_0
#   fribidi            conda-forge/win-64::fribidi-1.0.10-h8d14728_0
#   getopt-win32       conda-forge/win-64::getopt-win32-0.1-h6a83c73_3
#   graphite2          conda-forge/win-64::graphite2-1.3.14-hac47afa_2
#   graphviz           conda-forge/win-64::graphviz-11.0.0-h09e431a_0
#   gts                conda-forge/win-64::gts-0.7.6-h6b5321d_4
#   harfbuzz           pkgs/main/win-64::harfbuzz-10.2.0-he2f9f60_1
#   lerc               conda-forge/win-64::lerc-4.0.0-h6470a55_1
#   libdeflate         conda-forge/win-64::libdeflate-1.22-h2466b09_0
#   libexpat           conda-forge/win-64::libexpat-2.7.1-hac47afa_0
#   libgd              pkgs/main/win-64::libgd-2.3.3-hd9a01a5_4
#   libglib            pkgs/main/win-64::libglib-2.84.2-h405b238_0
#   libiconv           conda-forge/win-64::libiconv-1.18-hc1393d2_2
#   libtiff            pkgs/main/win-64::libtiff-4.7.0-h404307b_0
#   libwebp            conda-forge/win-64::libwebp-1.6.0-h4d5522a_0
#   libwebp-base       conda-forge/win-64::libwebp-base-1.6.0-h4d5522a_0
#   libzlib            conda-forge/win-64::libzlib-1.2.13-h2466b09_6
#   pango              conda-forge/win-64::pango-1.50.14-h07c897b_2
#   pcre2              conda-forge/win-64::pcre2-10.42-h17e33f8_0
#   pixman             conda-forge/win-64::pixman-0.46.4-h5112557_1
#   ucrt               conda-forge/win-64::ucrt-10.0.26100.0-h57928b3_0
#   vc14_runtime       conda-forge/win-64::vc14_runtime-14.44.35208-h818238b_31
#   vcomp14            conda-forge/win-64::vcomp14-14.44.35208-h818238b_31
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda/win-64::ca-certificates-2025~ --> conda-forge/noarch::ca-certificates-2025.8.3-h4c7d964_0
#   certifi            anaconda/win-64::certifi-2025.4.26-py~ --> conda-forge/noarch::certifi-2025.8.3-pyhd8ed1ab_0
#   openssl               anaconda::openssl-3.0.16-h3f729d1_0 --> conda-forge::openssl-3.5.2-h725018a_0
#   vs2015_runtime     anaconda::vs2015_runtime-14.42.34433-~ --> conda-forge::vs2015_runtime-14.44.35208-h38c0c73_31
#   zlib                     anaconda::zlib-1.2.13-h8cc25b3_1 --> conda-forge::zlib-1.2.13-h2466b09_6
#
#
#
# Downloading and Extracting Packages: ...working...
# openssl-3.5.2        | 8.8 MB    |            |   0%
#
# libglib-2.84.2       | 1.6 MB    |            |   0%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |            |   0%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    |            |   0%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    |            |   0%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    |            |   0%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    |            |   0%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    |            |   0%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.6.0   | 273 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 186 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libglib-2.84.2       | 1.6 MB    |            |   1%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | 1          |   1%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | 5          |   5%
#
# libglib-2.84.2       | 1.6 MB    | 3          |   4%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | 1          |   1%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | 2          |   3%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 1          |   1%
# openssl-3.5.2        | 8.8 MB    |            |   0%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | #          |  11%
#
# libglib-2.84.2       | 1.6 MB    | 7          |   8%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | 8          |   8%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 4          |   4%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ##1        |  21%
#
# libglib-2.84.2       | 1.6 MB    | #1         |  12%
#
# libglib-2.84.2       | 1.6 MB    | #4         |  15%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | #1         |  11%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ##6        |  26%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 6          |   6%
# openssl-3.5.2        | 8.8 MB    |            |   1%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | #8         |  18%
#
# libglib-2.84.2       | 1.6 MB    | #8         |  19%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 8          |   8%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ####2      |  42%
#
# libglib-2.84.2       | 1.6 MB    | ##4        |  25%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | #####1     |  52%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ##3        |  24%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #3         |  13%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ######3    |  63%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ###3       |  34%
# openssl-3.5.2        | 8.8 MB    | 2          |   2%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ###9       |  39%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #6         |  16%
# openssl-3.5.2        | 8.8 MB    | 2          |   3%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##         |  20%
#
# libglib-2.84.2       | 1.6 MB    | ##7        |  28%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ####6      |  47%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##9        |  29%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | #######2   |  73%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ######     |  61%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ########1  |  82%
#
# libglib-2.84.2       | 1.6 MB    | ###4       |  34%
# openssl-3.5.2        | 8.8 MB    | 3          |   4%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###3       |  33%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###6       |  36%
# openssl-3.5.2        | 8.8 MB    | 4          |   4%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ######7    |  68%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####2      |  42%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | #######7   |  78%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #####      |  51%
# openssl-3.5.2        | 8.8 MB    | 4          |   5%
#
# libglib-2.84.2       | 1.6 MB    | ###7       |  37%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #####5     |  56%
# openssl-3.5.2        | 8.8 MB    | 6          |   6%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ########9  |  90%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | #########1 |  92%
#
# libglib-2.84.2       | 1.6 MB    | ####2      |  42%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ########## | 100%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | #########8 |  99%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ########## | 100%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ######     |  61%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ######7    |  68%
# openssl-3.5.2        | 8.8 MB    | 6          |   7%
#
# libglib-2.84.2       | 1.6 MB    | ####5      |  45%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    | 1          |   2%
#
# libglib-2.84.2       | 1.6 MB    | ####8      |  48%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    | ##7        |  28%
#
# libglib-2.84.2       | 1.6 MB    | #####1     |  51%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ########## | 100%
#
#
#
# harfbuzz-10.2.0      | 1.2 MB    | ########## | 100%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########   |  81%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | #          |  10%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #########  |  91%
#
# libglib-2.84.2       | 1.6 MB    | #####4     |  54%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #########7 |  97%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    | ####2      |  43%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | #5         |  16%
# openssl-3.5.2        | 8.8 MB    | 7          |   7%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
# libglib-2.84.2       | 1.6 MB    | #####7     |  57%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    | #######    |  71%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ##1        |  22%
# openssl-3.5.2        | 8.8 MB    | 7          |   8%
#
# libglib-2.84.2       | 1.6 MB    | ######     |  60%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ##8        |  29%
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
# libglib-2.84.2       | 1.6 MB    | ######3    |  63%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ###4       |  34%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    | ########7  |  87%
#
#
#
#
# graphviz-11.0.0      | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | 2          |   2%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | 9          |   9%
# openssl-3.5.2        | 8.8 MB    | 8          |   8%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ####4      |  44%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    | ########## | 100%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ####       |  40%
#
# libglib-2.84.2       | 1.6 MB    | ######6    |  66%
# openssl-3.5.2        | 8.8 MB    | 8          |   9%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | #####1     |  51%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | #####6     |  56%
#
# libglib-2.84.2       | 1.6 MB    | #######3   |  74%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    | 2          |   2%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    | ###7       |  38%
# openssl-3.5.2        | 8.8 MB    | 9          |   9%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ######1    |  62%
#
# libglib-2.84.2       | 1.6 MB    | #######6   |  77%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | #########3 |  94%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    | #####8     |  59%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | #######    |  70%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    | #######7   |  78%
#
# libglib-2.84.2       | 1.6 MB    | #######9   |  80%
# openssl-3.5.2        | 8.8 MB    | 9          |  10%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | #######6   |  76%
#
# libglib-2.84.2       | 1.6 MB    | ########2  |  83%
# openssl-3.5.2        | 8.8 MB    | #          |  10%
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ########## | 100%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ########   |  80%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    | #########4 |  94%
#
#
#
#
#
#
# pcre2-10.42          | 860 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    | ########## | 100%
#
# libglib-2.84.2       | 1.6 MB    | ########5  |  86%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | 2          |   2%
# openssl-3.5.2        | 8.8 MB    | #          |  11%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ########9  |  89%
#
#
#
#
#
#
#
#
# libiconv-1.18        | 681 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ###        |  31%
#
# libglib-2.84.2       | 1.6 MB    | ########7  |  88%
# openssl-3.5.2        | 8.8 MB    | #          |  11%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | #########4 |  95%
#
# libglib-2.84.2       | 1.6 MB    | #########  |  91%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | #########9 |  99%
# openssl-3.5.2        | 8.8 MB    | #1         |  11%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ####4      |  45%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | 2          |   2%
#
# libglib-2.84.2       | 1.6 MB    | #########6 |  97%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ######6    |  66%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | #2         |  12%
# openssl-3.5.2        | 8.8 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | ###8       |  38%
#
# libglib-2.84.2       | 1.6 MB    | #########9 | 100%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | #########1 |  92%
#
# libglib-2.84.2       | 1.6 MB    | ########## | 100%
# openssl-3.5.2        | 8.8 MB    | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | 2          |   3%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ########## | 100%
# openssl-3.5.2        | 8.8 MB    | #2         |  13%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | ####8      |  48%
#
# libglib-2.84.2       | 1.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | #######2   |  72%
# openssl-3.5.2        | 8.8 MB    | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | ########6  |  86%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | ##         |  20%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | #########8 |  98%
# openssl-3.5.2        | 8.8 MB    | #3         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | #####      |  50%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | ##7        |  27%
# openssl-3.5.2        | 8.8 MB    | #3         |  14%
#
#
#
#
#
#
#
#
#
# ucrt-10.0.26100.0    | 678 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | #####7     |  58%
# openssl-3.5.2        | 8.8 MB    | #4         |  14%
#
#
#
#
#
#
#
#
#
#
# vc14_runtime-14.44.3 | 666 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | ####       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | #####7     |  57%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | ######7    |  68%
# openssl-3.5.2        | 8.8 MB    | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | ##5        |  26%
# openssl-3.5.2        | 8.8 MB    | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | #######5   |  75%
#
#
#
#
#
# libtiff-4.7.0        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | ####       |  41%
# openssl-3.5.2        | 8.8 MB    | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | ########   |  80%
# openssl-3.5.2        | 8.8 MB    | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | ########1  |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.4        | 530 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | #######4   |  74%
# openssl-3.5.2        | 8.8 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | 4          |   4%
# openssl-3.5.2        | 8.8 MB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.6.0   | 273 KB    | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.6.0   | 273 KB    | ##9        |  29%
# openssl-3.5.2        | 8.8 MB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.18.4         | 637 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.6.0   | 273 KB    | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pango-1.50.14        | 432 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    | ###6       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.6.0   | 273 KB    | ########8  |  88%
# openssl-3.5.2        | 8.8 MB    | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.6.0   | 273 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    | ######     |  61%
# openssl-3.5.2        | 8.8 MB    | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    | #########1 |  91%
# openssl-3.5.2        | 8.8 MB    | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# freetype-2.13.3      | 554 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.6.0   | 273 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 264 KB    | ########## | 100%
# openssl-3.5.2        | 8.8 MB    | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 186 KB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 186 KB    | ###4       |  34%
# openssl-3.5.2        | 8.8 MB    | #9         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 186 KB    | ########## | 100%
# openssl-3.5.2        | 8.8 MB    | #9         |  20%
# openssl-3.5.2        | 8.8 MB    | #9         |  20%
# openssl-3.5.2        | 8.8 MB    | ##         |  20%
# openssl-3.5.2        | 8.8 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 186 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fontconfig-2.14.2    | 186 KB    | ########## | 100%
# openssl-3.5.2        | 8.8 MB    | ##1        |  21%
# openssl-3.5.2        | 8.8 MB    | ##1        |  21%
# openssl-3.5.2        | 8.8 MB    | ##1        |  22%
# openssl-3.5.2        | 8.8 MB    | ##2        |  22%
# openssl-3.5.2        | 8.8 MB    | ##2        |  22%
# openssl-3.5.2        | 8.8 MB    | ##2        |  23%
# openssl-3.5.2        | 8.8 MB    | ##3        |  23%
# openssl-3.5.2        | 8.8 MB    | ##3        |  23%
# openssl-3.5.2        | 8.8 MB    | ##3        |  24%
# openssl-3.5.2        | 8.8 MB    | ##4        |  25%
# openssl-3.5.2        | 8.8 MB    | ##5        |  25%
# openssl-3.5.2        | 8.8 MB    | ##5        |  26%
# openssl-3.5.2        | 8.8 MB    | ##6        |  26%
# openssl-3.5.2        | 8.8 MB    | ##6        |  27%
# openssl-3.5.2        | 8.8 MB    | ##7        |  27%
# openssl-3.5.2        | 8.8 MB    | ##7        |  28%
# openssl-3.5.2        | 8.8 MB    | ##8        |  28%
# openssl-3.5.2        | 8.8 MB    | ##8        |  29%
# openssl-3.5.2        | 8.8 MB    | ##9        |  29%
# openssl-3.5.2        | 8.8 MB    | ###        |  30%
# openssl-3.5.2        | 8.8 MB    | ###        |  31%
# openssl-3.5.2        | 8.8 MB    | ###1       |  31%
# openssl-3.5.2        | 8.8 MB    | ###1       |  32%
# openssl-3.5.2        | 8.8 MB    | ###2       |  33%
# openssl-3.5.2        | 8.8 MB    | ###3       |  34%
# openssl-3.5.2        | 8.8 MB    | ###4       |  34%
# openssl-3.5.2        | 8.8 MB    | ###5       |  35%
# openssl-3.5.2        | 8.8 MB    | ###6       |  36%
# openssl-3.5.2        | 8.8 MB    | ###7       |  38%
# openssl-3.5.2        | 8.8 MB    | ###9       |  39%
# openssl-3.5.2        | 8.8 MB    | ###9       |  40%
# openssl-3.5.2        | 8.8 MB    | ####       |  41%
# openssl-3.5.2        | 8.8 MB    | ####1      |  41%
# openssl-3.5.2        | 8.8 MB    | ####2      |  42%
# openssl-3.5.2        | 8.8 MB    | ####2      |  43%
# openssl-3.5.2        | 8.8 MB    | ####3      |  44%
# openssl-3.5.2        | 8.8 MB    | ####4      |  45%
# openssl-3.5.2        | 8.8 MB    | ####5      |  46%
# openssl-3.5.2        | 8.8 MB    | ####6      |  47%
# openssl-3.5.2        | 8.8 MB    | ####7      |  48%
# openssl-3.5.2        | 8.8 MB    | ####9      |  50%
# openssl-3.5.2        | 8.8 MB    | #####      |  51%
# openssl-3.5.2        | 8.8 MB    | #####1     |  52%
# openssl-3.5.2        | 8.8 MB    | #####2     |  53%
# openssl-3.5.2        | 8.8 MB    | #####3     |  54%
# openssl-3.5.2        | 8.8 MB    | #####4     |  54%
# openssl-3.5.2        | 8.8 MB    | #####5     |  55%
# openssl-3.5.2        | 8.8 MB    | #####6     |  56%
# openssl-3.5.2        | 8.8 MB    | #####7     |  57%
# openssl-3.5.2        | 8.8 MB    | #####8     |  58%
# openssl-3.5.2        | 8.8 MB    | #####9     |  59%
# openssl-3.5.2        | 8.8 MB    | ######     |  60%
# openssl-3.5.2        | 8.8 MB    | ######1    |  61%
# openssl-3.5.2        | 8.8 MB    | ######2    |  63%
# openssl-3.5.2        | 8.8 MB    | ######3    |  64%
# openssl-3.5.2        | 8.8 MB    | ######4    |  65%
# openssl-3.5.2        | 8.8 MB    | ######6    |  67%
# openssl-3.5.2        | 8.8 MB    | ######8    |  68%
# openssl-3.5.2        | 8.8 MB    | ######9    |  69%
# openssl-3.5.2        | 8.8 MB    | #######    |  70%
# openssl-3.5.2        | 8.8 MB    | #######1   |  71%
# openssl-3.5.2        | 8.8 MB    | #######2   |  73%
# openssl-3.5.2        | 8.8 MB    | #######3   |  74%
# openssl-3.5.2        | 8.8 MB    | #######4   |  75%
# openssl-3.5.2        | 8.8 MB    | #######7   |  77%
# openssl-3.5.2        | 8.8 MB    | #######8   |  79%
# openssl-3.5.2        | 8.8 MB    | ########   |  80%
# openssl-3.5.2        | 8.8 MB    | ########1  |  81%
# openssl-3.5.2        | 8.8 MB    | ########2  |  82%
# openssl-3.5.2        | 8.8 MB    | ########3  |  84%
# openssl-3.5.2        | 8.8 MB    | ########4  |  85%
# openssl-3.5.2        | 8.8 MB    | ########6  |  86%
# openssl-3.5.2        | 8.8 MB    | ########7  |  87%
# openssl-3.5.2        | 8.8 MB    | ########8  |  89%
# openssl-3.5.2        | 8.8 MB    | ########9  |  90%
# openssl-3.5.2        | 8.8 MB    | #########  |  91%
# openssl-3.5.2        | 8.8 MB    | #########2 |  92%
# openssl-3.5.2        | 8.8 MB    | #########4 |  94%
# openssl-3.5.2        | 8.8 MB    | #########5 |  95%
# openssl-3.5.2        | 8.8 MB    | #########6 |  97%
# openssl-3.5.2        | 8.8 MB    | #########8 |  98%
# openssl-3.5.2        | 8.8 MB    | #########9 |  99%
# openssl-3.5.2        | 8.8 MB    | ########## | 100%
# openssl-3.5.2        | 8.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install automathon and graphviz
# !pip install automathon graphviz

from automathon import DFA
from IPython.display import Image

# States
Q = {'q0', 'q1', 'q_dead'}

# Alphabet
sigma = set([chr(c) for c in range(ord('a'), ord('z')+1)] + ['other'])

# Transition function
delta = {
    'q0': dict(**{ch: 'q1' for ch in [chr(c) for c in range(ord('a'), ord('z')+1)]},
               **{'other': 'q_dead'}),
    'q1': dict(**{ch: 'q1' for ch in [chr(c) for c in range(ord('a'), ord('z')+1)]},
               **{'other': 'q_dead'}),
    'q_dead': {ch: 'q_dead' for ch in sigma}
}

# Start state
q0 = 'q0'

# Final states
F = {'q1'}

# Create DFA
dfa = DFA(Q, sigma, delta, q0, F)

# View DFA (this will create "dfa.gv.png")
dfa.view("dfa")

# Display DFA diagram
Image(filename="dfa.gv.png")

# Function to classify words
def classify(word):
    if not word:
        return "Not Accepted"
    if not ('a' <= word[0] <= 'z'):
        return "Not Accepted"
    for ch in word:
        if not ('a' <= ch <= 'z'):
            return "Not Accepted"
    return "Accepted"

# Test words
test_words = ["cat", "dog", "a", "zebra", "dog1", "1dog", "DogHouse", "Dog_house", " cats"]
for w in test_words:
    print(f"{w} -> {classify(w)}")
# Out:
# Requirement already satisfied: automathon in c:\users\rani\anaconda3\envs\machinelearning\lib\site-packages (0.0.15)
# Requirement already satisfied: graphviz in c:\users\rani\anaconda3\envs\machinelearning\lib\site-packages (0.16)
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# cat -> Accepted
# dog -> Accepted
# a -> Accepted
# zebra -> Accepted
# dog1 -> Not Accepted
# 1dog -> Not Accepted
# DogHouse -> Not Accepted
# Dog_house -> Not Accepted
#  cats -> Not Accepted

# %%
import os

# Define input and output alphabets
input_alphabet = set("abcdefghijklmnopqrstuvwxyz")
output_alphabet = input_alphabet.union({"+N+SG", "+N+PL"})

# Define states
states = {
    "START",       # start reading the word
    "STEM",        # reading root letters
    "END_S",       # possible plural S
    "END_ES",      # plural ES
    "END_IES",     # plural IES
    "FINAL_SG",    # singular accept state
    "FINAL_PL"     # plural accept state
}
start_state = "START"
final_states = {"FINAL_SG", "FINAL_PL"}

# Define transitions: (state, input) -> (next_state, output)
transitions = {}

# Generic letter reading (build stem)
for ch in input_alphabet:
    transitions[("START", ch)] = ("STEM", ch)
    transitions[("STEM", ch)] = ("STEM", ch)

# Rule 1: E insertion after -s, -z, -x, -ch, -sh before adding "es"
# We'll detect these endings in the FST
special_es_endings = ["s", "z", "x"]
special_es_pairs = ["ch", "sh"]

# Rule 2: Y replacement (consonant + y → ies)
# Will handle in code logic (needs context: prev char consonant)

# Rule 3: S addition (default plural rule)

def run_fst(word):
    # First, handle plural vs singular classification manually
    if word in input_alphabet:
        return "Invalid Word"  # too short

    # Singular case: if it's in our noun list and no plural ending
    if not (word.endswith("s") or word.endswith("es") or word.endswith("ies")):
        return f"{word}+N+SG"

    # Plural cases:
    # Case 1: Ends with 'ies' → Y replacement
    if word.endswith("ies") and len(word) > 3:
        stem = word[:-3] + "y"
        # Ensure before 'y' is a consonant
        if stem[-2] not in "aeiou":
            return f"{stem}+N+PL"
        else:
            return "Invalid Word"

    # Case 2: Ends with 'es' and matches E-insertion rule
    if word.endswith("es"):
        stem = word[:-2]
        if any(stem.endswith(e) for e in special_es_endings) or any(stem.endswith(e) for e in special_es_pairs):
            return f"{stem}+N+PL"
        

    # Case 3: Ends with 's' → default plural
    if word.endswith("s"):
        stem = word[:-1]
        # reject if stem should have had 'es'
        if any(stem.endswith(e) for e in special_es_endings) or any(stem.endswith(e) for e in special_es_pairs):
            return "Invalid Word"
        # reject if stem should have had 'ies'
        if stem.endswith("y") and stem[-2] not in "aeiou":
            return "Invalid Word"
        return f"{stem}+N+PL"

    return "Invalid Word"



lexicon = set()    #unordered
if os.path.exists("brown_nouns.txt"):
        with open('brown_nouns.txt', "r") as f_in, open('output.txt', "w") as f_out:
            for line in f_in:
                word = line.strip().lower()
                if not word:
                    continue
                output = run_fst(word)
                f_out.write(f"{word} = {output}\n")

#print(f"associates-> {run_fst('associates')}")

# %%
from graphviz import Digraph

def visualize_fst():
    dot = Digraph(comment='Plural Morphology FST')

    # States
    states = ["START",       # start reading the word
    "STEM",        # reading root letters
    "END_S",       # possible plural S
    "END_ES",      # plural ES
    "END_IES",     # plural IES
    "FINAL_SG",    # singular accept state
    "FINAL_PL" ]
    final_states = ["FINAL_SG",    # singular accept state
    "FINAL_PL" ]

    # Add states to graph
    for s in states:
        if s in final_states:
            dot.node(s, s, shape='doublecircle')
        else:
            dot.node(s, s)

    # Transitions from q0
    dot.edge('START', 'STEM', label='s / ε')
    dot.edge('START', 'STEM', label='a–z except s / copy letter')

    # Transitions from q_s
    dot.edge('STEM', 'END_ES', label='e / ε')
    dot.edge('STEM', 'END_IES', label='i / ε')
    dot.edge('STEM', 'FINAL_PL', label='a–z except e,i,x,z,s,h / copy letter')

    # Transitions from q_se
    dot.edge('END_ES', 'FINAL_PL', label='s,x,z,o / copy letter')
    dot.edge('END_ES', 'FINAL_PL', label='h + lookahead c or s / copy ch or sh')
    #dot.edge('END_ES', 'q_dead', label='others / ε')

    # Transitions from q_sei
    dot.edge('END_IES', 'FINAL_PL', label='consonant / copy letter')
    #dot.edge('END_IES', 'q_dead', label='vowel / ε')

    # Copy plural states transitions (loop to self)
    dot.edge('FINAL_PL', 'FINAL_PL', label='a–z / copy letter')
    dot.edge('FINAL_PL', 'FINAL_PL', label='a–z / copy letter')

    # Copy singular state transitions (loop to self)
    dot.edge('FINAL_SG', 'FINAL_SG', label='a–z / copy letter')

    # Dead state loop
    #dot.edge('q_dead', 'q_dead', label='any / ε')

    # You can add labels for final outputs on final states
    dot.node('FINAL_PL', 'FINAL_PL\n(final +N+PL)', shape='doublecircle', color='black')
    dot.node('FINAL_PL', 'FINAL_PL\n(final +N+PL)', shape='doublecircle', color='black')
    dot.node('FINAL_SG', 'FINAL_SG\n(final +N+SG)', shape='doublecircle', color='black')

    # Render to a file (PDF/PNG/SVG)
    dot.render('fst_plural_morphology', format='png', cleanup=True)
    print("FST diagram saved as fst_plural_morphology.png")

visualize_fst()
# Out:
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Warning: no value for width of non-ASCII character 206. Falling back to width of space character
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "C:\Users\rani\anaconda3\envs\machinelearning\Library\bin\gvplugin_pango.dll" - It was found, so perhaps one of its dependents was not.  Try ldd.
# FST diagram saved as fst_plural_morphology.png
