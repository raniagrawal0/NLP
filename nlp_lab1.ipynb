# %%
from datasets import load_dataset

# Directly stream the Hindi-Devanagari split
hindi_stream = load_dataset(
    "ai4bharat/IndicCorpV2",
    "indiccorp_v2",
    streaming=True,
    split="hin_Deva"  
)

# %%
pip install datasets

# %%
from itertools import islice

samples = list(islice(hindi_stream, 100))

# %%
text = samples[0]['text']
text
# Out:
# 'लोगों को बिलों संबंधी सुविधा देना ही उनका काम'

# %%
import re

def hindi_tokenizer(text):
    url_pattern = r'https?://[^\s]+|www\.[^\s]+'
    email_pattern = r'\b[\w\.-]+@[\w\.-]+\.\w{2,4}\b'

    # Save and replace URLs and emails
    urls = re.findall(url_pattern, text)
    text = re.sub(url_pattern, '<URL>', text)

    emails = re.findall(email_pattern, text)
    text = re.sub(email_pattern, '<EMAIL>', text)

    tokens = []
    for token in text.split():
        if token == '<URL>':
            tokens.append(urls.pop(0))
        elif token == '<EMAIL>':
            tokens.append(emails.pop(0))
        else:
            split_tokens = re.findall(
                r'[\u0900-\u097F]+|[a-zA-Z0-9]+|[।.,!?;:()\"\'\-]|[^\s]',
                token
            )
            tokens.extend(split_tokens)

    return tokens

def hindi_sentence_tokenizer(text):
    sentence_end_pattern = r'(?<=[।!?\.])\s+'
    sentences = re.split(sentence_end_pattern, text.strip())
    return [s.strip() for s in sentences if s.strip()]

def detokenize(tokens):
    # Rebuild sentence with proper spacing logic
    sentence = ''
    for i, token in enumerate(tokens):
        if i > 0 and not re.match(r'[।.,!?;:)\]\'\"]', token):
            sentence += ' '
        sentence += token
    return sentence.strip()

def hindi_corpus_statistics(text):
    sentences = hindi_sentence_tokenizer(text)
    all_tokens = []
    reconstructed_sentences = []

    for sentence in sentences:
        tokens = hindi_tokenizer(sentence)
        all_tokens.extend(tokens)

        # For checking reformation
        reconstructed = detokenize(tokens)
        reconstructed_sentences.append(reconstructed)

    num_tokens = len(all_tokens)
    unique_tokens = set(all_tokens)
    total_chars = sum(len(token) for token in all_tokens)

    word_tokens = [t for t in all_tokens if re.match(r'^[\u0900-\u097F\w]+$', t)]
    avg_word_length = sum(len(t) for t in word_tokens) / len(word_tokens) if word_tokens else 0
    type_token_ratio = len(unique_tokens) / num_tokens if num_tokens else 0

    return {
        'sentences': sentences,
        'tokens': all_tokens,
        'num_tokens': num_tokens,
        'total_characters': total_chars,
        'average_word_length': round(avg_word_length, 2),
        'type_token_ratio': round(type_token_ratio, 3),
        'reconstructed_sentences': reconstructed_sentences
    }

# %%
text = ' '.join(sample['text'] for sample in samples)
stats = hindi_corpus_statistics(text)

print("Original Sentences:")
i=0
for sentence in stats['sentences']:
    i+=1
    print(i," : ",sentence)

print("\nReconstructed Sentences:")
i=0
for re_sent in stats['reconstructed_sentences']:
    i+=1
    print(i," : ",re_sent)


print("\nTokens:", stats['tokens'])
print("\nNumber of original sentences:", len(stats['sentences']))
print("\nNumber of reconstructed sentences:", len(stats['reconstructed_sentences']))
print("Number of Tokens:", stats['num_tokens'])
print("Total Characters:", stats['total_characters'])
print("Average Word Length:", stats['average_word_length'])
print("Type-Token Ratio:", stats['type_token_ratio'])
# Out:
# Original Sentences:
# 1  :  लोगों को बिलों संबंधी सुविधा देना ही उनका काम  इनेलो 1987 में उस वक्त ऐसे ही दोराहे पर खड़ी थी, जब पूर्व उपप्रधानमंत्री देवीलाल ने अपने पुत्र ओमप्रकाश चौटाला को अपना राजनीतिक उत्तराधिकारी घोषित किया था।
# 2  :  हालांकि तब पार्टी पर देवीलाल की मजबूत पकड़ के चलते पार्टी टूटने से बच गई थी।
# 3  :  1989 में देवीलाल केन्द्र की राजनीति में सक्रिय हो गए थे और उनके उपप्रधानमंत्री बनने के पश्चात् उनके तीन बेटों जगदीश सिंह, रणजीत सिंह और ओमप्रकाश चौटाला में से रणजीत और ओमप्रकाश के बीच हरियाणा में उनकी राजनीतिक विरासत को लेकर जंग शुरू हो गई थी।
# 4  :  उन परिस्थितियों में देवीलाल ने कड़ा निर्णय लेते हुए पार्टी की बागडोर ओमप्रकाश चौटाला के हवाले कर दी थी, जिसके बाद रणजीत की बगावत का असर पार्टी, संगठन और उनकी सरकार पर भी पड़ा था।
# 5  :  उस समय रणजीत की नाराजगी के चलते उनके समर्थन में कई कैबिनेट मंत्रियों ने इस्तीफे दे दिए थे किन्तु तब पार्टी सुप्रीमो चौ.
# 6  :  देवीलाल की हरियाणा की जनता पर इतनी मजबूत पकड़ थी कि ओमप्रकाश चौटाला को उत्तराधिकारी बनाने के उनके फैसले का जनता के बीच कोई खास विरोध नहीं हुआ था लेकिन आज स्थिति बिल्कुल विपरीत है।
# 7  :  ओमप्रकाश चौटाला पिछले काफी समय से जेल में हैं और जेल में रहते पार्टी के साथ-साथ परिवार पर भी उनकी पकड़ काफी ढ़ीली हो गई है, इसी कारण उनमें अब देवीलाल जैसा वो सामर्थ्य नजर नहीं आता कि वे अपने फैसलों को बगैर किसी प्रतिरोध के लागू करा सकें।
# 8  :  जहां आई थी तबाही उस घाटी क्षेत्र में खतरा ज्यादा  इसके बाद केंद्र की ओर से प्रदेश सरकार को पीएमजीएसवाई में 200 करोड़ रुपये की राशि उपलब्ध करा दी गई।
# 9  :  भाजपा के मीडिया प्रभारी दिवाकर सिंह ने शनिवार को बताया कि केंद्र ने प्रदेश सरकार को 200 करोड़ रुपये भेजा है।
# 10  :  यह पूछने पर कि इस बड़े मैच से पहले उनकी नींद गायब हुई तो बाबर ने कहा, "हम काफी टूर्नामेंट खेल चुके हैं, हमने चैम्पियंस ट्राफी में भी अच्छा किया था.
# 11  :  हम इसे जितना सरल रखेंगे, उतना ही बेहतर होगा.
# 12  :  इसमें सिर्फ बेसिक्स पर अडिग रहना होगा और साथ ही शांत चित्त बने रहना होगा.
# 13  :  हमारी तैयारी हमारे हाथों में हैं और हमने अपना शत प्रतिशत दिया है.
# 14  :  हमें मैच के दिन अच्छी क्रिकेट खेलने की उम्मीद है."  समाचार एजेंसी 'डीपीए' के अनुसार, उप गृह मंत्री पैट्रीकियो रोसेंडे ने कहा कि 76 लोगों के मरने की पुष्टि हो चुकी है।
# 15  :  पिछले कई सालों से हमने इतना बड़ा हादसा नहीं देखा।
# 16  :  प्रियंका माहेश्वरी ने किया है एमबीए  बुधवार सुबह 10.30 बजे बड़ी संख्या में एबीवीपी के छात्र नेता कॉलेज के छात्रों को लेकर कलेक्टोरेट पहुंचे और जमकर नारेबाजी करने लगे।
# 17  :  छात्र कलेक्टर से बात करने के लिए अड़े रहे, लेकिन कलेक्टर ने चेंबर में प्रतिनिधि मंडल से मुलाकात कर चर्चा करने की बात कही।
# 18  :  इस बात से छात्र भड़क गए और जिला प्रशासन मुर्दाबाद के नारे लगाने लगे।
# 19  :  मौके पर पहुंचे एसडीएम ने छात्रों को समझाने की कोशिश की, लेकिन छात्र मानने को तैयार नहीं थे।
# 20  :  करीब दो घंटे तक कलेक्टोरेट के गेट पर धरने पर बैठे छात्रों ने आखिरकार प्रतिनिधिमंडल के रूप में जाकर कलेक्टर धनंजय देवांगन से मिलकर अपनी समस्याओं से अवगत कराया।
# 21  :  बता दें कि ये फोटो ड्रग्स पैडलर द्वारा सैंपल के तौर पर बॉलीवुड के सेलिब्रिटीज और सोशलाइट्स को मोबाइल पर भेजे जाते थे, ताकि क्वालिटी का सबूत दिया जा सके.
# 22  :  विक्टोरिया: प्रधानमंत्री नरेंद्र मोदी ने आज कहा कि सेशेल्स जैसे द्वीप देशों के लिए जलवायु परिवर्तन उतना ही गंभीर खतरा है जितना कि दुनिया के सामने आतंकवाद का है.
# 23  :  इसके साथ ही उन्होंने जलवायु परिवर्तन का मुकाबला करने के लिए भारत की गहरी प्रतिबद्धता व्यक्त की है.
# 24  :  चीनी रक्षा मंत्रालय ने एक बयान जारी करके इसकी जानकारी दी।
# 25  :  अमेरिकी सर्वे शिप द्वारा दक्षिण चीन सागर में संचालित यह ड्रोन चीनी नेवी ने जब्त कर लिया था और कथित तौर पर उसे लौटाने से भी इंकार कर दिया था।
# 26  :  हरदोई: डीएम का नया आदेश, ADM से SDM तक आंखों के सामने कराएंगे सफाई, फोटो भेजना भी जरूरी  आईआईएम अहमदाबाद के साथ एमओयू करने की तैयारी में सरकार  सहकारी बैंक घोटाले की जांच में शरद पवार के सहयोग करने की बात कहने सहित आज के बड़े समाचार  लैब से वायरस लीक होने के कई ऐसे मामले हैं जिनकी बाक़ायदा पुष्टि हो चुकी है.
# 27  :  उसका चेक नंबर 36 दर्शाया जा रहा है।
# 28  :  व्यापारी ने बताया कि हमारे खाते में इस क्रमांक की कोई भी चेक जारी नहीं हुई हैद्ध यह किसी ने फर्जी तरीके से हमारे अकाउंट से चेक के माध्यम से पैसे निकाल कर अपने अकाउंट में जमा किए हैं।
# 29  :  जिसकी सूचना व्यापारी ने बैंक ऑफ बड़ौदा शाखा प्रबंधक मैगलगंज को दी है।
# 30  :  बैंक ऑफ बड़ौदा के शाखा प्रबंधक नीरज त्रिपाठी से बात की गई उन्होंने बताया सीतापुर की शाखा से चेक  से पैसा ट्रांसफर हुआ है प्रथम दृष्टया गलती प्रतीत हो रही है जिसे बात करके भुगतान वापस कराया जाएगा।
# 31  :  यह मामला है देश की राजधानी का।
# 32  :  दिल्‍ली के करोलबाग की कंपनी ने लोगों से वादा किया कि आपके INVEST किए पैसे एक साल में डबल कर दिए जाएंगे।
# 33  :  लालच में लोगों ने उस कंपनी में जमकर पैसे लगा दिए।
# 34  :  लोगों को इस झूठ में फंसाने के लिए कंपनी ने एक वेबसाइट भी तैयार करवाई।
# 35  :  कंपनी पर PACIFIC ROYAL AIRLINES के नाम पर धन इकट्ठा कर गबन करने का आरोप है।
# 36  :  दोहरे रिटर्न की आस में लोगों ने दस हजार करोड़ रुपये लगा दिए।
# 37  :  टूर्नामेंट में अबतक खामोश ही रहे भारतीय विश्व कप टीम में शामिल कार्तिक ने 50 गेंद में नाबाद 97 रन बनाए, जिसकी बदौलत कोलकाता तीन विकेट पर 49 रन से उबरते हुए 176 रन जोड़ पाया, लेकिन 17 वर्षीय युवा रियान पराग ने 47 ओर जोफ्रा आर्चर ने नाबाद 27 रन बनाकर कोलकाता से जीत छीन ली।
# 38  :  मोदीपुरम।
# 39  :  बीते दो दिनो में मेरठ में एयर क्वालिटी इंडेक्स (एक्यूआई) का स्तर भले ही घटा है, इसके बावजूद यह सामान्य से बहुत अधिक है।
# 40  :  जनता की सेहत के लिए यह अभी भी खतरनाक है।
# 41  :  चिकित्सकों के अनुसार, प्रदूषण का यह स्तर टीबी व अस्थमा के मरीजों के लिए जानलेवा है।
# 42  :  टिगुआन की प्रोफाइल को साधारण लाइनों और क्रीज द्वारा चिह्नित जा किया सकता है, जो फॉक्सवैगन की क्लासिक डिज़ाइन थीम को बनाए रखती है।
# 43  :  मैट्रिक्स एलईडी नवीन फिटमेंट हैं, जो रात के वक़्त प्रभावी होने चाहिए।
# 44  :  नया VW लोगो और फ्रंट री-टच टिगुआन के चेहरे को साफ रखते हैं।
# 45  :  - इसमें जोड़ सूज भी सकते हैं,लाल भी हो सकते हैं और बुखार भी आ सकता है।
# 46  :  माल गाड़ियों को उनके लिये अलग से बनाये जा रहे गलियारे में स्थानांरित किये जाने से यह संभव हो सकता है।
# 47  :  इस पर काम जारी है और व्यस्त मार्ग दिल्ली-हावड़ा और दिल्ली-मुंबई मार्गों को ट्रेनों की गति बढ़ाने के लिये उन्नत बनाया जा रहा है।
# 48  :  राजस्थान में श्रीगंगानगर जिले के हिंदुमलकोट बॉर्डर इलाके में सीमा पार से सुबह करीब 6 बजे पाकिस्तानी की ओर से फायरिंग की सूचना मिली है.
# 49  :  इस फायरिंग के बाद एक पाकिस्तानी टोही विमान के देखे जाने की भी बात सामने आई.
# 50  :  बता दें कि पश्चिमी राजस्थान में भारत-पाक अंतरराष्ट्रीय बॉर्डर पर पाकिस्तान अपनी हरकतों से  नेहरू जूलॉजिकल पार्क में मुकेश शेर के बाड़े में कूद गया.
# 51  :  35 वर्षीय मुकेश को शराब के नशे में बताया गया.
# 52  :  जिस बाड़े में कूदा था उसमें अफ्रीकन शेरनी राधिका और शेर कृष्णा रहते हैं.
# 53  :  वीडियो देखने के लिए  ...और अगली स्लाइड में पढ़ें, शेरनी को चूमना या शेर से हाथ मिलाना चाहता था युवक?
# 54  :  मछोदरी के रहने वाले रमेश कुमार विश्वकर्मा को चांदी की गुलाबी मीनाकारी की कारीगरी से वह रथ बनाने पर राष्ट्रीय पुरस्कार के लिए चयन किया गया है जिसपर श्रीकृष्ण व अर्जुन विराजमान है।
# 55  :  रमेश के साथ ही देशभर के 40 हस्तशिल्पियों को राष्ट्रीय पुरस्कार के लिए चयनित किया गया है।
# 56  :  ROORKEE (JNN) : तहसील प्रशासन ने बारिश और ओलावृष्टि से प्रभावित किसानों के चेक काटने बंद कर दिए हैं।
# 57  :  वजह यह है कि 20 लाख के बजट में से 16 लाख के चेक काटे जा चुके हैं, जबकि और चेक काटने के लिए पर्याप्त बजट ही नहीं हैं।
# 58  :  गौरतलब है कि वर्मा पूर्व राज्यसभा सदस्य हैं।
# 59  :  इससे पहले वह ‘ द ग्रेट इंडियन मिडिल क्लास’, ‘ बीइंग इंडियन’, ‘ आदि शंकराचार्य : हिंदुज्म ग्रेटेस्ट थिंकर आदि किताबों की रचना कर चुके हैं।
# 60  :  इस समय वह सिम्बायोसिस इंटरनेशनल यूनिवर्सिटी के प्रतिष्ठित प्राध्यापक हैं।
# 61  :  बॉलीवुड अभिनेत्री करीना कपूर खान शुक्रवार को बांद्रा में अपने बेटे तैमूर अली खान के साथ नजर आईं।
# 62  :  प्रेस विज्ञप्ति में हॉकी इंडिया के कार्यवाहक अध्यक्ष ज्ञानेंद्रो निंगोमबाम के हवाले से कहा गया, ‘‘कोविड-19 के साथ मौजूदा लड़ाई का उन खिलाड़ियों पर प्रतिकूल असर पड़ा है जिनके पास नौकरी नहीं है, उनके लिए खेल गतिविधियां शुरू कर पाना मुश्किल है क्योंकि उनका परिवार वित्तीय संकट का सामना कर रहा है।’’  आईएईए ने इस बात को लेकर ईरान की आलोचना की थी कि वह गोपनीय ढंग से रखी गई परमाणु सामग्री और इससे जुड़ी गतिविधियों को लेकर सवालों के जवाब नहीं दे रहा और दो ठिकानों की जांच की अनुमति नहीं दे रहा।
# 63  :  स्वास्तिक शास्त्रों के अनुसार बहुत ही महत्वपूर्ण माना जाता है।
# 64  :  इसलिये जब भी आप स्वास्तिक बनाये तो उस जगह पर स्वच्छ व शुद्ध स्थान का ही चुनाव करें।
# 65  :  क्योंकि अशुद्ध स्थान जैसे शौचालय या फिर किसी गंदगी वाले स्थान पर स्वास्तिक बनाने से आपकी बुद्धि और विवेक भ्रष्ट हो सकता है।
# 66  :  अशुद्ध जगहों पर स्वास्तिक बनाना निषेध माना जाता है।
# 67  :  Home » रविवारीय » जाति व्यवस्था की दशा, दिशा और हमारे कार्यभार  जिला कोर्ट में न्यायाधीश रेखा आर.
# 68  :  चंद्रवंशी की कोर्ट में राधिका नगर निवासी सूरज बाई (55) ने बहू नेहा के खिलाफ वकील कृष्ण कुमार कुन्हारे व वकील काशू महंत के माध्यम से परिवाद दायर किया था.
# 69  :  वकील कुन्हारे के मुताबिक सूरज बाई के बेटे दीपक की शादी नेहा से हुई थी.
# 70  :  शादी के चार साल तक बहू नेहा ससुराल ही नहीं आई.
# 71  :  दीपक और अन्य परिजन बड़ी मुश्किल से समझाकर उसे घर लेकर आए.
# 72  :  पाकिस्तान में आम लोगों और राजनेताओं की इस सोच से विश्लेषक सहमत दिखाई नहीं देते.
# 73  :  सबसे चकित करने वाली बात है, सरकार द्वारा डीजल कीमतों में नियमित बढ़ोतरी के फैसले पर पुनर्विचार करने संबंधी खबरें।
# 74  :  सरकार ने बहुत पहले यह फैसला किया था कि सब्सिडी वाले डीजल की कीमत में हर माह 50 पैसे प्रति लीटर की बढ़ोतरी की जाएगी ताकि लागत और पेट्रोल पम्प पर उसकी कीमत के अंतर को कम किया जा सके।
# 75  :  सरकार को इसकी समीक्षा निर्वाचन आयोग से करवाने अथवा कीमतों को नियंत्रणमुक्त करने के अपने ही पुराने फैसले को मंत्रिमंडल के समक्ष दोबारा ले जाने की कोई आवश्यकता नहीं है।
# 76  :  निर्वाचन आयोग को भी पेट्रोलियम एवं प्राकृतिक गैस मंत्रालय से मिलने वाले ऐसे किसी अनुरोध से जुड़े फैसले पर देर नहीं करनी चाहिए।
# 77  :  - जयराम, थाना प्रभारी, हसनपुर  नदी नालों कि की जा रहीं है जिओ टैगिंग  हम इस क्षेत्र में अपनी क्षमताएं बढ़ाना चाहते हैं।
# 78  :  हालांकि, यहां हम किसी अपने दुश्मन या प्रतिद्वंदी के रूप किसी खास देश या को नहीं देख रहे हैं।
# 79  :  मिग-27 और हॉक स्क्वेड्रन्स के अलावा राफेल की डील के बाद पूर्वी एयर कमांड में हमारी क्षमता बढ़ेगी।’  कोविड-19 संक्रमण के बीच तापमान ने भी परेशान कर दिया है।
# 80  :  मंगलवार को हवा में नमी कम और पारा अधिक होने से दिनभर गर्म हवाओं ने सताया।
# 81  :  अधिकतम तापमान सामान्य से तीन डिग्री सेल्सियस अधिक रिकार्ड किया गया।
# 82  :  उन्होंने दावा किया कि रजस्वला लड़कियों और महिलाओं पर लगी बंदिशें केरल के जंगलों में रहने वाले आदिवासी समाजों के रीति-रिवाज का हिस्सा हैं।
# 83  :  आदिवासियों ने यह भी कहा कि सबरीमाला मंदिर और इससे जुड़ी जगहों पर जनजातीय समुदायों के कई अधिकार सरकारी अधिकारियों और मंदिर का प्रबंधन करने वाले टीडीबी के अधिकारियों द्वारा छीने जा रहे हैं।
# 84  :  45 सीट जीत पाएंगे?
# 85  :  हाउसफुल 3 'हाउसफुल' सीरिज की सबसे कमजोर फिल्म है।
# 86  :  हंसने के लिए इससे बेहतर कई विकल्प मौजूद हैं।
# 87  :  आप को अनेक क्षेत्र में लाभ और यश प्राप्त होगा.
# 88  :  धन प्राप्ति के लिए योग अच्छा है.
# 89  :  मित्रों के पीछे धन खर्च होगा.
# 90  :  परिजनों या दोस्तों के साथ बाहर घूमने जाने का अवसर मिलेगा.
# 91  :  दोस्तों के बाद आप को शारीरिक और मानसिक अस्वस्थता का अनुभव करना पड़ेगा.
# 92  :  किसी के साथ इगो ना रखें, अन्यथा नुकसान आपका ही होगा.
# 93  :  बुकी श्याम वोहरा की संपत्ति की कुर्की करने की तैयारी, आगरा पुलिस ने नोटिस किया चस्‍पा  अशोकनगर(नवदुनिया न्यूज)।
# 94  :  मध्य प्रदेश डिप्लोमा एसोसिएशन दो सूत्रों मांग को लेकर संभाग स्तर पर कमिश्नर के द्वारा मुख्यमंत्री एवं एडिशनल चीफ सेक्रेटरी(छभझ) को ज्ञापन देंगे जिसमें जो अभियंता 28 साल अपने सेवाकाल में पूर्ण कर चुके हैं उन्हें सहायक यंत्री का पद नाम एवं 2006 के बाद के जो संविदाकर्मी इंजीनियर हैं उन्हें स्थाईकर्मी बनाने ज्ञापन दिया जाए  संदीप 10 किमी के बाद 12वें, 14 किमी के बाद 19वें और 16 किमी के बाद 23वें स्थान पर खिसक गए।
# 95  :  संदीप ने एक घंटा 25 मिनट और सात सेकेंड का समय लिया।
# 96  :  राहुल ने एक घंटा 32 मिनट और छह सेकेंड में रेस पूरी की।
# 97  :  इरफान ने बेहद निराश किया और वह एक मिनट 34 मिनट और 41 सेकेंड का सत्र का सर्वश्रेष्ठ प्रदर्शन करने के बावजूद स्पर्धा पूरी करने वाले 52 एथलीटों में 51वें स्थान पर रहे।
# 98  :  इन पदों के लिए आवेदन की प्रक्रिया 5 दिसंबर से शुरू हो गई है।
# 99  :  व्यापार मंडल ने किया विरोध का ऐलान  उसने कहा ,‘‘ मैं चाहती हूं कि एक नौकरी मिल जाये ।
# 100  :  गार्ड की ही सही ।
# 101  :  मैं योग सिखाकर अपना खर्च चलाती हूं और फिजियोथेरेपी के लिये भी लोगों की मदद करती हूं ।
# 102  :  मैने खुद से यह सीखा है ।लेकिन कब तक मेरे भाई मेरा खर्च चलायेंगे ।मुझे एक नौकरी की सख्त जरूरत है ।’’ उसे प्रोटीन वाला भोजन या सूखे मेवे भी मयस्सर नहीं है ।
# 103  :  सब्जी और भात पर गुजारा होता है जिससे शरीर में कैल्शियम और हीमोग्लोबिन की कमी हो गई है।
# 104  :  अपने जुनून के दम पर वह ताकत के इस खेल में बनी हुई है ।
# 105  :  पलसदरी को इसकी प्राकृतिक सुंदरता और कठिन रास्तों के लिए जाना जाता है।
# 106  :  पहाड़ों पर पैदल यात्रा, पर्यटकों में विशेष रूप से लोकप्रिय है।
# 107  :  लेकिन पर्यटकों को इन यात्राओं के दौरान यहाँ की कंटीली झाड़ियों से सावधान रहना चाहिए।
# 108  :  यह कंटीली झाड़ियां किसी लापरवाह पथिक के लिए खतरनाक साबित हो सकती हैं।
# 109  :  पलसदरी में कई स्थान निजी स्वामित्व में हैं और इनसे होकर गुजरना अवैध है।
#
# Reconstructed Sentences:
# 1  :  लोगों को बिलों संबंधी सुविधा देना ही उनका काम इनेलो 1987 में उस वक्त ऐसे ही दोराहे पर खड़ी थी, जब पूर्व उपप्रधानमंत्री देवीलाल ने अपने पुत्र ओमप्रकाश चौटाला को अपना राजनीतिक उत्तराधिकारी घोषित किया था।
# 2  :  हालांकि तब पार्टी पर देवीलाल की मजबूत पकड़ के चलते पार्टी टूटने से बच गई थी।
# 3  :  1989 में देवीलाल केन्द्र की राजनीति में सक्रिय हो गए थे और उनके उपप्रधानमंत्री बनने के पश्चात् उनके तीन बेटों जगदीश सिंह, रणजीत सिंह और ओमप्रकाश चौटाला में से रणजीत और ओमप्रकाश के बीच हरियाणा में उनकी राजनीतिक विरासत को लेकर जंग शुरू हो गई थी।
# 4  :  उन परिस्थितियों में देवीलाल ने कड़ा निर्णय लेते हुए पार्टी की बागडोर ओमप्रकाश चौटाला के हवाले कर दी थी, जिसके बाद रणजीत की बगावत का असर पार्टी, संगठन और उनकी सरकार पर भी पड़ा था।
# 5  :  उस समय रणजीत की नाराजगी के चलते उनके समर्थन में कई कैबिनेट मंत्रियों ने इस्तीफे दे दिए थे किन्तु तब पार्टी सुप्रीमो चौ.
# 6  :  देवीलाल की हरियाणा की जनता पर इतनी मजबूत पकड़ थी कि ओमप्रकाश चौटाला को उत्तराधिकारी बनाने के उनके फैसले का जनता के बीच कोई खास विरोध नहीं हुआ था लेकिन आज स्थिति बिल्कुल विपरीत है।
# 7  :  ओमप्रकाश चौटाला पिछले काफी समय से जेल में हैं और जेल में रहते पार्टी के साथ - साथ परिवार पर भी उनकी पकड़ काफी ढ़ीली हो गई है, इसी कारण उनमें अब देवीलाल जैसा वो सामर्थ्य नजर नहीं आता कि वे अपने फैसलों को बगैर किसी प्रतिरोध के लागू करा सकें।
# 8  :  जहां आई थी तबाही उस घाटी क्षेत्र में खतरा ज्यादा इसके बाद केंद्र की ओर से प्रदेश सरकार को पीएमजीएसवाई में 200 करोड़ रुपये की राशि उपलब्ध करा दी गई।
# 9  :  भाजपा के मीडिया प्रभारी दिवाकर सिंह ने शनिवार को बताया कि केंद्र ने प्रदेश सरकार को 200 करोड़ रुपये भेजा है।
# 10  :  यह पूछने पर कि इस बड़े मैच से पहले उनकी नींद गायब हुई तो बाबर ने कहा," हम काफी टूर्नामेंट खेल चुके हैं, हमने चैम्पियंस ट्राफी में भी अच्छा किया था.
# 11  :  हम इसे जितना सरल रखेंगे, उतना ही बेहतर होगा.
# 12  :  इसमें सिर्फ बेसिक्स पर अडिग रहना होगा और साथ ही शांत चित्त बने रहना होगा.
# 13  :  हमारी तैयारी हमारे हाथों में हैं और हमने अपना शत प्रतिशत दिया है.
# 14  :  हमें मैच के दिन अच्छी क्रिकेट खेलने की उम्मीद है." समाचार एजेंसी' डीपीए' के अनुसार, उप गृह मंत्री पैट्रीकियो रोसेंडे ने कहा कि 76 लोगों के मरने की पुष्टि हो चुकी है।
# 15  :  पिछले कई सालों से हमने इतना बड़ा हादसा नहीं देखा।
# 16  :  प्रियंका माहेश्वरी ने किया है एमबीए बुधवार सुबह 10. 30 बजे बड़ी संख्या में एबीवीपी के छात्र नेता कॉलेज के छात्रों को लेकर कलेक्टोरेट पहुंचे और जमकर नारेबाजी करने लगे।
# 17  :  छात्र कलेक्टर से बात करने के लिए अड़े रहे, लेकिन कलेक्टर ने चेंबर में प्रतिनिधि मंडल से मुलाकात कर चर्चा करने की बात कही।
# 18  :  इस बात से छात्र भड़क गए और जिला प्रशासन मुर्दाबाद के नारे लगाने लगे।
# 19  :  मौके पर पहुंचे एसडीएम ने छात्रों को समझाने की कोशिश की, लेकिन छात्र मानने को तैयार नहीं थे।
# 20  :  करीब दो घंटे तक कलेक्टोरेट के गेट पर धरने पर बैठे छात्रों ने आखिरकार प्रतिनिधिमंडल के रूप में जाकर कलेक्टर धनंजय देवांगन से मिलकर अपनी समस्याओं से अवगत कराया।
# 21  :  बता दें कि ये फोटो ड्रग्स पैडलर द्वारा सैंपल के तौर पर बॉलीवुड के सेलिब्रिटीज और सोशलाइट्स को मोबाइल पर भेजे जाते थे, ताकि क्वालिटी का सबूत दिया जा सके.
# 22  :  विक्टोरिया: प्रधानमंत्री नरेंद्र मोदी ने आज कहा कि सेशेल्स जैसे द्वीप देशों के लिए जलवायु परिवर्तन उतना ही गंभीर खतरा है जितना कि दुनिया के सामने आतंकवाद का है.
# 23  :  इसके साथ ही उन्होंने जलवायु परिवर्तन का मुकाबला करने के लिए भारत की गहरी प्रतिबद्धता व्यक्त की है.
# 24  :  चीनी रक्षा मंत्रालय ने एक बयान जारी करके इसकी जानकारी दी।
# 25  :  अमेरिकी सर्वे शिप द्वारा दक्षिण चीन सागर में संचालित यह ड्रोन चीनी नेवी ने जब्त कर लिया था और कथित तौर पर उसे लौटाने से भी इंकार कर दिया था।
# 26  :  हरदोई: डीएम का नया आदेश, ADM से SDM तक आंखों के सामने कराएंगे सफाई, फोटो भेजना भी जरूरी आईआईएम अहमदाबाद के साथ एमओयू करने की तैयारी में सरकार सहकारी बैंक घोटाले की जांच में शरद पवार के सहयोग करने की बात कहने सहित आज के बड़े समाचार लैब से वायरस लीक होने के कई ऐसे मामले हैं जिनकी बाक़ायदा पुष्टि हो चुकी है.
# 27  :  उसका चेक नंबर 36 दर्शाया जा रहा है।
# 28  :  व्यापारी ने बताया कि हमारे खाते में इस क्रमांक की कोई भी चेक जारी नहीं हुई हैद्ध यह किसी ने फर्जी तरीके से हमारे अकाउंट से चेक के माध्यम से पैसे निकाल कर अपने अकाउंट में जमा किए हैं।
# 29  :  जिसकी सूचना व्यापारी ने बैंक ऑफ बड़ौदा शाखा प्रबंधक मैगलगंज को दी है।
# 30  :  बैंक ऑफ बड़ौदा के शाखा प्रबंधक नीरज त्रिपाठी से बात की गई उन्होंने बताया सीतापुर की शाखा से चेक से पैसा ट्रांसफर हुआ है प्रथम दृष्टया गलती प्रतीत हो रही है जिसे बात करके भुगतान वापस कराया जाएगा।
# 31  :  यह मामला है देश की राजधानी का।
# 32  :  दिल् ‍ ली के करोलबाग की कंपनी ने लोगों से वादा किया कि आपके INVEST किए पैसे एक साल में डबल कर दिए जाएंगे।
# 33  :  लालच में लोगों ने उस कंपनी में जमकर पैसे लगा दिए।
# 34  :  लोगों को इस झूठ में फंसाने के लिए कंपनी ने एक वेबसाइट भी तैयार करवाई।
# 35  :  कंपनी पर PACIFIC ROYAL AIRLINES के नाम पर धन इकट्ठा कर गबन करने का आरोप है।
# 36  :  दोहरे रिटर्न की आस में लोगों ने दस हजार करोड़ रुपये लगा दिए।
# 37  :  टूर्नामेंट में अबतक खामोश ही रहे भारतीय विश्व कप टीम में शामिल कार्तिक ने 50 गेंद में नाबाद 97 रन बनाए, जिसकी बदौलत कोलकाता तीन विकेट पर 49 रन से उबरते हुए 176 रन जोड़ पाया, लेकिन 17 वर्षीय युवा रियान पराग ने 47 ओर जोफ्रा आर्चर ने नाबाद 27 रन बनाकर कोलकाता से जीत छीन ली।
# 38  :  मोदीपुरम।
# 39  :  बीते दो दिनो में मेरठ में एयर क्वालिटी इंडेक्स ( एक्यूआई) का स्तर भले ही घटा है, इसके बावजूद यह सामान्य से बहुत अधिक है।
# 40  :  जनता की सेहत के लिए यह अभी भी खतरनाक है।
# 41  :  चिकित्सकों के अनुसार, प्रदूषण का यह स्तर टीबी व अस्थमा के मरीजों के लिए जानलेवा है।
# 42  :  टिगुआन की प्रोफाइल को साधारण लाइनों और क्रीज द्वारा चिह्नित जा किया सकता है, जो फॉक्सवैगन की क्लासिक डिज़ाइन थीम को बनाए रखती है।
# 43  :  मैट्रिक्स एलईडी नवीन फिटमेंट हैं, जो रात के वक़्त प्रभावी होने चाहिए।
# 44  :  नया VW लोगो और फ्रंट री - टच टिगुआन के चेहरे को साफ रखते हैं।
# 45  :  - इसमें जोड़ सूज भी सकते हैं, लाल भी हो सकते हैं और बुखार भी आ सकता है।
# 46  :  माल गाड़ियों को उनके लिये अलग से बनाये जा रहे गलियारे में स्थानांरित किये जाने से यह संभव हो सकता है।
# 47  :  इस पर काम जारी है और व्यस्त मार्ग दिल्ली - हावड़ा और दिल्ली - मुंबई मार्गों को ट्रेनों की गति बढ़ाने के लिये उन्नत बनाया जा रहा है।
# 48  :  राजस्थान में श्रीगंगानगर जिले के हिंदुमलकोट बॉर्डर इलाके में सीमा पार से सुबह करीब 6 बजे पाकिस्तानी की ओर से फायरिंग की सूचना मिली है.
# 49  :  इस फायरिंग के बाद एक पाकिस्तानी टोही विमान के देखे जाने की भी बात सामने आई.
# 50  :  बता दें कि पश्चिमी राजस्थान में भारत - पाक अंतरराष्ट्रीय बॉर्डर पर पाकिस्तान अपनी हरकतों से नेहरू जूलॉजिकल पार्क में मुकेश शेर के बाड़े में कूद गया.
# 51  :  35 वर्षीय मुकेश को शराब के नशे में बताया गया.
# 52  :  जिस बाड़े में कूदा था उसमें अफ्रीकन शेरनी राधिका और शेर कृष्णा रहते हैं.
# 53  :  वीडियो देखने के लिए... और अगली स्लाइड में पढ़ें, शेरनी को चूमना या शेर से हाथ मिलाना चाहता था युवक?
# 54  :  मछोदरी के रहने वाले रमेश कुमार विश्वकर्मा को चांदी की गुलाबी मीनाकारी की कारीगरी से वह रथ बनाने पर राष्ट्रीय पुरस्कार के लिए चयन किया गया है जिसपर श्रीकृष्ण व अर्जुन विराजमान है।
# 55  :  रमेश के साथ ही देशभर के 40 हस्तशिल्पियों को राष्ट्रीय पुरस्कार के लिए चयनित किया गया है।
# 56  :  ROORKEE ( JNN): तहसील प्रशासन ने बारिश और ओलावृष्टि से प्रभावित किसानों के चेक काटने बंद कर दिए हैं।
# 57  :  वजह यह है कि 20 लाख के बजट में से 16 लाख के चेक काटे जा चुके हैं, जबकि और चेक काटने के लिए पर्याप्त बजट ही नहीं हैं।
# 58  :  गौरतलब है कि वर्मा पूर्व राज्यसभा सदस्य हैं।
# 59  :  इससे पहले वह ‘ द ग्रेट इंडियन मिडिल क्लास ’, ‘ बीइंग इंडियन ’, ‘ आदि शंकराचार्य: हिंदुज्म ग्रेटेस्ट थिंकर आदि किताबों की रचना कर चुके हैं।
# 60  :  इस समय वह सिम्बायोसिस इंटरनेशनल यूनिवर्सिटी के प्रतिष्ठित प्राध्यापक हैं।
# 61  :  बॉलीवुड अभिनेत्री करीना कपूर खान शुक्रवार को बांद्रा में अपने बेटे तैमूर अली खान के साथ नजर आईं।
# 62  :  प्रेस विज्ञप्ति में हॉकी इंडिया के कार्यवाहक अध्यक्ष ज्ञानेंद्रो निंगोमबाम के हवाले से कहा गया, ‘ ‘ कोविड - 19 के साथ मौजूदा लड़ाई का उन खिलाड़ियों पर प्रतिकूल असर पड़ा है जिनके पास नौकरी नहीं है, उनके लिए खेल गतिविधियां शुरू कर पाना मुश्किल है क्योंकि उनका परिवार वित्तीय संकट का सामना कर रहा है। ’ ’ आईएईए ने इस बात को लेकर ईरान की आलोचना की थी कि वह गोपनीय ढंग से रखी गई परमाणु सामग्री और इससे जुड़ी गतिविधियों को लेकर सवालों के जवाब नहीं दे रहा और दो ठिकानों की जांच की अनुमति नहीं दे रहा।
# 63  :  स्वास्तिक शास्त्रों के अनुसार बहुत ही महत्वपूर्ण माना जाता है।
# 64  :  इसलिये जब भी आप स्वास्तिक बनाये तो उस जगह पर स्वच्छ व शुद्ध स्थान का ही चुनाव करें।
# 65  :  क्योंकि अशुद्ध स्थान जैसे शौचालय या फिर किसी गंदगी वाले स्थान पर स्वास्तिक बनाने से आपकी बुद्धि और विवेक भ्रष्ट हो सकता है।
# 66  :  अशुद्ध जगहों पर स्वास्तिक बनाना निषेध माना जाता है।
# 67  :  Home » रविवारीय » जाति व्यवस्था की दशा, दिशा और हमारे कार्यभार जिला कोर्ट में न्यायाधीश रेखा आर.
# 68  :  चंद्रवंशी की कोर्ट में राधिका नगर निवासी सूरज बाई ( 55) ने बहू नेहा के खिलाफ वकील कृष्ण कुमार कुन्हारे व वकील काशू महंत के माध्यम से परिवाद दायर किया था.
# 69  :  वकील कुन्हारे के मुताबिक सूरज बाई के बेटे दीपक की शादी नेहा से हुई थी.
# 70  :  शादी के चार साल तक बहू नेहा ससुराल ही नहीं आई.
# 71  :  दीपक और अन्य परिजन बड़ी मुश्किल से समझाकर उसे घर लेकर आए.
# 72  :  पाकिस्तान में आम लोगों और राजनेताओं की इस सोच से विश्लेषक सहमत दिखाई नहीं देते.
# 73  :  सबसे चकित करने वाली बात है, सरकार द्वारा डीजल कीमतों में नियमित बढ़ोतरी के फैसले पर पुनर्विचार करने संबंधी खबरें।
# 74  :  सरकार ने बहुत पहले यह फैसला किया था कि सब्सिडी वाले डीजल की कीमत में हर माह 50 पैसे प्रति लीटर की बढ़ोतरी की जाएगी ताकि लागत और पेट्रोल पम्प पर उसकी कीमत के अंतर को कम किया जा सके।
# 75  :  सरकार को इसकी समीक्षा निर्वाचन आयोग से करवाने अथवा कीमतों को नियंत्रणमुक्त करने के अपने ही पुराने फैसले को मंत्रिमंडल के समक्ष दोबारा ले जाने की कोई आवश्यकता नहीं है।
# 76  :  निर्वाचन आयोग को भी पेट्रोलियम एवं प्राकृतिक गैस मंत्रालय से मिलने वाले ऐसे किसी अनुरोध से जुड़े फैसले पर देर नहीं करनी चाहिए।
# 77  :  - जयराम, थाना प्रभारी, हसनपुर नदी नालों कि की जा रहीं है जिओ टैगिंग हम इस क्षेत्र में अपनी क्षमताएं बढ़ाना चाहते हैं।
# 78  :  हालांकि, यहां हम किसी अपने दुश्मन या प्रतिद्वंदी के रूप किसी खास देश या को नहीं देख रहे हैं।
# 79  :  मिग - 27 और हॉक स्क्वेड्रन्स के अलावा राफेल की डील के बाद पूर्वी एयर कमांड में हमारी क्षमता बढ़ेगी। ’ कोविड - 19 संक्रमण के बीच तापमान ने भी परेशान कर दिया है।
# 80  :  मंगलवार को हवा में नमी कम और पारा अधिक होने से दिनभर गर्म हवाओं ने सताया।
# 81  :  अधिकतम तापमान सामान्य से तीन डिग्री सेल्सियस अधिक रिकार्ड किया गया।
# 82  :  उन्होंने दावा किया कि रजस्वला लड़कियों और महिलाओं पर लगी बंदिशें केरल के जंगलों में रहने वाले आदिवासी समाजों के रीति - रिवाज का हिस्सा हैं।
# 83  :  आदिवासियों ने यह भी कहा कि सबरीमाला मंदिर और इससे जुड़ी जगहों पर जनजातीय समुदायों के कई अधिकार सरकारी अधिकारियों और मंदिर का प्रबंधन करने वाले टीडीबी के अधिकारियों द्वारा छीने जा रहे हैं।
# 84  :  45 सीट जीत पाएंगे?
# 85  :  हाउसफुल 3' हाउसफुल' सीरिज की सबसे कमजोर फिल्म है।
# 86  :  हंसने के लिए इससे बेहतर कई विकल्प मौजूद हैं।
# 87  :  आप को अनेक क्षेत्र में लाभ और यश प्राप्त होगा.
# 88  :  धन प्राप्ति के लिए योग अच्छा है.
# 89  :  मित्रों के पीछे धन खर्च होगा.
# 90  :  परिजनों या दोस्तों के साथ बाहर घूमने जाने का अवसर मिलेगा.
# 91  :  दोस्तों के बाद आप को शारीरिक और मानसिक अस्वस्थता का अनुभव करना पड़ेगा.
# 92  :  किसी के साथ इगो ना रखें, अन्यथा नुकसान आपका ही होगा.
# 93  :  बुकी श्याम वोहरा की संपत्ति की कुर्की करने की तैयारी, आगरा पुलिस ने नोटिस किया चस् ‍ पा अशोकनगर ( नवदुनिया न्यूज) ।
# 94  :  मध्य प्रदेश डिप्लोमा एसोसिएशन दो सूत्रों मांग को लेकर संभाग स्तर पर कमिश्नर के द्वारा मुख्यमंत्री एवं एडिशनल चीफ सेक्रेटरी ( छभझ) को ज्ञापन देंगे जिसमें जो अभियंता 28 साल अपने सेवाकाल में पूर्ण कर चुके हैं उन्हें सहायक यंत्री का पद नाम एवं 2006 के बाद के जो संविदाकर्मी इंजीनियर हैं उन्हें स्थाईकर्मी बनाने ज्ञापन दिया जाए संदीप 10 किमी के बाद 12 वें, 14 किमी के बाद 19 वें और 16 किमी के बाद 23 वें स्थान पर खिसक गए।
# 95  :  संदीप ने एक घंटा 25 मिनट और सात सेकेंड का समय लिया।
# 96  :  राहुल ने एक घंटा 32 मिनट और छह सेकेंड में रेस पूरी की।
# 97  :  इरफान ने बेहद निराश किया और वह एक मिनट 34 मिनट और 41 सेकेंड का सत्र का सर्वश्रेष्ठ प्रदर्शन करने के बावजूद स्पर्धा पूरी करने वाले 52 एथलीटों में 51 वें स्थान पर रहे।
# 98  :  इन पदों के लिए आवेदन की प्रक्रिया 5 दिसंबर से शुरू हो गई है।
# 99  :  व्यापार मंडल ने किया विरोध का ऐलान उसने कहा, ‘ ‘ मैं चाहती हूं कि एक नौकरी मिल जाये ।
# 100  :  गार्ड की ही सही ।
# 101  :  मैं योग सिखाकर अपना खर्च चलाती हूं और फिजियोथेरेपी के लिये भी लोगों की मदद करती हूं ।
# 102  :  मैने खुद से यह सीखा है ।लेकिन कब तक मेरे भाई मेरा खर्च चलायेंगे ।मुझे एक नौकरी की सख्त जरूरत है । ’ ’ उसे प्रोटीन वाला भोजन या सूखे मेवे भी मयस्सर नहीं है ।
# 103  :  सब्जी और भात पर गुजारा होता है जिससे शरीर में कैल्शियम और हीमोग्लोबिन की कमी हो गई है।
# 104  :  अपने जुनून के दम पर वह ताकत के इस खेल में बनी हुई है ।
# 105  :  पलसदरी को इसकी प्राकृतिक सुंदरता और कठिन रास्तों के लिए जाना जाता है।
# 106  :  पहाड़ों पर पैदल यात्रा, पर्यटकों में विशेष रूप से लोकप्रिय है।
# 107  :  लेकिन पर्यटकों को इन यात्राओं के दौरान यहाँ की कंटीली झाड़ियों से सावधान रहना चाहिए।
# 108  :  यह कंटीली झाड़ियां किसी लापरवाह पथिक के लिए खतरनाक साबित हो सकती हैं।
# 109  :  पलसदरी में कई स्थान निजी स्वामित्व में हैं और इनसे होकर गुजरना अवैध है।
#
# Tokens: ['लोगों', 'को', 'बिलों', 'संबंधी', 'सुविधा', 'देना', 'ही', 'उनका', 'काम', 'इनेलो', '1987', 'में', 'उस', 'वक्त', 'ऐसे', 'ही', 'दोराहे', 'पर', 'खड़ी', 'थी', ',', 'जब', 'पूर्व', 'उपप्रधानमंत्री', 'देवीलाल', 'ने', 'अपने', 'पुत्र', 'ओमप्रकाश', 'चौटाला', 'को', 'अपना', 'राजनीतिक', 'उत्तराधिकारी', 'घोषित', 'किया', 'था।', 'हालांकि', 'तब', 'पार्टी', 'पर', 'देवीलाल', 'की', 'मजबूत', 'पकड़', 'के', 'चलते', 'पार्टी', 'टूटने', 'से', 'बच', 'गई', 'थी।', '1989', 'में', 'देवीलाल', 'केन्द्र', 'की', 'राजनीति', 'में', 'सक्रिय', 'हो', 'गए', 'थे', 'और', 'उनके', 'उपप्रधानमंत्री', 'बनने', 'के', 'पश्चात्', 'उनके', 'तीन', 'बेटों', 'जगदीश', 'सिंह', ',', 'रणजीत', 'सिंह', 'और', 'ओमप्रकाश', 'चौटाला', 'में', 'से', 'रणजीत', 'और', 'ओमप्रकाश', 'के', 'बीच', 'हरियाणा', 'में', 'उनकी', 'राजनीतिक', 'विरासत', 'को', 'लेकर', 'जंग', 'शुरू', 'हो', 'गई', 'थी।', 'उन', 'परिस्थितियों', 'में', 'देवीलाल', 'ने', 'कड़ा', 'निर्णय', 'लेते', 'हुए', 'पार्टी', 'की', 'बागडोर', 'ओमप्रकाश', 'चौटाला', 'के', 'हवाले', 'कर', 'दी', 'थी', ',', 'जिसके', 'बाद', 'रणजीत', 'की', 'बगावत', 'का', 'असर', 'पार्टी', ',', 'संगठन', 'और', 'उनकी', 'सरकार', 'पर', 'भी', 'पड़ा', 'था।', 'उस', 'समय', 'रणजीत', 'की', 'नाराजगी', 'के', 'चलते', 'उनके', 'समर्थन', 'में', 'कई', 'कैबिनेट', 'मंत्रियों', 'ने', 'इस्तीफे', 'दे', 'दिए', 'थे', 'किन्तु', 'तब', 'पार्टी', 'सुप्रीमो', 'चौ', '.', 'देवीलाल', 'की', 'हरियाणा', 'की', 'जनता', 'पर', 'इतनी', 'मजबूत', 'पकड़', 'थी', 'कि', 'ओमप्रकाश', 'चौटाला', 'को', 'उत्तराधिकारी', 'बनाने', 'के', 'उनके', 'फैसले', 'का', 'जनता', 'के', 'बीच', 'कोई', 'खास', 'विरोध', 'नहीं', 'हुआ', 'था', 'लेकिन', 'आज', 'स्थिति', 'बिल्कुल', 'विपरीत', 'है।', 'ओमप्रकाश', 'चौटाला', 'पिछले', 'काफी', 'समय', 'से', 'जेल', 'में', 'हैं', 'और', 'जेल', 'में', 'रहते', 'पार्टी', 'के', 'साथ', '-', 'साथ', 'परिवार', 'पर', 'भी', 'उनकी', 'पकड़', 'काफी', 'ढ़ीली', 'हो', 'गई', 'है', ',', 'इसी', 'कारण', 'उनमें', 'अब', 'देवीलाल', 'जैसा', 'वो', 'सामर्थ्य', 'नजर', 'नहीं', 'आता', 'कि', 'वे', 'अपने', 'फैसलों', 'को', 'बगैर', 'किसी', 'प्रतिरोध', 'के', 'लागू', 'करा', 'सकें।', 'जहां', 'आई', 'थी', 'तबाही', 'उस', 'घाटी', 'क्षेत्र', 'में', 'खतरा', 'ज्यादा', 'इसके', 'बाद', 'केंद्र', 'की', 'ओर', 'से', 'प्रदेश', 'सरकार', 'को', 'पीएमजीएसवाई', 'में', '200', 'करोड़', 'रुपये', 'की', 'राशि', 'उपलब्ध', 'करा', 'दी', 'गई।', 'भाजपा', 'के', 'मीडिया', 'प्रभारी', 'दिवाकर', 'सिंह', 'ने', 'शनिवार', 'को', 'बताया', 'कि', 'केंद्र', 'ने', 'प्रदेश', 'सरकार', 'को', '200', 'करोड़', 'रुपये', 'भेजा', 'है।', 'यह', 'पूछने', 'पर', 'कि', 'इस', 'बड़े', 'मैच', 'से', 'पहले', 'उनकी', 'नींद', 'गायब', 'हुई', 'तो', 'बाबर', 'ने', 'कहा', ',', '"', 'हम', 'काफी', 'टूर्नामेंट', 'खेल', 'चुके', 'हैं', ',', 'हमने', 'चैम्पियंस', 'ट्राफी', 'में', 'भी', 'अच्छा', 'किया', 'था', '.', 'हम', 'इसे', 'जितना', 'सरल', 'रखेंगे', ',', 'उतना', 'ही', 'बेहतर', 'होगा', '.', 'इसमें', 'सिर्फ', 'बेसिक्स', 'पर', 'अडिग', 'रहना', 'होगा', 'और', 'साथ', 'ही', 'शांत', 'चित्त', 'बने', 'रहना', 'होगा', '.', 'हमारी', 'तैयारी', 'हमारे', 'हाथों', 'में', 'हैं', 'और', 'हमने', 'अपना', 'शत', 'प्रतिशत', 'दिया', 'है', '.', 'हमें', 'मैच', 'के', 'दिन', 'अच्छी', 'क्रिकेट', 'खेलने', 'की', 'उम्मीद', 'है', '.', '"', 'समाचार', 'एजेंसी', "'", 'डीपीए', "'", 'के', 'अनुसार', ',', 'उप', 'गृह', 'मंत्री', 'पैट्रीकियो', 'रोसेंडे', 'ने', 'कहा', 'कि', '76', 'लोगों', 'के', 'मरने', 'की', 'पुष्टि', 'हो', 'चुकी', 'है।', 'पिछले', 'कई', 'सालों', 'से', 'हमने', 'इतना', 'बड़ा', 'हादसा', 'नहीं', 'देखा।', 'प्रियंका', 'माहेश्वरी', 'ने', 'किया', 'है', 'एमबीए', 'बुधवार', 'सुबह', '10', '.', '30', 'बजे', 'बड़ी', 'संख्या', 'में', 'एबीवीपी', 'के', 'छात्र', 'नेता', 'कॉलेज', 'के', 'छात्रों', 'को', 'लेकर', 'कलेक्टोरेट', 'पहुंचे', 'और', 'जमकर', 'नारेबाजी', 'करने', 'लगे।', 'छात्र', 'कलेक्टर', 'से', 'बात', 'करने', 'के', 'लिए', 'अड़े', 'रहे', ',', 'लेकिन', 'कलेक्टर', 'ने', 'चेंबर', 'में', 'प्रतिनिधि', 'मंडल', 'से', 'मुलाकात', 'कर', 'चर्चा', 'करने', 'की', 'बात', 'कही।', 'इस', 'बात', 'से', 'छात्र', 'भड़क', 'गए', 'और', 'जिला', 'प्रशासन', 'मुर्दाबाद', 'के', 'नारे', 'लगाने', 'लगे।', 'मौके', 'पर', 'पहुंचे', 'एसडीएम', 'ने', 'छात्रों', 'को', 'समझाने', 'की', 'कोशिश', 'की', ',' ...
#
# Number of original sentences: 109
#
# Number of reconstructed sentences: 109
# Number of Tokens: 2442
# Total Characters: 9479
# Average Word Length: 4.03
# Type-Token Ratio: 0.463

# %%
import re

def english_tokenizer(text):
    # Define patterns
    url_pattern = r'https?://[^\s]+|www\.[^\s]+'
    email_pattern = r'\b[\w\.-]+@[\w\.-]+\.\w{2,}\b'

    # Save and replace URLs/emails
    urls = re.findall(url_pattern, text)
    text = re.sub(url_pattern, '<URL>', text)

    emails = re.findall(email_pattern, text)
    text = re.sub(email_pattern, '<EMAIL>', text)

    tokens = []
    for token in text.split():
        if token == '<URL>':
            tokens.append(urls.pop(0))
        elif token == '<EMAIL>':
            tokens.append(emails.pop(0))
        else:
            # Tokenize: words, numbers, punctuation
            split_tokens = re.findall(r"[a-zA-Z0-9]+|[.,!?;:'\"()\-]|[^\s]", token)
            tokens.extend(split_tokens)

    return tokens

def english_sentence_tokenizer(text):
    # Split on sentence-ending punctuation followed by space
    sentence_end_pattern = r'(?<=[.!?])\s+'
    sentences = re.split(sentence_end_pattern, text.strip())
    return [s.strip() for s in sentences if s.strip()]

def detokenize(tokens):
    sentence = ''
    for i, token in enumerate(tokens):
        if i > 0 and not re.match(r'[.,!?;:)\]\'\"]', token):
            sentence += ' '
        sentence += token
    return sentence.strip()

def english_corpus_statistics(text):
    sentences = english_sentence_tokenizer(text)
    all_tokens = []
    reconstructed_sentences = []

    for sentence in sentences:
        tokens = english_tokenizer(sentence)
        all_tokens.extend(tokens)

        reconstructed = detokenize(tokens)
        reconstructed_sentences.append(reconstructed)

    num_tokens = len(all_tokens)
    unique_tokens = set(all_tokens)
    total_chars = sum(len(token) for token in all_tokens)

    word_tokens = [t for t in all_tokens if re.match(r'^[a-zA-Z0-9]+$', t)]
    avg_word_length = sum(len(t) for t in word_tokens) / len(word_tokens) if word_tokens else 0
    type_token_ratio = len(unique_tokens) / num_tokens if num_tokens else 0

    return {
        'sentences': sentences,
        'tokens': all_tokens,
        'num_tokens': num_tokens,
        'total_characters': total_chars,
        'average_word_length': round(avg_word_length, 2),
        'type_token_ratio': round(type_token_ratio, 3),
        'reconstructed_sentences': reconstructed_sentences
    }

# %%
text = """Hi! My name is John. Email me at john.doe@example.com or visit https://openai.com. 
This is amazing, isn't it? Let's test URLs like www.testsite.com too."""

stats = english_corpus_statistics(text)

print("Original Sentences:")
for s in stats['sentences']:
    print(s)

print("\nReconstructed Sentences:")
for s in stats['reconstructed_sentences']:
    print(s)

print("\nTokens:", stats['tokens'])
print("Number of Tokens:", stats['num_tokens'])
print("Total Characters:", stats['total_characters'])
print("Average Word Length:", stats['average_word_length'])
print("Type-Token Ratio:", stats['type_token_ratio'])
# Out:
# Original Sentences:
# Hi!
# My name is John.
# Email me at john.doe@example.com or visit https://openai.com.
# This is amazing, isn't it?
# Let's test URLs like www.testsite.com too.
#
# Reconstructed Sentences:
# Hi!
# My name is John.
# Email me at john.doe@example.com or visit https://openai.com.
# This is amazing, isn' t it?
# Let' s test URLs like www.testsite.com too.
#
# Tokens: ['Hi', '!', 'My', 'name', 'is', 'John', '.', 'Email', 'me', 'at', 'john.doe@example.com', 'or', 'visit', 'https://openai.com.', 'This', 'is', 'amazing', ',', 'isn', "'", 't', 'it', '?', 'Let', "'", 's', 'test', 'URLs', 'like', 'www.testsite.com', 'too', '.']
# Number of Tokens: 32
# Total Characters: 130
# Average Word Length: 3.09
# Type-Token Ratio: 0.906
